# %%
# !cat .env
# Out:
# cat: .env: No such file or directory

# %%
import json
from django.contrib.admin.utils import flatten
from helpers.strings import keys_to_snake_case, keys_to_camel_case
from rest_framework_json_api.utils import format_field_names
from tqdm.notebook import tqdm
from django.db.models import CharField
from django.db.models.functions import Cast

# %%
def generate_select_multiple_export(field):

    result={"cat":[]}    
    values=field["selectOptions"]["options"]

    for value in values:
        if field["apiName"] == "demandOrigin":
            result["cat"].append({"if":[{"in": 
                                     [value["value"], {"var": "formData."+field["apiName"]}]
                                    }, value["name"] + " ", ""]})
        else:
            result["cat"].append({"if":[{"in": 
                                     [value["value"], {"var": "formData."+field["apiName"]}]
                                    }, value["name"] + ", ", ""]})


    return result

# %%
def generate_select_export(field):
    result={"if":[]}    
    values=field["selectOptions"]["options"]
    
    for value in values:
        result["if"].append({"==":[{"var": "formData."+field["apiName"]}, value["value"]]})
        result["if"].append(value["name"])
        
    return result

# %%
def generate_export(field):
    result={"header": field["displayName"], "key": field["apiName"]}
    
    if field["dataType"]=="timestamp":
        result["isDate"]=True
    elif (field["dataType"]=="select") and ("options" in field["selectOptions"]):
        result["logic"]=generate_select_export(field)
    elif (field["dataType"]=="selectMultiple") and ("options" in field["selectOptions"]):
        result["logic"]=generate_select_multiple_export(field)
    elif field["dataType"]=="jsonLogic":
        result["logic"]=field["logic"]
    elif field["dataType"]=="float":
        result["style"]= {
                "num_fmt": "0.000"
                }
    
    
    return result

# %%
def generate_array_export(field, number=6):
    result_list=[]
    values=field["innerFields"]
    
    for value in values:
        
        if (value["dataType"] == "select") and ("options" in value["selectOptions"]):
            for index in range(1, number+1):            
                result={}
                result["header"]=field["displayName"] + " - " + value["displayName"] + " "  + str(index)
                result["key"]=value["apiName"]+str(index)
                result["logic"]={}
                result["logic"]["if"]=[]
                values_select=value["selectOptions"]["options"]

                for value_select in values_select:
                    result["logic"]["if"].append({"==":[{"var": "formData." + field["apiName"]+ "."+str(index-1) + "." +value["apiName"]}, value_select["value"]]})
                    result["logic"]["if"].append(value_select["name"])

                result_list.append(result)
        elif (value["dataType"] == "select") and ("reference" in value["selectOptions"]) and company.name == "CAJ":
            lista = [{"name":a['name'],"uuid":a['uuid_str']} for a in OccurrenceType.objects.filter(company=company,occurrence_kind=6).annotate(uuid_str=Cast("uuid",output_field=CharField())).values('name', 'uuid_str')]
            for index in range(1, number+1):            
                result={}
                result["header"]=field["displayName"] + " - " + value["displayName"] + " "  + str(index)
                result["key"]=value["apiName"]+str(index)
                result["logic"]={}
                result["logic"]["if"]=[]
#                 print(lista)
                values_select=lista

                for value_select in values_select:
                    result["logic"]["if"].append({"==":[{"var": "formData." + field["apiName"]+ "."+str(index-1) + "." +value["apiName"]}, value_select["uuid"]]})
                    result["logic"]["if"].append(value_select["name"])

                result_list.append(result)
        
        elif (value["dataType"] == "boolean") and ("display" in value["apiName"]):
            pass
        
        elif value["dataType"] == "innerImagesArray":
            pass
        
        elif (value["dataType"] == "selectMultiple") and ("options" in value["selectOptions"]):
            for index in range(1, number+1):            
                result={}
                result["header"]=field["displayName"] + " - " + value["displayName"] + " "  + str(index)
                result["key"]=value["apiName"]+str(index)
                result["logic"]={}
                result["logic"]["cat"]=[]
                values_select=value["selectOptions"]["options"]

                for value_select in values_select:
                    result["logic"]["cat"].append({"if":[{"in": 
                                     [value_select["value"], {"var": "formData." + field["apiName"]+ "."+str(index-1) + "." +value["apiName"]}]
                                    }, value_select["name"], ", "]})

                result_list.append(result)
            
        else:
            for index in range(1, number+1):
                result={}
                result["header"]=field["displayName"] + " - " + value["displayName"] + " " + str(index)
                result["key"]=value["apiName"]+str(index)
                result["logic"]= {"var": "formData." + field["apiName"] + "." + str(index-1) + "." + value["apiName"]}
                result_list.append(result)

    
    
    return result_list

# %%
def generate_array_export_lado_a_lado(field, number=6):
    result_list=[]
    values=field["innerFields"]
    
    for value in values:
        for index in range(1, number+1): 
            if (value["dataType"] == "select") and ("options" in value["selectOptions"]):            
                result={}
                result["header"]=field["displayName"] + " - " + value["displayName"] + " "  + str(index)
                result["key"]=value["apiName"]+str(index)
                result["logic"]={}
                result["logic"]["if"]=[]
                values_select=value["selectOptions"]["options"]

                for value_select in values_select:
                    result["logic"]["if"].append({"==":[{"var": "formData." + field["apiName"]+ "."+str(index-1) + "." +value["apiName"]}, value_select["value"]]})
                    result["logic"]["if"].append(value_select["name"])

            elif (value["dataType"] == "select") and ("reference" in value["selectOptions"]) and company.name == "CAJ":
                lista = [{"name":a['name'],"uuid":a['uuid_str']} for a in OccurrenceType.objects.filter(company=company,occurrence_kind=6).annotate(uuid_str=Cast("uuid",output_field=CharField())).values('name', 'uuid_str')]           
                result={}
                result["header"]=field["displayName"] + " - " + value["displayName"] + " "  + str(index)
                result["key"]=value["apiName"]+str(index)
                result["logic"]={}
                result["logic"]["if"]=[]
    #                 print(lista)
                values_select=lista

                for value_select in values_select:
                    result["logic"]["if"].append({"==":[{"var": "formData." + field["apiName"]+ "."+str(index-1) + "." +value["apiName"]}, value_select["uuid"]]})
                    result["logic"]["if"].append(value_select["name"])


            elif (value["dataType"] == "boolean") and ("display" in value["apiName"]):
                pass

            elif value["dataType"] == "innerImagesArray":
                pass

            elif (value["dataType"] == "selectMultiple") and ("options" in value["selectOptions"]):
                            
                result={}
                result["header"]=field["displayName"] + " - " + value["displayName"] + " "  + str(index)
                result["key"]=value["apiName"]+str(index)
                result["logic"]={}
                result["logic"]["cat"]=[]
                values_select=value["selectOptions"]["options"]

                for value_select in values_select:
                    result["logic"]["cat"].append({"if":[{"in": 
                                     [value_select["value"], {"var": "formData." + field["apiName"]+ "."+str(index-1) + "." +value["apiName"]}]
                                    }, value_select["name"], ", "]})


            else:
                result={}
                result["header"]=field["displayName"] + " - " + value["displayName"] + " " + str(index)
                result["key"]=value["apiName"]+str(index)
                result["logic"]= {"var": "formData." + field["apiName"] + "." + str(index-1) + "." + value["apiName"]}
            result_list.append(result)

    
    
    return result_list

# %%
def update_export_data(data, occ=None, filename=None):
    if occ is not None:
        if 'measurement_columns' in occ.form_fields.keys():
            del occ.form_fields['measurement_columns']
        occ.form_fields['measurementColumns']=data
        occ.save()
    if filename is not None:
        with open(filename + '.txt', 'w') as outfile:
            json.dump(data, outfile, indent=4)

# %%
def format_keys(obj, format_type="camelize"):
    if isinstance(obj, dict):
        for key, value in obj.items():
            if isinstance(value, dict):
                obj[key] = format_field_names(
                            format_keys(value), format_type
                            )
            elif isinstance(value, list):
                list_temp = value.copy()
                for i, item in enumerate(value):
                    if isinstance(item, dict):
                        list_temp[i] = format_field_names(
                        format_keys(item), format_type
                        )
                    else:
                        list_temp[i] = item
                obj[key] = list_temp
    return obj

# %%
# company=Company.objects.get(name='Eixo Sp - Pavimento')
company=Company.objects.get(name='Entrevias')
company
# Out:
# <Company: 91d69c92-2284-4570-9011-760a5a74a708: Entrevias>

# %%
# occ=OccurrenceType.objects.get(uuid='f6033d7d-9649-420d-9125-2000aefcd25a')
occ=OccurrenceType.objects.filter(company=company,name='Viga Benkelman').order_by('name')
# occ=OccurrenceType.objects.filter(company=company, active=True, next_version__isnull=True).order_by('name')
occ.count()
# Out:
# 1

# %%
for match in tqdm(occ):
    for index, field in enumerate(match.form_fields['fields']):
        match.form_fields['fields'][index]=format_keys(keys_to_camel_case(field))
    for indexg, field_group in enumerate(match.form_fields['groups']):
        match.form_fields['groups'][indexg]=format_keys(keys_to_camel_case(field_group))
    match.save()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
field_group
# Out:
# {'order': 3, 'members': [6], 'displayName': 'Informações adicionais'}

# %%
# columns=[]

# for field in occ.form_fields['fields']:
    
#     if field['dataType'] != 'arrayOfObjects':
#         columns.append(generate_export(field))
#     else:
#         columns.append(generate_array_export(field))
    

# columns=flatten(columns)

# update_export_data(columns, occ=occ)

# %%
for match in tqdm(occ):
        
    try:
        columns=[]

        for field in match.form_fields['fields']:
            if field['dataType'] != 'arrayOfObjects':
                columns.append(generate_export(field))
            else:
#                 pass
                columns.append(generate_array_export(field, 6))
#                 columns.append(generate_array_export_lado_a_lado(field, 50))
                


        columns=flatten(columns)
#         update_export_data(columns, occ=match)
    
    except Exception as e:
        print(f'{match.uuid} - {e}')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
columns
# Out:
# [{'header': 'Código de Edital', 'key': 'contratualCode'},
#  {'header': 'CSP', 'key': 'csp'},
#  {'header': 'Código da ocorrência', 'key': 'artespCode'},
#  {'header': 'Recebido da ARTESP em:', 'key': 'receivedDate', 'isDate': True},
#  {'header': 'Comprimento (m)', 'key': 'length', 'style': {'num_fmt': '0.000'}},
#  {'header': 'Largura (m)', 'key': 'width', 'style': {'num_fmt': '0.000'}},
#  {'header': 'Altura (m)', 'key': 'height', 'style': {'num_fmt': '0.000'}},
#  {'header': 'Área (m²)', 'key': 'area', 'style': {'num_fmt': '0.000'}},
#  {'header': 'Volume (m³)', 'key': 'volume', 'style': {'num_fmt': '0.000'}},
#  {'header': 'Observações', 'key': 'notes'},
#  {'header': 'Origem',
#   'key': 'demandOrigin',
#   'logic': {'cat': [{'if': [{'in': ['1', {'var': 'formData.demandOrigin'}]},
#       'CCO ',
#       '']},
#     {'if': [{'in': ['2', {'var': 'formData.demandOrigin'}]},
#       'Entrevias ',
#       '']},
#     {'if': [{'in': ['3', {'var': 'formData.demandOrigin'}]},
#       'ARTESP DIN ',
#       '']},
#     {'if': [{'in': ['4', {'var': 'formData.demandOrigin'}]},
#       'ARTESP DOP ',
#       '']}]}},
#  {'header': 'Dano ao Patrimônio?', 'key': 'notDamage'},
#  {'header': 'Descrição do Dano ao Patrimônio', 'key': 'notDamageDescription'},
#  {'header': 'Código CCO', 'key': 'ccoCode'},
#  {'header': 'Código Interno', 'key': 'internCode'},
#  {'header': 'Quantitativos adicionados - Km Estaca 1',
#   'key': 'kmStation1',
#   'logic': {'var': 'formData.newQuant.0.kmStation'}},
#  {'header': 'Quantitativos adicionados - Km Estaca 2',
#   'key': 'kmStation2',
#   'logic': {'var': 'formData.newQuant.1.kmStation'}},
#  {'header': 'Quantitativos adicionados - Km Estaca 3',
#   'key': 'kmStation3',
#   'logic': {'var': 'formData.newQuant.2.kmStation'}},
#  {'header': 'Quantitativos adicionados - Km Estaca 4',
#   'key': 'kmStation4',
#   'logic': {'var': 'formData.newQuant.3.kmStation'}},
#  {'header': 'Quantitativos adicionados - Km Estaca 5',
#   'key': 'kmStation5',
#   'logic': {'var': 'formData.newQuant.4.kmStation'}},
#  {'header': 'Quantitativos adicionados - Km Estaca 6',
#   'key': 'kmStation6',
#   'logic': {'var': 'formData.newQuant.5.kmStation'}},
#  {'header': 'Quantitativos adicionados - Leitura Inicial (L0) 1',
#   'key': 'initialReading1',
#   'logic': {'var': 'formData.newQuant.0.initialReading'}},
#  {'header': 'Quantitativos adicionados - Leitura Inicial (L0) 2',
#   'key': 'initialReading2',
#   'logic': {'var': 'formData.newQuant.1.initialReading'}},
#  {'header': 'Quantitativos adicionados - Leitura Inicial (L0) 3',
#   'key': 'initialReading3',
#   'logic': {'var': 'formData.newQuant.2.initialReading'}},
#  {'header': 'Quantitativos adicionados - Leitura Inicial (L0) 4',
#   'key': 'initialReading4',
#   'logic': {'var': 'formData.newQuant.3.initialReading'}},
#  {'header': 'Quantitativos adicionados - Leitura Inicial (L0) 5',
#   'key': 'initialReading5',
#   'logic': {'var': 'formData.newQuant.4.initialReading'}},
#  {'header': 'Quantitativos adicionados - Leitura Inicial (L0) 6',
#   'key': 'initialReading6',
#   'logic': {'var': 'formData.newQuant.5.initialReading'}},
#  {'header': 'Quantitativos adicionados - Leitura (L25) 1',
#   'key': 'reading1',
#   'logic': {'var': 'formData.newQuant.0.reading'}},
#  {'header': 'Quantitativos adicionados - Leitura (L25) 2',
#   'key': 'reading2',
#   'logic': {'var': 'formData.newQuant.1.reading'}},
#  {'header': 'Quantitativos adicionados - Leitura (L25) 3',
#   'key': 'reading3',
#   'logic': {'var': 'formData.newQuant.2.reading'}},
#  {'header': 'Quantitativos adicionados - Leitura (L25) 4',
#   'key': 'reading4',
#   'logic': {'var': 'formData.newQuant.3.reading'}},
#  {'header': 'Quantitativos adicionados - Leitura (L25) 5',
#   'key': 'reading5',
#   'logic': {'var': 'formData.newQuant.4.reading'}},
#  {'header': 'Quantitativos adicionados - Leitura (L25) 6',
#   'key': 'reading6',
#   'logic': {'var': 'formData.newQuant.5.reading'}},
#  {'header': 'Quantitativos adicionados - Leitura Final (L1) 1',
#   'key': 'finalReading 1',
#   'logic': {'var': 'formData.newQuant.0.finalReading '}},
#  {'header': 'Quantitativos adicionados - Leitura Final (L1) 2',
#   'key': 'finalReading 2',
#   'logic': {'var': 'formData.newQuant.1.finalReading '}},
#  {'header': 'Quantitativos adicionados - Leitura Final (L1) 3',
#   'key': 'finalReading 3',
#   'logic': {'var': 'formData.newQuant.2.finalReading '}},
#  {'header': 'Quantitativos adicionados - Leitura Final (L1) 4',
#   'key': 'finalReading 4',
#   'logic': {'var': 'formData.newQuant.3.finalReading '}},
#  {'header': 'Quantitativos adicionados - Leitura Final (L1) 5',
#   'key': 'finalReading 5',
#   'logic': {'var': 'formData.newQuant.4.finalReading '}},
#  {'header': 'Quantitativos adicionados - Leitura Final (L1) 6',
#   'key': 'finalReading 6',
#   'logic': {'var': 'formData.newQuant.5.finalReading '}},
#  {'header': 'Quantitativos adicionados - Deflexão (0,01mm) 1',
#   'key': 'deflection1',
#   'logic': {'var': 'formData.newQuant.0.deflection'}},
#  {'header': 'Quantitativos adicionados - Deflexão (0,01mm) 2',
#   'key': 'deflection2',
#   'logic': {'var': 'formData.newQuant.1.deflection'}},
#  {'header': 'Quantitativos adicionados - Deflexão (0,01mm) 3',
#   'key': 'deflection3',
#   'logic': {'var': 'formData.newQuant.2.deflection'}},
#  {'header': 'Quantitativos adicionados - Deflexão (0,01mm) 4',
#   'key': 'deflection4',
#   'logic': {'var': 'formData.newQuant.3.deflection'}},
#  {'header': 'Quantitativos adicionados - Deflexão (0,01mm) 5',
#   'key': 'deflection5',
#   'logic': {'var': 'formData.newQuant.4.deflection'}},
#  {'header': 'Quantitativos adicionados - Deflexão (0,01mm) 6',
#   'key': 'deflection6',
#   'logic': {'var': 'formData.newQuant.5.deflection'}},
#  {'header': 'Quantitativos adicionados - Raio de Curvatura (m) 1',
#   'key': 'radiusofCurvature 1',
#   'logic': {'var': 'formData.newQuant.0.radiusofCurvature '}},
#  {'header': 'Quantitativos adicionados - Raio de Curvatura (m) 2',
#   'key': 'radiusofCurvature 2',
#   'logic': {'var': 'formData.newQuant.1.radiusofCurvature '}},
#  {'header': 'Quantitativos adicionados - Raio de Curvatura (m) 3',
#   'key': 'radiusofCurvature 3',
#   'logic': {'var': 'formData.newQuant.2.radiusofCurvature '}},
#  {'header': 'Quantitativos adicionados - Raio de Curvatura (m) 4',
#   'key': 'radiusofCurvature 4',
#   'logic': {'var': 'formData.newQuant.3.radiusofCurvature '}},
#  {'header': 'Quantitativos adicionados - Raio de Curvatura (m) 5',
#   'key': 'radiusofCurvature 5',
#   'logic': {'var': 'formData.newQuant.4.radiusofCurvature '}},
#  {'header': 'Quantitativos adicionados - Raio de Curvatura (m) 6',
#   'key': 'radiusofCurvature 6',
#   'logic': {'var': 'formData.newQuant.5.radiusofCurvature '}},
#  {'header': 'Quantitativos adicionados - Temperatura 1',
#   'key': 'temperature 1',
#   'logic': {'var': 'formData.newQuant.0.temperature '}},
#  {'header': 'Quantitativos adicionados - Temperatura 2',
#   'key': 'temperature 2',
#   'logic': {'var': 'formData.newQuant.1.temperature '}},
#  {'header': 'Quantitativos adicionados - Temperatura 3',
#   'key': 'temperature 3',
#   'logic': {'var': 'formData.newQuant.2.temperature '}},
#  {'header': 'Quantitativos adicionados - Temperatura 4',
#   'key': 'temperature 4',
#   'logic': {'var': 'formData.newQuant.3.temperature '}},
#  {'header': 'Quantitativos adicionados - Temperatura 5',
#   'key': 'temperature 5',
#   'logic': {'var': 'formData.newQuant.4.temperature '}},
#  {'header': 'Quantitativos adicionados - Temperatura 6',
#   'key': 'temperature 6',
#   'logic': {'var': 'formData.newQuant.5.temperature '}},
#  {'header': 'Volume (t)', 'key': 'tonnage', 'style': {'num_fmt': '0.000'}},
#  {'header': 'Notificações?', 'key': 'isNotified'},
#  {'header': 'Nº da Notificação', 'key': 'notifiedId'},
#  {'header': 'Nº da Infração', 'key': 'notifiedNumber'},
#  {'header': 'Volume do Descarte de fresa (m³)',
#   'key': 'volumeDiscard',
#   'style': {'num_fmt': '0.000'}},
#  {'header': 'Período da Medição', 'key': 'notePeriod'},
#  {'header': 'Fornecimento de brita #02 (m³)',
#   'key': 'stoneSupply',
#   'style': {'num_fmt': '0.000'}},
#  {'header': 'Geomanta (m)', 'key': 'geomanta', 'style': {'num_fmt': '0.000'}},
#  {'header': 'Tubo tipo kanaflex (D 100mm)',
#   'key': 'pipeKanaflex',
#   'style': {'num_fmt': '0.000'}},
#  {'header': 'Ligante RR-2C (m²)',
#   'key': 'binder',
#   'style': {'num_fmt': '0.000'}},
#  {'header': 'Ala drenos (conforme projeto)',
#   'key': 'wingDrain',
#   'style': {'num_fmt': '0.000'}}]

# %%
occ=OccurrenceType.objects.filter(uuid=str('da392f7a-ab26-47eb-900e-497ca86850c7')).first()
teste=occ.form_fields['fields'][5]

# %%
generate_array_export(teste)
# Out:
# [{'header': 'Inclusão de devolutivas - Classe 1',
#   'key': 'occurrenceType1',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '029fcd2f-998b-4d19-802c-325617478c27']},
#     'B2.3 - Sinalização',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '02ed6a53-21ef-42e0-b9a8-703520ff54db']},
#     'C3.3 - Integridade Das Peças',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '078a0011-43b8-4345-ad31-3a16b010d87b']},
#     'A1.1 - Controle Da Produção De Efluentes Contaminantes E Condições Sanitárias',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '11e22bda-19e1-45f5-afcd-6744acba229e']},
#     'B2.1 - Escoramento - Tem Projeto? Precisa Do Escoramento?',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '1361cb22-a6f2-4eae-a233-b91be422915f']},
#     'C2.6 - Espessura Das Camadas',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '15f5f0a0-2be3-4ab2-9584-87442096701f']},
#     'C3.6 - Viga De Travamento',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '1a0fa90c-1f50-4eb1-9f96-46436ed5af61']},
#     'C3.1 - Execução Da Base - Areia',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '2590028b-06cc-4e05-b798-664886cc081d']},
#     'C5.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '2ffd8525-a322-4d32-94a5-27e1189b70fe']},
#     'C2.4 - Umidade Do Material - Base E Sub-Base',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '32ae70a3-b61f-4880-9947-6b48c5a505d1']},
#     'B2.4 - Organização Do Canteiro/ Frente De Trabalho',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '32f1b304-e4f1-47f9-90e3-0376c53b6d9c']},
#     'C5.5 - Execução De Desenpeno',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '336680b3-d766-4964-b516-b72890b8729c']},
#     'C3.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '3567af75-c947-4d3b-9745-3b102ddfd211']},
#     'C2.3 - Adensamento Hidráulico',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '3738d871-64a1-4d63-a36c-4ee166a359ce']},
#     'C3.7 - Limpeza Do Trecho',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '38a8a156-173f-45ea-9a83-5004e272c36c']},
#     'A1.3 - Controle De Ruído E De Horários De Funcionamento',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '45904e96-32d7-444c-ab59-6f8a19139df4']},
#     'C3.5 - Aplicação De Placa Vibratória',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '572744b0-f742-4b72-905c-1e23836e776f']},
#     'C3.6 - Compactação + Placa Vibratória (Sem Água)',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '5c6054ac-2e07-4f8c-bfc7-5f347c844ee4']},
#     'C3.4 - Nivelamento Das Peças/Assentamento - Com Correto Espaçamento (2,5 A 5Mm) - Cfme Via',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '5db71040-4ba6-4547-b1f3-3085086cad7b']},
#     'A1.2 - Controle De Emissão De Poeira E Fumaça',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '6080f99c-f943-4872-9a50-e7d5a3234d88']},
#     'C1.2 - Destinação Correta De Material Descartado',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '63a33eac-495f-41e8-9435-b22d21cd95d7']},
#     'A2.1 - Marcação Prévia Dos Indivíduos A Serem Suprimidos',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '6cbb3f7c-474f-4700-aabf-d9a2eb233e2c']},
#     'C2.5 - Compactação - Número De Fechas',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '71668bc9-fb3d-405f-842c-56162c68c212']},
#     'C3.2 - Regularidade Da Superfície',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '7a6b87f9-8119-4dc6-a4ca-58bf88a3ff17']},
#     'C2.2 - Berço De Areia - Embasamento Dos Tubos',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '80211de7-4e39-4bc2-9bf5-5df3efca6257']},
#     'A3.1 - Reconhecimento De Vestígios Arqueológicos',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '86f3625f-0c73-458e-8ed1-627cc3edac03']},
#     'B1.1 - Documentação: Registro Dos Trabalhadores E Empresas Contratadas.',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '899f0c2f-d128-4f8b-8458-6551229c9285']},
#     'C5.4 - Despejo De Concreto Com Fck >= 25 Mpa Para Entrada De Carro E 20 Mpa Para Passeio',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '9447ffdb-fb73-455a-86e6-585969ae1737']},
#     'A1.4 - Controle De Vazamentos De Combustíveis, Lubrificantes E Águas Residuais De Concretagem',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '971b5a5a-47f6-4e7e-8b06-447622912c20']},
#     'C2.7 - Limpeza Da Via',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       '99789fef-24bb-4a40-9e47-9289f06850c2']},
#     'C3.4 - Espessura Da Capa Asfáltica - À Partir De 5Mm',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'a8b610cd-081b-4f04-8b9a-07c9d58941a6']},
#     'B2.5 - Veículos, Máquinas E Equipamentos',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'b5ce6cb2-86b8-48dd-896c-d856c434e461']},
#     'A2.4 - Destinação de restos vegetais não aproveitáveis',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'c41ff4ef-cab2-46cd-b054-00f7fa1b98ba']},
#     'B1.3 - Atendimento Às Solicitações/Notificação: Atende Ou Está Atendendo Solicitações?',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'c48e5550-3e60-4050-9f52-2e74d16f7eb8']},
#     "B2.2 - Epi'S E Uniformes",
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'c967aaee-8ae3-4fe9-865d-6dc9ef8dacfd']},
#     'C3.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'cc7ccd2e-5a5a-4661-907e-1b76030d491a']},
#     'A1.6 - Gerenciamento Dos Resíduos Sólidos, Segregação / Classificação',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'd8b22ace-5f8a-475d-aa87-5341c680a5af']},
#     'C3.3 - Pintura De Ligação - Aplicação E Tempo De Rompimento',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'd8e6c771-5d72-405f-8d20-8fb228eedfb3']},
#     'C5.3 - Espessura Correta Da Cancha - Entrada De Carro (10Cm) E Passeio (5 A 7Cm)',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'dd16ba8f-c127-4002-9de1-d60aae3eafe8']},
#     'C2.1 - Qualidade Do Material - Se Não Tiver Conforme Nem Executa O Serviço',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'e7379fa8-1550-4920-88c1-f5fb253e9acf']},
#     'C1.3 - Organização Do Material Reaproveitável Na Via',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'e7e92a41-5dba-4d9c-b7a0-0e57d485911e']},
#     'C1.1 - Cortes Retos/ Organização Do Poliedro Na Área De Serviços',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'e8144528-c4b0-44fe-8041-dcf69c2ca0ba']},
#     'A2.3 - Classificação E Aproveitamento De Restos Vegetais',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'e93c90d8-06e6-49fa-afba-953e6f547a39']},
#     'C3.5 - Temperatura Cbuq - De 140º A 180º',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'f1396ce9-12c8-4605-952e-76bef92ff663']},
#     'A1.5 - Gerenciamento De Recursos Hídricos',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'fa49dd4c-973a-41cd-9de7-e241e925b533']},
#     'B1.2 - Integração - Tem Treinamento De Integração De Saúde E Segurança Realizado Pela Caj?',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'fbd2472a-8eb5-4ce0-8621-fa4202a27ba5']},
#     'C3.7 - Recolhimento Imediato Do Material Descartado + Varrição',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'febc3531-3249-45ae-9e65-d1e205637ae4']},
#     'C5.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.0.occurrenceType'},
#       'ffca1af8-c87b-4eec-8b77-eb78caa49054']},
#     'A2.2 - Proteção Da Vegetação Do Entorno, Quando Necessário']}},
#  {'header': 'Inclusão de devolutivas - Classe 2',
#   'key': 'occurrenceType2',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '029fcd2f-998b-4d19-802c-325617478c27']},
#     'B2.3 - Sinalização',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '02ed6a53-21ef-42e0-b9a8-703520ff54db']},
#     'C3.3 - Integridade Das Peças',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '078a0011-43b8-4345-ad31-3a16b010d87b']},
#     'A1.1 - Controle Da Produção De Efluentes Contaminantes E Condições Sanitárias',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '11e22bda-19e1-45f5-afcd-6744acba229e']},
#     'B2.1 - Escoramento - Tem Projeto? Precisa Do Escoramento?',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '1361cb22-a6f2-4eae-a233-b91be422915f']},
#     'C2.6 - Espessura Das Camadas',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '15f5f0a0-2be3-4ab2-9584-87442096701f']},
#     'C3.6 - Viga De Travamento',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '1a0fa90c-1f50-4eb1-9f96-46436ed5af61']},
#     'C3.1 - Execução Da Base - Areia',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '2590028b-06cc-4e05-b798-664886cc081d']},
#     'C5.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '2ffd8525-a322-4d32-94a5-27e1189b70fe']},
#     'C2.4 - Umidade Do Material - Base E Sub-Base',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '32ae70a3-b61f-4880-9947-6b48c5a505d1']},
#     'B2.4 - Organização Do Canteiro/ Frente De Trabalho',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '32f1b304-e4f1-47f9-90e3-0376c53b6d9c']},
#     'C5.5 - Execução De Desenpeno',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '336680b3-d766-4964-b516-b72890b8729c']},
#     'C3.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '3567af75-c947-4d3b-9745-3b102ddfd211']},
#     'C2.3 - Adensamento Hidráulico',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '3738d871-64a1-4d63-a36c-4ee166a359ce']},
#     'C3.7 - Limpeza Do Trecho',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '38a8a156-173f-45ea-9a83-5004e272c36c']},
#     'A1.3 - Controle De Ruído E De Horários De Funcionamento',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '45904e96-32d7-444c-ab59-6f8a19139df4']},
#     'C3.5 - Aplicação De Placa Vibratória',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '572744b0-f742-4b72-905c-1e23836e776f']},
#     'C3.6 - Compactação + Placa Vibratória (Sem Água)',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '5c6054ac-2e07-4f8c-bfc7-5f347c844ee4']},
#     'C3.4 - Nivelamento Das Peças/Assentamento - Com Correto Espaçamento (2,5 A 5Mm) - Cfme Via',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '5db71040-4ba6-4547-b1f3-3085086cad7b']},
#     'A1.2 - Controle De Emissão De Poeira E Fumaça',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '6080f99c-f943-4872-9a50-e7d5a3234d88']},
#     'C1.2 - Destinação Correta De Material Descartado',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '63a33eac-495f-41e8-9435-b22d21cd95d7']},
#     'A2.1 - Marcação Prévia Dos Indivíduos A Serem Suprimidos',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '6cbb3f7c-474f-4700-aabf-d9a2eb233e2c']},
#     'C2.5 - Compactação - Número De Fechas',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '71668bc9-fb3d-405f-842c-56162c68c212']},
#     'C3.2 - Regularidade Da Superfície',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '7a6b87f9-8119-4dc6-a4ca-58bf88a3ff17']},
#     'C2.2 - Berço De Areia - Embasamento Dos Tubos',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '80211de7-4e39-4bc2-9bf5-5df3efca6257']},
#     'A3.1 - Reconhecimento De Vestígios Arqueológicos',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '86f3625f-0c73-458e-8ed1-627cc3edac03']},
#     'B1.1 - Documentação: Registro Dos Trabalhadores E Empresas Contratadas.',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '899f0c2f-d128-4f8b-8458-6551229c9285']},
#     'C5.4 - Despejo De Concreto Com Fck >= 25 Mpa Para Entrada De Carro E 20 Mpa Para Passeio',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '9447ffdb-fb73-455a-86e6-585969ae1737']},
#     'A1.4 - Controle De Vazamentos De Combustíveis, Lubrificantes E Águas Residuais De Concretagem',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '971b5a5a-47f6-4e7e-8b06-447622912c20']},
#     'C2.7 - Limpeza Da Via',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       '99789fef-24bb-4a40-9e47-9289f06850c2']},
#     'C3.4 - Espessura Da Capa Asfáltica - À Partir De 5Mm',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'a8b610cd-081b-4f04-8b9a-07c9d58941a6']},
#     'B2.5 - Veículos, Máquinas E Equipamentos',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'b5ce6cb2-86b8-48dd-896c-d856c434e461']},
#     'A2.4 - Destinação de restos vegetais não aproveitáveis',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'c41ff4ef-cab2-46cd-b054-00f7fa1b98ba']},
#     'B1.3 - Atendimento Às Solicitações/Notificação: Atende Ou Está Atendendo Solicitações?',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'c48e5550-3e60-4050-9f52-2e74d16f7eb8']},
#     "B2.2 - Epi'S E Uniformes",
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'c967aaee-8ae3-4fe9-865d-6dc9ef8dacfd']},
#     'C3.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'cc7ccd2e-5a5a-4661-907e-1b76030d491a']},
#     'A1.6 - Gerenciamento Dos Resíduos Sólidos, Segregação / Classificação',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'd8b22ace-5f8a-475d-aa87-5341c680a5af']},
#     'C3.3 - Pintura De Ligação - Aplicação E Tempo De Rompimento',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'd8e6c771-5d72-405f-8d20-8fb228eedfb3']},
#     'C5.3 - Espessura Correta Da Cancha - Entrada De Carro (10Cm) E Passeio (5 A 7Cm)',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'dd16ba8f-c127-4002-9de1-d60aae3eafe8']},
#     'C2.1 - Qualidade Do Material - Se Não Tiver Conforme Nem Executa O Serviço',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'e7379fa8-1550-4920-88c1-f5fb253e9acf']},
#     'C1.3 - Organização Do Material Reaproveitável Na Via',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'e7e92a41-5dba-4d9c-b7a0-0e57d485911e']},
#     'C1.1 - Cortes Retos/ Organização Do Poliedro Na Área De Serviços',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'e8144528-c4b0-44fe-8041-dcf69c2ca0ba']},
#     'A2.3 - Classificação E Aproveitamento De Restos Vegetais',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'e93c90d8-06e6-49fa-afba-953e6f547a39']},
#     'C3.5 - Temperatura Cbuq - De 140º A 180º',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'f1396ce9-12c8-4605-952e-76bef92ff663']},
#     'A1.5 - Gerenciamento De Recursos Hídricos',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'fa49dd4c-973a-41cd-9de7-e241e925b533']},
#     'B1.2 - Integração - Tem Treinamento De Integração De Saúde E Segurança Realizado Pela Caj?',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'fbd2472a-8eb5-4ce0-8621-fa4202a27ba5']},
#     'C3.7 - Recolhimento Imediato Do Material Descartado + Varrição',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'febc3531-3249-45ae-9e65-d1e205637ae4']},
#     'C5.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.1.occurrenceType'},
#       'ffca1af8-c87b-4eec-8b77-eb78caa49054']},
#     'A2.2 - Proteção Da Vegetação Do Entorno, Quando Necessário']}},
#  {'header': 'Inclusão de devolutivas - Classe 3',
#   'key': 'occurrenceType3',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '029fcd2f-998b-4d19-802c-325617478c27']},
#     'B2.3 - Sinalização',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '02ed6a53-21ef-42e0-b9a8-703520ff54db']},
#     'C3.3 - Integridade Das Peças',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '078a0011-43b8-4345-ad31-3a16b010d87b']},
#     'A1.1 - Controle Da Produção De Efluentes Contaminantes E Condições Sanitárias',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '11e22bda-19e1-45f5-afcd-6744acba229e']},
#     'B2.1 - Escoramento - Tem Projeto? Precisa Do Escoramento?',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '1361cb22-a6f2-4eae-a233-b91be422915f']},
#     'C2.6 - Espessura Das Camadas',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '15f5f0a0-2be3-4ab2-9584-87442096701f']},
#     'C3.6 - Viga De Travamento',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '1a0fa90c-1f50-4eb1-9f96-46436ed5af61']},
#     'C3.1 - Execução Da Base - Areia',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '2590028b-06cc-4e05-b798-664886cc081d']},
#     'C5.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '2ffd8525-a322-4d32-94a5-27e1189b70fe']},
#     'C2.4 - Umidade Do Material - Base E Sub-Base',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '32ae70a3-b61f-4880-9947-6b48c5a505d1']},
#     'B2.4 - Organização Do Canteiro/ Frente De Trabalho',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '32f1b304-e4f1-47f9-90e3-0376c53b6d9c']},
#     'C5.5 - Execução De Desenpeno',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '336680b3-d766-4964-b516-b72890b8729c']},
#     'C3.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '3567af75-c947-4d3b-9745-3b102ddfd211']},
#     'C2.3 - Adensamento Hidráulico',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '3738d871-64a1-4d63-a36c-4ee166a359ce']},
#     'C3.7 - Limpeza Do Trecho',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '38a8a156-173f-45ea-9a83-5004e272c36c']},
#     'A1.3 - Controle De Ruído E De Horários De Funcionamento',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '45904e96-32d7-444c-ab59-6f8a19139df4']},
#     'C3.5 - Aplicação De Placa Vibratória',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '572744b0-f742-4b72-905c-1e23836e776f']},
#     'C3.6 - Compactação + Placa Vibratória (Sem Água)',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '5c6054ac-2e07-4f8c-bfc7-5f347c844ee4']},
#     'C3.4 - Nivelamento Das Peças/Assentamento - Com Correto Espaçamento (2,5 A 5Mm) - Cfme Via',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '5db71040-4ba6-4547-b1f3-3085086cad7b']},
#     'A1.2 - Controle De Emissão De Poeira E Fumaça',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '6080f99c-f943-4872-9a50-e7d5a3234d88']},
#     'C1.2 - Destinação Correta De Material Descartado',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '63a33eac-495f-41e8-9435-b22d21cd95d7']},
#     'A2.1 - Marcação Prévia Dos Indivíduos A Serem Suprimidos',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '6cbb3f7c-474f-4700-aabf-d9a2eb233e2c']},
#     'C2.5 - Compactação - Número De Fechas',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '71668bc9-fb3d-405f-842c-56162c68c212']},
#     'C3.2 - Regularidade Da Superfície',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '7a6b87f9-8119-4dc6-a4ca-58bf88a3ff17']},
#     'C2.2 - Berço De Areia - Embasamento Dos Tubos',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '80211de7-4e39-4bc2-9bf5-5df3efca6257']},
#     'A3.1 - Reconhecimento De Vestígios Arqueológicos',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '86f3625f-0c73-458e-8ed1-627cc3edac03']},
#     'B1.1 - Documentação: Registro Dos Trabalhadores E Empresas Contratadas.',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '899f0c2f-d128-4f8b-8458-6551229c9285']},
#     'C5.4 - Despejo De Concreto Com Fck >= 25 Mpa Para Entrada De Carro E 20 Mpa Para Passeio',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '9447ffdb-fb73-455a-86e6-585969ae1737']},
#     'A1.4 - Controle De Vazamentos De Combustíveis, Lubrificantes E Águas Residuais De Concretagem',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '971b5a5a-47f6-4e7e-8b06-447622912c20']},
#     'C2.7 - Limpeza Da Via',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       '99789fef-24bb-4a40-9e47-9289f06850c2']},
#     'C3.4 - Espessura Da Capa Asfáltica - À Partir De 5Mm',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'a8b610cd-081b-4f04-8b9a-07c9d58941a6']},
#     'B2.5 - Veículos, Máquinas E Equipamentos',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'b5ce6cb2-86b8-48dd-896c-d856c434e461']},
#     'A2.4 - Destinação de restos vegetais não aproveitáveis',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'c41ff4ef-cab2-46cd-b054-00f7fa1b98ba']},
#     'B1.3 - Atendimento Às Solicitações/Notificação: Atende Ou Está Atendendo Solicitações?',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'c48e5550-3e60-4050-9f52-2e74d16f7eb8']},
#     "B2.2 - Epi'S E Uniformes",
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'c967aaee-8ae3-4fe9-865d-6dc9ef8dacfd']},
#     'C3.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'cc7ccd2e-5a5a-4661-907e-1b76030d491a']},
#     'A1.6 - Gerenciamento Dos Resíduos Sólidos, Segregação / Classificação',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'd8b22ace-5f8a-475d-aa87-5341c680a5af']},
#     'C3.3 - Pintura De Ligação - Aplicação E Tempo De Rompimento',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'd8e6c771-5d72-405f-8d20-8fb228eedfb3']},
#     'C5.3 - Espessura Correta Da Cancha - Entrada De Carro (10Cm) E Passeio (5 A 7Cm)',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'dd16ba8f-c127-4002-9de1-d60aae3eafe8']},
#     'C2.1 - Qualidade Do Material - Se Não Tiver Conforme Nem Executa O Serviço',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'e7379fa8-1550-4920-88c1-f5fb253e9acf']},
#     'C1.3 - Organização Do Material Reaproveitável Na Via',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'e7e92a41-5dba-4d9c-b7a0-0e57d485911e']},
#     'C1.1 - Cortes Retos/ Organização Do Poliedro Na Área De Serviços',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'e8144528-c4b0-44fe-8041-dcf69c2ca0ba']},
#     'A2.3 - Classificação E Aproveitamento De Restos Vegetais',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'e93c90d8-06e6-49fa-afba-953e6f547a39']},
#     'C3.5 - Temperatura Cbuq - De 140º A 180º',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'f1396ce9-12c8-4605-952e-76bef92ff663']},
#     'A1.5 - Gerenciamento De Recursos Hídricos',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'fa49dd4c-973a-41cd-9de7-e241e925b533']},
#     'B1.2 - Integração - Tem Treinamento De Integração De Saúde E Segurança Realizado Pela Caj?',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'fbd2472a-8eb5-4ce0-8621-fa4202a27ba5']},
#     'C3.7 - Recolhimento Imediato Do Material Descartado + Varrição',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'febc3531-3249-45ae-9e65-d1e205637ae4']},
#     'C5.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.2.occurrenceType'},
#       'ffca1af8-c87b-4eec-8b77-eb78caa49054']},
#     'A2.2 - Proteção Da Vegetação Do Entorno, Quando Necessário']}},
#  {'header': 'Inclusão de devolutivas - Classe 4',
#   'key': 'occurrenceType4',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '029fcd2f-998b-4d19-802c-325617478c27']},
#     'B2.3 - Sinalização',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '02ed6a53-21ef-42e0-b9a8-703520ff54db']},
#     'C3.3 - Integridade Das Peças',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '078a0011-43b8-4345-ad31-3a16b010d87b']},
#     'A1.1 - Controle Da Produção De Efluentes Contaminantes E Condições Sanitárias',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '11e22bda-19e1-45f5-afcd-6744acba229e']},
#     'B2.1 - Escoramento - Tem Projeto? Precisa Do Escoramento?',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '1361cb22-a6f2-4eae-a233-b91be422915f']},
#     'C2.6 - Espessura Das Camadas',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '15f5f0a0-2be3-4ab2-9584-87442096701f']},
#     'C3.6 - Viga De Travamento',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '1a0fa90c-1f50-4eb1-9f96-46436ed5af61']},
#     'C3.1 - Execução Da Base - Areia',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '2590028b-06cc-4e05-b798-664886cc081d']},
#     'C5.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '2ffd8525-a322-4d32-94a5-27e1189b70fe']},
#     'C2.4 - Umidade Do Material - Base E Sub-Base',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '32ae70a3-b61f-4880-9947-6b48c5a505d1']},
#     'B2.4 - Organização Do Canteiro/ Frente De Trabalho',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '32f1b304-e4f1-47f9-90e3-0376c53b6d9c']},
#     'C5.5 - Execução De Desenpeno',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '336680b3-d766-4964-b516-b72890b8729c']},
#     'C3.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '3567af75-c947-4d3b-9745-3b102ddfd211']},
#     'C2.3 - Adensamento Hidráulico',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '3738d871-64a1-4d63-a36c-4ee166a359ce']},
#     'C3.7 - Limpeza Do Trecho',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '38a8a156-173f-45ea-9a83-5004e272c36c']},
#     'A1.3 - Controle De Ruído E De Horários De Funcionamento',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '45904e96-32d7-444c-ab59-6f8a19139df4']},
#     'C3.5 - Aplicação De Placa Vibratória',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '572744b0-f742-4b72-905c-1e23836e776f']},
#     'C3.6 - Compactação + Placa Vibratória (Sem Água)',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '5c6054ac-2e07-4f8c-bfc7-5f347c844ee4']},
#     'C3.4 - Nivelamento Das Peças/Assentamento - Com Correto Espaçamento (2,5 A 5Mm) - Cfme Via',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '5db71040-4ba6-4547-b1f3-3085086cad7b']},
#     'A1.2 - Controle De Emissão De Poeira E Fumaça',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '6080f99c-f943-4872-9a50-e7d5a3234d88']},
#     'C1.2 - Destinação Correta De Material Descartado',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '63a33eac-495f-41e8-9435-b22d21cd95d7']},
#     'A2.1 - Marcação Prévia Dos Indivíduos A Serem Suprimidos',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '6cbb3f7c-474f-4700-aabf-d9a2eb233e2c']},
#     'C2.5 - Compactação - Número De Fechas',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '71668bc9-fb3d-405f-842c-56162c68c212']},
#     'C3.2 - Regularidade Da Superfície',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '7a6b87f9-8119-4dc6-a4ca-58bf88a3ff17']},
#     'C2.2 - Berço De Areia - Embasamento Dos Tubos',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '80211de7-4e39-4bc2-9bf5-5df3efca6257']},
#     'A3.1 - Reconhecimento De Vestígios Arqueológicos',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '86f3625f-0c73-458e-8ed1-627cc3edac03']},
#     'B1.1 - Documentação: Registro Dos Trabalhadores E Empresas Contratadas.',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '899f0c2f-d128-4f8b-8458-6551229c9285']},
#     'C5.4 - Despejo De Concreto Com Fck >= 25 Mpa Para Entrada De Carro E 20 Mpa Para Passeio',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '9447ffdb-fb73-455a-86e6-585969ae1737']},
#     'A1.4 - Controle De Vazamentos De Combustíveis, Lubrificantes E Águas Residuais De Concretagem',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '971b5a5a-47f6-4e7e-8b06-447622912c20']},
#     'C2.7 - Limpeza Da Via',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       '99789fef-24bb-4a40-9e47-9289f06850c2']},
#     'C3.4 - Espessura Da Capa Asfáltica - À Partir De 5Mm',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'a8b610cd-081b-4f04-8b9a-07c9d58941a6']},
#     'B2.5 - Veículos, Máquinas E Equipamentos',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'b5ce6cb2-86b8-48dd-896c-d856c434e461']},
#     'A2.4 - Destinação de restos vegetais não aproveitáveis',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'c41ff4ef-cab2-46cd-b054-00f7fa1b98ba']},
#     'B1.3 - Atendimento Às Solicitações/Notificação: Atende Ou Está Atendendo Solicitações?',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'c48e5550-3e60-4050-9f52-2e74d16f7eb8']},
#     "B2.2 - Epi'S E Uniformes",
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'c967aaee-8ae3-4fe9-865d-6dc9ef8dacfd']},
#     'C3.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'cc7ccd2e-5a5a-4661-907e-1b76030d491a']},
#     'A1.6 - Gerenciamento Dos Resíduos Sólidos, Segregação / Classificação',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'd8b22ace-5f8a-475d-aa87-5341c680a5af']},
#     'C3.3 - Pintura De Ligação - Aplicação E Tempo De Rompimento',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'd8e6c771-5d72-405f-8d20-8fb228eedfb3']},
#     'C5.3 - Espessura Correta Da Cancha - Entrada De Carro (10Cm) E Passeio (5 A 7Cm)',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'dd16ba8f-c127-4002-9de1-d60aae3eafe8']},
#     'C2.1 - Qualidade Do Material - Se Não Tiver Conforme Nem Executa O Serviço',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'e7379fa8-1550-4920-88c1-f5fb253e9acf']},
#     'C1.3 - Organização Do Material Reaproveitável Na Via',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'e7e92a41-5dba-4d9c-b7a0-0e57d485911e']},
#     'C1.1 - Cortes Retos/ Organização Do Poliedro Na Área De Serviços',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'e8144528-c4b0-44fe-8041-dcf69c2ca0ba']},
#     'A2.3 - Classificação E Aproveitamento De Restos Vegetais',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'e93c90d8-06e6-49fa-afba-953e6f547a39']},
#     'C3.5 - Temperatura Cbuq - De 140º A 180º',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'f1396ce9-12c8-4605-952e-76bef92ff663']},
#     'A1.5 - Gerenciamento De Recursos Hídricos',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'fa49dd4c-973a-41cd-9de7-e241e925b533']},
#     'B1.2 - Integração - Tem Treinamento De Integração De Saúde E Segurança Realizado Pela Caj?',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'fbd2472a-8eb5-4ce0-8621-fa4202a27ba5']},
#     'C3.7 - Recolhimento Imediato Do Material Descartado + Varrição',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'febc3531-3249-45ae-9e65-d1e205637ae4']},
#     'C5.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.3.occurrenceType'},
#       'ffca1af8-c87b-4eec-8b77-eb78caa49054']},
#     'A2.2 - Proteção Da Vegetação Do Entorno, Quando Necessário']}},
#  {'header': 'Inclusão de devolutivas - Classe 5',
#   'key': 'occurrenceType5',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '029fcd2f-998b-4d19-802c-325617478c27']},
#     'B2.3 - Sinalização',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '02ed6a53-21ef-42e0-b9a8-703520ff54db']},
#     'C3.3 - Integridade Das Peças',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '078a0011-43b8-4345-ad31-3a16b010d87b']},
#     'A1.1 - Controle Da Produção De Efluentes Contaminantes E Condições Sanitárias',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '11e22bda-19e1-45f5-afcd-6744acba229e']},
#     'B2.1 - Escoramento - Tem Projeto? Precisa Do Escoramento?',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '1361cb22-a6f2-4eae-a233-b91be422915f']},
#     'C2.6 - Espessura Das Camadas',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '15f5f0a0-2be3-4ab2-9584-87442096701f']},
#     'C3.6 - Viga De Travamento',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '1a0fa90c-1f50-4eb1-9f96-46436ed5af61']},
#     'C3.1 - Execução Da Base - Areia',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '2590028b-06cc-4e05-b798-664886cc081d']},
#     'C5.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '2ffd8525-a322-4d32-94a5-27e1189b70fe']},
#     'C2.4 - Umidade Do Material - Base E Sub-Base',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '32ae70a3-b61f-4880-9947-6b48c5a505d1']},
#     'B2.4 - Organização Do Canteiro/ Frente De Trabalho',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '32f1b304-e4f1-47f9-90e3-0376c53b6d9c']},
#     'C5.5 - Execução De Desenpeno',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '336680b3-d766-4964-b516-b72890b8729c']},
#     'C3.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '3567af75-c947-4d3b-9745-3b102ddfd211']},
#     'C2.3 - Adensamento Hidráulico',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '3738d871-64a1-4d63-a36c-4ee166a359ce']},
#     'C3.7 - Limpeza Do Trecho',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '38a8a156-173f-45ea-9a83-5004e272c36c']},
#     'A1.3 - Controle De Ruído E De Horários De Funcionamento',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '45904e96-32d7-444c-ab59-6f8a19139df4']},
#     'C3.5 - Aplicação De Placa Vibratória',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '572744b0-f742-4b72-905c-1e23836e776f']},
#     'C3.6 - Compactação + Placa Vibratória (Sem Água)',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '5c6054ac-2e07-4f8c-bfc7-5f347c844ee4']},
#     'C3.4 - Nivelamento Das Peças/Assentamento - Com Correto Espaçamento (2,5 A 5Mm) - Cfme Via',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '5db71040-4ba6-4547-b1f3-3085086cad7b']},
#     'A1.2 - Controle De Emissão De Poeira E Fumaça',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '6080f99c-f943-4872-9a50-e7d5a3234d88']},
#     'C1.2 - Destinação Correta De Material Descartado',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '63a33eac-495f-41e8-9435-b22d21cd95d7']},
#     'A2.1 - Marcação Prévia Dos Indivíduos A Serem Suprimidos',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '6cbb3f7c-474f-4700-aabf-d9a2eb233e2c']},
#     'C2.5 - Compactação - Número De Fechas',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '71668bc9-fb3d-405f-842c-56162c68c212']},
#     'C3.2 - Regularidade Da Superfície',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '7a6b87f9-8119-4dc6-a4ca-58bf88a3ff17']},
#     'C2.2 - Berço De Areia - Embasamento Dos Tubos',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '80211de7-4e39-4bc2-9bf5-5df3efca6257']},
#     'A3.1 - Reconhecimento De Vestígios Arqueológicos',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '86f3625f-0c73-458e-8ed1-627cc3edac03']},
#     'B1.1 - Documentação: Registro Dos Trabalhadores E Empresas Contratadas.',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '899f0c2f-d128-4f8b-8458-6551229c9285']},
#     'C5.4 - Despejo De Concreto Com Fck >= 25 Mpa Para Entrada De Carro E 20 Mpa Para Passeio',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '9447ffdb-fb73-455a-86e6-585969ae1737']},
#     'A1.4 - Controle De Vazamentos De Combustíveis, Lubrificantes E Águas Residuais De Concretagem',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '971b5a5a-47f6-4e7e-8b06-447622912c20']},
#     'C2.7 - Limpeza Da Via',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       '99789fef-24bb-4a40-9e47-9289f06850c2']},
#     'C3.4 - Espessura Da Capa Asfáltica - À Partir De 5Mm',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'a8b610cd-081b-4f04-8b9a-07c9d58941a6']},
#     'B2.5 - Veículos, Máquinas E Equipamentos',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'b5ce6cb2-86b8-48dd-896c-d856c434e461']},
#     'A2.4 - Destinação de restos vegetais não aproveitáveis',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'c41ff4ef-cab2-46cd-b054-00f7fa1b98ba']},
#     'B1.3 - Atendimento Às Solicitações/Notificação: Atende Ou Está Atendendo Solicitações?',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'c48e5550-3e60-4050-9f52-2e74d16f7eb8']},
#     "B2.2 - Epi'S E Uniformes",
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'c967aaee-8ae3-4fe9-865d-6dc9ef8dacfd']},
#     'C3.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'cc7ccd2e-5a5a-4661-907e-1b76030d491a']},
#     'A1.6 - Gerenciamento Dos Resíduos Sólidos, Segregação / Classificação',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'd8b22ace-5f8a-475d-aa87-5341c680a5af']},
#     'C3.3 - Pintura De Ligação - Aplicação E Tempo De Rompimento',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'd8e6c771-5d72-405f-8d20-8fb228eedfb3']},
#     'C5.3 - Espessura Correta Da Cancha - Entrada De Carro (10Cm) E Passeio (5 A 7Cm)',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'dd16ba8f-c127-4002-9de1-d60aae3eafe8']},
#     'C2.1 - Qualidade Do Material - Se Não Tiver Conforme Nem Executa O Serviço',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'e7379fa8-1550-4920-88c1-f5fb253e9acf']},
#     'C1.3 - Organização Do Material Reaproveitável Na Via',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'e7e92a41-5dba-4d9c-b7a0-0e57d485911e']},
#     'C1.1 - Cortes Retos/ Organização Do Poliedro Na Área De Serviços',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'e8144528-c4b0-44fe-8041-dcf69c2ca0ba']},
#     'A2.3 - Classificação E Aproveitamento De Restos Vegetais',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'e93c90d8-06e6-49fa-afba-953e6f547a39']},
#     'C3.5 - Temperatura Cbuq - De 140º A 180º',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'f1396ce9-12c8-4605-952e-76bef92ff663']},
#     'A1.5 - Gerenciamento De Recursos Hídricos',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'fa49dd4c-973a-41cd-9de7-e241e925b533']},
#     'B1.2 - Integração - Tem Treinamento De Integração De Saúde E Segurança Realizado Pela Caj?',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'fbd2472a-8eb5-4ce0-8621-fa4202a27ba5']},
#     'C3.7 - Recolhimento Imediato Do Material Descartado + Varrição',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'febc3531-3249-45ae-9e65-d1e205637ae4']},
#     'C5.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.4.occurrenceType'},
#       'ffca1af8-c87b-4eec-8b77-eb78caa49054']},
#     'A2.2 - Proteção Da Vegetação Do Entorno, Quando Necessário']}},
#  {'header': 'Inclusão de devolutivas - Classe 6',
#   'key': 'occurrenceType6',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '029fcd2f-998b-4d19-802c-325617478c27']},
#     'B2.3 - Sinalização',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '02ed6a53-21ef-42e0-b9a8-703520ff54db']},
#     'C3.3 - Integridade Das Peças',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '078a0011-43b8-4345-ad31-3a16b010d87b']},
#     'A1.1 - Controle Da Produção De Efluentes Contaminantes E Condições Sanitárias',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '11e22bda-19e1-45f5-afcd-6744acba229e']},
#     'B2.1 - Escoramento - Tem Projeto? Precisa Do Escoramento?',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '1361cb22-a6f2-4eae-a233-b91be422915f']},
#     'C2.6 - Espessura Das Camadas',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '15f5f0a0-2be3-4ab2-9584-87442096701f']},
#     'C3.6 - Viga De Travamento',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '1a0fa90c-1f50-4eb1-9f96-46436ed5af61']},
#     'C3.1 - Execução Da Base - Areia',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '2590028b-06cc-4e05-b798-664886cc081d']},
#     'C5.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '2ffd8525-a322-4d32-94a5-27e1189b70fe']},
#     'C2.4 - Umidade Do Material - Base E Sub-Base',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '32ae70a3-b61f-4880-9947-6b48c5a505d1']},
#     'B2.4 - Organização Do Canteiro/ Frente De Trabalho',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '32f1b304-e4f1-47f9-90e3-0376c53b6d9c']},
#     'C5.5 - Execução De Desenpeno',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '336680b3-d766-4964-b516-b72890b8729c']},
#     'C3.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '3567af75-c947-4d3b-9745-3b102ddfd211']},
#     'C2.3 - Adensamento Hidráulico',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '3738d871-64a1-4d63-a36c-4ee166a359ce']},
#     'C3.7 - Limpeza Do Trecho',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '38a8a156-173f-45ea-9a83-5004e272c36c']},
#     'A1.3 - Controle De Ruído E De Horários De Funcionamento',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '45904e96-32d7-444c-ab59-6f8a19139df4']},
#     'C3.5 - Aplicação De Placa Vibratória',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '572744b0-f742-4b72-905c-1e23836e776f']},
#     'C3.6 - Compactação + Placa Vibratória (Sem Água)',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '5c6054ac-2e07-4f8c-bfc7-5f347c844ee4']},
#     'C3.4 - Nivelamento Das Peças/Assentamento - Com Correto Espaçamento (2,5 A 5Mm) - Cfme Via',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '5db71040-4ba6-4547-b1f3-3085086cad7b']},
#     'A1.2 - Controle De Emissão De Poeira E Fumaça',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '6080f99c-f943-4872-9a50-e7d5a3234d88']},
#     'C1.2 - Destinação Correta De Material Descartado',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '63a33eac-495f-41e8-9435-b22d21cd95d7']},
#     'A2.1 - Marcação Prévia Dos Indivíduos A Serem Suprimidos',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '6cbb3f7c-474f-4700-aabf-d9a2eb233e2c']},
#     'C2.5 - Compactação - Número De Fechas',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '71668bc9-fb3d-405f-842c-56162c68c212']},
#     'C3.2 - Regularidade Da Superfície',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '7a6b87f9-8119-4dc6-a4ca-58bf88a3ff17']},
#     'C2.2 - Berço De Areia - Embasamento Dos Tubos',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '80211de7-4e39-4bc2-9bf5-5df3efca6257']},
#     'A3.1 - Reconhecimento De Vestígios Arqueológicos',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '86f3625f-0c73-458e-8ed1-627cc3edac03']},
#     'B1.1 - Documentação: Registro Dos Trabalhadores E Empresas Contratadas.',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '899f0c2f-d128-4f8b-8458-6551229c9285']},
#     'C5.4 - Despejo De Concreto Com Fck >= 25 Mpa Para Entrada De Carro E 20 Mpa Para Passeio',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '9447ffdb-fb73-455a-86e6-585969ae1737']},
#     'A1.4 - Controle De Vazamentos De Combustíveis, Lubrificantes E Águas Residuais De Concretagem',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '971b5a5a-47f6-4e7e-8b06-447622912c20']},
#     'C2.7 - Limpeza Da Via',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       '99789fef-24bb-4a40-9e47-9289f06850c2']},
#     'C3.4 - Espessura Da Capa Asfáltica - À Partir De 5Mm',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'a8b610cd-081b-4f04-8b9a-07c9d58941a6']},
#     'B2.5 - Veículos, Máquinas E Equipamentos',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'b5ce6cb2-86b8-48dd-896c-d856c434e461']},
#     'A2.4 - Destinação de restos vegetais não aproveitáveis',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'c41ff4ef-cab2-46cd-b054-00f7fa1b98ba']},
#     'B1.3 - Atendimento Às Solicitações/Notificação: Atende Ou Está Atendendo Solicitações?',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'c48e5550-3e60-4050-9f52-2e74d16f7eb8']},
#     "B2.2 - Epi'S E Uniformes",
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'c967aaee-8ae3-4fe9-865d-6dc9ef8dacfd']},
#     'C3.1 - Reenquadro - Cortes Com Ângulos Retos',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'cc7ccd2e-5a5a-4661-907e-1b76030d491a']},
#     'A1.6 - Gerenciamento Dos Resíduos Sólidos, Segregação / Classificação',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'd8b22ace-5f8a-475d-aa87-5341c680a5af']},
#     'C3.3 - Pintura De Ligação - Aplicação E Tempo De Rompimento',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'd8e6c771-5d72-405f-8d20-8fb228eedfb3']},
#     'C5.3 - Espessura Correta Da Cancha - Entrada De Carro (10Cm) E Passeio (5 A 7Cm)',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'dd16ba8f-c127-4002-9de1-d60aae3eafe8']},
#     'C2.1 - Qualidade Do Material - Se Não Tiver Conforme Nem Executa O Serviço',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'e7379fa8-1550-4920-88c1-f5fb253e9acf']},
#     'C1.3 - Organização Do Material Reaproveitável Na Via',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'e7e92a41-5dba-4d9c-b7a0-0e57d485911e']},
#     'C1.1 - Cortes Retos/ Organização Do Poliedro Na Área De Serviços',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'e8144528-c4b0-44fe-8041-dcf69c2ca0ba']},
#     'A2.3 - Classificação E Aproveitamento De Restos Vegetais',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'e93c90d8-06e6-49fa-afba-953e6f547a39']},
#     'C3.5 - Temperatura Cbuq - De 140º A 180º',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'f1396ce9-12c8-4605-952e-76bef92ff663']},
#     'A1.5 - Gerenciamento De Recursos Hídricos',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'fa49dd4c-973a-41cd-9de7-e241e925b533']},
#     'B1.2 - Integração - Tem Treinamento De Integração De Saúde E Segurança Realizado Pela Caj?',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'fbd2472a-8eb5-4ce0-8621-fa4202a27ba5']},
#     'C3.7 - Recolhimento Imediato Do Material Descartado + Varrição',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'febc3531-3249-45ae-9e65-d1e205637ae4']},
#     'C5.2 - Compactação E Nivelamento Da Superfície',
#     {'==': [{'var': 'formData.therapy.5.occurrenceType'},
#       'ffca1af8-c87b-4eec-8b77-eb78caa49054']},
#     'A2.2 - Proteção Da Vegetação Do Entorno, Quando Necessário']}},
#  {'header': 'Inclusão de devolutivas - Nota 1',
#   'key': 'checkTask1',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.0.checkTask'}, '1']},
#     '1 Não conforme - Elevado',
#     {'==': [{'var': 'formData.therapy.0.checkTask'}, '2']},
#     '2 Não conforme - Relevante',
#     {'==': [{'var': 'formData.therapy.0.checkTask'}, '3']},
#     '3 Não conforme - Moderado',
#     {'==': [{'var': 'formData.therapy.0.checkTask'}, '4']},
#     '4 Liberação especial - Baixo',
#     {'==': [{'var': 'formData.therapy.0.checkTask'}, '5']},
#     '5 Conforme',
#     {'==': [{'var': 'formData.therapy.0.checkTask'}, '6']},
#     'Não se aplica']}},
#  {'header': 'Inclusão de devolutivas - Nota 2',
#   'key': 'checkTask2',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.1.checkTask'}, '1']},
#     '1 Não conforme - Elevado',
#     {'==': [{'var': 'formData.therapy.1.checkTask'}, '2']},
#     '2 Não conforme - Relevante',
#     {'==': [{'var': 'formData.therapy.1.checkTask'}, '3']},
#     '3 Não conforme - Moderado',
#     {'==': [{'var': 'formData.therapy.1.checkTask'}, '4']},
#     '4 Liberação especial - Baixo',
#     {'==': [{'var': 'formData.therapy.1.checkTask'}, '5']},
#     '5 Conforme',
#     {'==': [{'var': 'formData.therapy.1.checkTask'}, '6']},
#     'Não se aplica']}},
#  {'header': 'Inclusão de devolutivas - Nota 3',
#   'key': 'checkTask3',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.2.checkTask'}, '1']},
#     '1 Não conforme - Elevado',
#     {'==': [{'var': 'formData.therapy.2.checkTask'}, '2']},
#     '2 Não conforme - Relevante',
#     {'==': [{'var': 'formData.therapy.2.checkTask'}, '3']},
#     '3 Não conforme - Moderado',
#     {'==': [{'var': 'formData.therapy.2.checkTask'}, '4']},
#     '4 Liberação especial - Baixo',
#     {'==': [{'var': 'formData.therapy.2.checkTask'}, '5']},
#     '5 Conforme',
#     {'==': [{'var': 'formData.therapy.2.checkTask'}, '6']},
#     'Não se aplica']}},
#  {'header': 'Inclusão de devolutivas - Nota 4',
#   'key': 'checkTask4',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.3.checkTask'}, '1']},
#     '1 Não conforme - Elevado',
#     {'==': [{'var': 'formData.therapy.3.checkTask'}, '2']},
#     '2 Não conforme - Relevante',
#     {'==': [{'var': 'formData.therapy.3.checkTask'}, '3']},
#     '3 Não conforme - Moderado',
#     {'==': [{'var': 'formData.therapy.3.checkTask'}, '4']},
#     '4 Liberação especial - Baixo',
#     {'==': [{'var': 'formData.therapy.3.checkTask'}, '5']},
#     '5 Conforme',
#     {'==': [{'var': 'formData.therapy.3.checkTask'}, '6']},
#     'Não se aplica']}},
#  {'header': 'Inclusão de devolutivas - Nota 5',
#   'key': 'checkTask5',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.4.checkTask'}, '1']},
#     '1 Não conforme - Elevado',
#     {'==': [{'var': 'formData.therapy.4.checkTask'}, '2']},
#     '2 Não conforme - Relevante',
#     {'==': [{'var': 'formData.therapy.4.checkTask'}, '3']},
#     '3 Não conforme - Moderado',
#     {'==': [{'var': 'formData.therapy.4.checkTask'}, '4']},
#     '4 Liberação especial - Baixo',
#     {'==': [{'var': 'formData.therapy.4.checkTask'}, '5']},
#     '5 Conforme',
#     {'==': [{'var': 'formData.therapy.4.checkTask'}, '6']},
#     'Não se aplica']}},
#  {'header': 'Inclusão de devolutivas - Nota 6',
#   'key': 'checkTask6',
#   'logic': {'if': [{'==': [{'var': 'formData.therapy.5.checkTask'}, '1']},
#     '1 Não conforme - Elevado',
#     {'==': [{'var': 'formData.therapy.5.checkTask'}, '2']},
#     '2 Não conforme - Relevante',
#     {'==': [{'var': 'formData.therapy.5.checkTask'}, '3']},
#     '3 Não conforme - Moderado',
#     {'==': [{'var': 'formData.therapy.5.checkTask'}, '4']},
#     '4 Liberação especial - Baixo',
#     {'==': [{'var': 'formData.therapy.5.checkTask'}, '5']},
#     '5 Conforme',
#     {'==': [{'var': 'formData.therapy.5.checkTask'}, '6']},
#     'Não se aplica']}},
#  {'header': 'Inclusão de devolutivas - Plano de ação 1',
#   'key': 'description1',
#   'logic': {'var': 'formData.therapy.0.description'}},
#  {'header': 'Inclusão de devolutivas - Plano de ação 2',
#   'key': 'description2',
#   'logic': {'var': 'formData.therapy.1.description'}},
#  {'header': 'Inclusão de devolutivas - Plano de ação 3',
#   'key': 'description3',
#   'logic': {'var': 'formData.therapy.2.description'}},
#  {'header': 'Inclusão de devolutivas - Plano de ação 4',
#   'key': 'description4',
#   'logic': {'var': 'formData.therapy.3.description'}},
#  {'header': 'Inclusão de devolutivas - Plano de ação 5',
#   'key': 'description5',
#   'logic': {'var': 'formData.therapy.4.description'}},
#  {'header': 'Inclusão de devolutivas - Plano de ação 6',
#   'key': 'description6',
#   'logic': {'var': 'formData.therapy.5.description'}}]

# %%
lista = [{"name":a['name'],"uuid":a['uuid_str']} for a in OccurrenceType.objects.filter(company=company,occurrence_kind=6).annotate(uuid_str=Cast("uuid",output_field=CharField())).values('name', 'uuid_str')]

# %%
lista
# Out:
# [{'name': 'B2.3 - Sinalização',
#   'uuid': '029fcd2f-998b-4d19-802c-325617478c27'},
#  {'name': 'C3.3 - Integridade Das Peças',
#   'uuid': '02ed6a53-21ef-42e0-b9a8-703520ff54db'},
#  {'name': 'A1.1 - Controle Da Produção De Efluentes Contaminantes E Condições Sanitárias',
#   'uuid': '078a0011-43b8-4345-ad31-3a16b010d87b'},
#  {'name': 'B2.1 - Escoramento - Tem Projeto? Precisa Do Escoramento?',
#   'uuid': '11e22bda-19e1-45f5-afcd-6744acba229e'},
#  {'name': 'C2.6 - Espessura Das Camadas',
#   'uuid': '1361cb22-a6f2-4eae-a233-b91be422915f'},
#  {'name': 'C3.6 - Viga De Travamento',
#   'uuid': '15f5f0a0-2be3-4ab2-9584-87442096701f'},
#  {'name': 'C3.1 - Execução Da Base - Areia',
#   'uuid': '1a0fa90c-1f50-4eb1-9f96-46436ed5af61'},
#  {'name': 'C5.1 - Reenquadro - Cortes Com Ângulos Retos',
#   'uuid': '2590028b-06cc-4e05-b798-664886cc081d'},
#  {'name': 'C2.4 - Umidade Do Material - Base E Sub-Base',
#   'uuid': '2ffd8525-a322-4d32-94a5-27e1189b70fe'},
#  {'name': 'B2.4 - Organização Do Canteiro/ Frente De Trabalho',
#   'uuid': '32ae70a3-b61f-4880-9947-6b48c5a505d1'},
#  {'name': 'C5.5 - Execução De Desenpeno',
#   'uuid': '32f1b304-e4f1-47f9-90e3-0376c53b6d9c'},
#  {'name': 'C3.2 - Compactação E Nivelamento Da Superfície',
#   'uuid': '336680b3-d766-4964-b516-b72890b8729c'},
#  {'name': 'C2.3 - Adensamento Hidráulico',
#   'uuid': '3567af75-c947-4d3b-9745-3b102ddfd211'},
#  {'name': 'C3.7 - Limpeza Do Trecho',
#   'uuid': '3738d871-64a1-4d63-a36c-4ee166a359ce'},
#  {'name': 'A1.3 - Controle De Ruído E De Horários De Funcionamento',
#   'uuid': '38a8a156-173f-45ea-9a83-5004e272c36c'},
#  {'name': 'C3.5 - Aplicação De Placa Vibratória',
#   'uuid': '45904e96-32d7-444c-ab59-6f8a19139df4'},
#  {'name': 'C3.6 - Compactação + Placa Vibratória (Sem Água)',
#   'uuid': '572744b0-f742-4b72-905c-1e23836e776f'},
#  {'name': 'C3.4 - Nivelamento Das Peças/Assentamento - Com Correto Espaçamento (2,5 A 5Mm) - Cfme Via',
#   'uuid': '5c6054ac-2e07-4f8c-bfc7-5f347c844ee4'},
#  {'name': 'A1.2 - Controle De Emissão De Poeira E Fumaça',
#   'uuid': '5db71040-4ba6-4547-b1f3-3085086cad7b'},
#  {'name': 'C1.2 - Destinação Correta De Material Descartado',
#   'uuid': '6080f99c-f943-4872-9a50-e7d5a3234d88'},
#  {'name': 'A2.1 - Marcação Prévia Dos Indivíduos A Serem Suprimidos',
#   'uuid': '63a33eac-495f-41e8-9435-b22d21cd95d7'},
#  {'name': 'C2.5 - Compactação - Número De Fechas',
#   'uuid': '6cbb3f7c-474f-4700-aabf-d9a2eb233e2c'},
#  {'name': 'C3.2 - Regularidade Da Superfície',
#   'uuid': '71668bc9-fb3d-405f-842c-56162c68c212'},
#  {'name': 'C2.2 - Berço De Areia - Embasamento Dos Tubos',
#   'uuid': '7a6b87f9-8119-4dc6-a4ca-58bf88a3ff17'},
#  {'name': 'A3.1 - Reconhecimento De Vestígios Arqueológicos',
#   'uuid': '80211de7-4e39-4bc2-9bf5-5df3efca6257'},
#  {'name': 'B1.1 - Documentação: Registro Dos Trabalhadores E Empresas Contratadas.',
#   'uuid': '86f3625f-0c73-458e-8ed1-627cc3edac03'},
#  {'name': 'C5.4 - Despejo De Concreto Com Fck >= 25 Mpa Para Entrada De Carro E 20 Mpa Para Passeio',
#   'uuid': '899f0c2f-d128-4f8b-8458-6551229c9285'},
#  {'name': 'A1.4 - Controle De Vazamentos De Combustíveis, Lubrificantes E Águas Residuais De Concretagem',
#   'uuid': '9447ffdb-fb73-455a-86e6-585969ae1737'},
#  {'name': 'C2.7 - Limpeza Da Via',
#   'uuid': '971b5a5a-47f6-4e7e-8b06-447622912c20'},
#  {'name': 'C3.4 - Espessura Da Capa Asfáltica - À Partir De 5Mm',
#   'uuid': '99789fef-24bb-4a40-9e47-9289f06850c2'},
#  {'name': 'B2.5 - Veículos, Máquinas E Equipamentos',
#   'uuid': 'a8b610cd-081b-4f04-8b9a-07c9d58941a6'},
#  {'name': 'A2.4 - Destinação de restos vegetais não aproveitáveis',
#   'uuid': 'b5ce6cb2-86b8-48dd-896c-d856c434e461'},
#  {'name': 'B1.3 - Atendimento Às Solicitações/Notificação: Atende Ou Está Atendendo Solicitações?',
#   'uuid': 'c41ff4ef-cab2-46cd-b054-00f7fa1b98ba'},
#  {'name': "B2.2 - Epi'S E Uniformes",
#   'uuid': 'c48e5550-3e60-4050-9f52-2e74d16f7eb8'},
#  {'name': 'C3.1 - Reenquadro - Cortes Com Ângulos Retos',
#   'uuid': 'c967aaee-8ae3-4fe9-865d-6dc9ef8dacfd'},
#  {'name': 'A1.6 - Gerenciamento Dos Resíduos Sólidos, Segregação / Classificação',
#   'uuid': 'cc7ccd2e-5a5a-4661-907e-1b76030d491a'},
#  {'name': 'C3.3 - Pintura De Ligação - Aplicação E Tempo De Rompimento',
#   'uuid': 'd8b22ace-5f8a-475d-aa87-5341c680a5af'},
#  {'name': 'C5.3 - Espessura Correta Da Cancha - Entrada De Carro (10Cm) E Passeio (5 A 7Cm)',
#   'uuid': 'd8e6c771-5d72-405f-8d20-8fb228eedfb3'},
#  {'name': 'C2.1 - Qualidade Do Material - Se Não Tiver Conforme Nem Executa O Serviço',
#   'uuid': 'dd16ba8f-c127-4002-9de1-d60aae3eafe8'},
#  {'name': 'C1.3 - Organização Do Material Reaproveitável Na Via',
#   'uuid': 'e7379fa8-1550-4920-88c1-f5fb253e9acf'},
#  {'name': 'C1.1 - Cortes Retos/ Organização Do Poliedro Na Área De Serviços',
#   'uuid': 'e7e92a41-5dba-4d9c-b7a0-0e57d485911e'},
#  {'name': 'A2.3 - Classificação E Aproveitamento De Restos Vegetais',
#   'uuid': 'e8144528-c4b0-44fe-8041-dcf69c2ca0ba'},
#  {'name': 'C3.5 - Temperatura Cbuq - De 140º A 180º',
#   'uuid': 'e93c90d8-06e6-49fa-afba-953e6f547a39'},
#  {'name': 'A1.5 - Gerenciamento De Recursos Hídricos',
#   'uuid': 'f1396ce9-12c8-4605-952e-76bef92ff663'},
#  {'name': 'B1.2 - Integração - Tem Treinamento De Integração De Saúde E Segurança Realizado Pela Caj?',
#   'uuid': 'fa49dd4c-973a-41cd-9de7-e241e925b533'},
#  {'name': 'C3.7 - Recolhimento Imediato Do Material Descartado + Varrição',
#   'uuid': 'fbd2472a-8eb5-4ce0-8621-fa4202a27ba5'},
#  {'name': 'C5.2 - Compactação E Nivelamento Da Superfície',
#   'uuid': 'febc3531-3249-45ae-9e65-d1e205637ae4'},
#  {'name': 'A2.2 - Proteção Da Vegetação Do Entorno, Quando Necessário',
#   'uuid': 'ffca1af8-c87b-4eec-8b77-eb78caa49054'}]

# %%
occ=[]
for a in Reporting.objects.filter(company=company):
    if a.name not in occ:
        occ.append(a.name)
    else:
        print(a.name)

# %%
for a in Reporting.objects.filter(company=company).values('occurrence_type__name').annotate(qtd_apt=Count('uuid')):
    print(a['occurrence_type__name'],a['qtd_apt'])
# Out:
# Desgaste 6
# Camada Rolamento - Cbuq - Grad. C. - Com Dop 177
# Fresagem 2248
# Escorregamento  ARTESP 1
# Trecho Rodoviário 3
# Panela 32
# Retrabalho 25
# Trinca Interligada "Bloco" 6
# Microrevestimento Asfaltico a Frio Com Polimero Sem Fibra 344
# Depressão 18
# Trinca Interligada "Jacaré" 27
# Sinalização Hor. Tinta P/Pouco Trafego (Sin. Provisoria) 2331
# Escorregamento ARTESP 1
# Afundamento Da Trilha Plástico 9
# Escorregamento 10
# Estrutural 315
# Ondulação Ou Corrugação 9
# Camada Rolamento - Cbuq - Grad. 3 - Com Dop 760
# Afundamento Local Plástico 7
# Concreto Asfaltico Modificado por Polimero - Grad. 3 3
# Trinca Interligada "Jacaré" ARTESP 1
# Desplacamento 2
# Imprimadura Betuminosa Ligante 934
# Revestimento 2
# Fresagem Continua de Pav. 253
# Fresagem Fina 3
# Reciclagem Capa/Base com Adição de 4% de Cimento 5
# Afundamento Local Consolidado 57
# Afundamento Da Trilha Consolidado 4
# Fresagem Continua de Pav., Imprimadura Betuminosa Ligante, Camada Rolamento - CBUQ - Grad. 3 - Com Dop 1
# Correção De Degrau 2
# Fresagem Descontinua de Pav. 562
# Microrevestimento 4

# %%
from tqdm.notebook import tqdm

# %%
for a in tqdm(Reporting.objects.filter(company=company).exclude(occurrence_type__name__in=['Fresagem','Desgaste','Estrutural'])):
    try:
        if len(a.form_data.get('service_dois')) >= 1:
            print(len(a.form_data.get('service_dois')),a.occurrence_type.name,a.number)
    except:
        pass
# Out:
#   0%|          | 0/5593 [00:00<?, ?it/s]
# 5 Afundamento Local Plástico EIXO-PAT-2023.00195

# %%
generate_select_export({
        "apiName": "lot",
        "dataType": "select",
        "displayName": "Lote",
        "selectOptions": {
          "options": [
            {
              "name": "Não se aplica",
              "value": "0"
            },
            {
              "name": "OBRA 1",
              "value": "1"
            },
            {
              "name": "OBRA 2",
              "value": "2"
            },
            {
              "name": "OBRA 3",
              "value": "3"
            },
            {
              "name": "OBRA 4",
              "value": "4"
            },
            {
              "name": "OBRA 5",
              "value": "5"
            },
            {
              "name": "OBRA 6",
              "value": "6"
            },
            {
              "name": "OBRA 7",
              "value": "7"
            },
            {
              "name": "OBRA 8",
              "value": "8"
            },
            {
              "name": "OBRA 9",
              "value": "9"
            },
            {
              "name": "OBRA 10",
              "value": "10"
            },
            {
              "name": "OBRA 11",
              "value": "11"
            },
            {
              "name": "OBRA 12",
              "value": "12"
            },
            {
              "name": "OBRA 13",
              "value": "13"
            },
            {
              "name": "OBRA 14",
              "value": "14"
            },
            {
              "name": "OBRA 15",
              "value": "15"
            },
            {
              "name": "OBRA 16",
              "value": "16"
            },
            {
              "name": "OBRA 17",
              "value": "17"
            },
            {
              "name": "OBRA 18",
              "value": "18"
            },
            {
              "name": "OBRA 19",
              "value": "19"
            },
            {
              "name": "OBRA 20",
              "value": "20"
            },
            {
              "name": "OBRA 21",
              "value": "21"
            },
            {
              "name": "OBRA 22",
              "value": "22"
            },
            {
              "name": "OBRA 23",
              "value": "23"
            },
            {
              "name": "OBRA 24",
              "value": "24"
            },
            {
              "name": "OBRA 25",
              "value": "25"
            },
            {
              "name": "OBRA 26",
              "value": "26"
            },
            {
              "name": "OBRA 27",
              "value": "27"
            },
            {
              "name": "OBRA 28",
              "value": "28"
            },
            {
              "name": "OBRA 29",
              "value": "29"
            },
            {
              "name": "OBRA 30",
              "value": "30"
            },
            {
              "name": "OBRA 31",
              "value": "31"
            },
            {
              "name": "OBRA 32",
              "value": "32"
            }
          ]
        }
      })
# Out:
# {'if': [{'==': [{'var': 'formData.lot'}, '0']},
#   'Não se aplica',
#   {'==': [{'var': 'formData.lot'}, '1']},
#   'OBRA 1',
#   {'==': [{'var': 'formData.lot'}, '2']},
#   'OBRA 2',
#   {'==': [{'var': 'formData.lot'}, '3']},
#   'OBRA 3',
#   {'==': [{'var': 'formData.lot'}, '4']},
#   'OBRA 4',
#   {'==': [{'var': 'formData.lot'}, '5']},
#   'OBRA 5',
#   {'==': [{'var': 'formData.lot'}, '6']},
#   'OBRA 6',
#   {'==': [{'var': 'formData.lot'}, '7']},
#   'OBRA 7',
#   {'==': [{'var': 'formData.lot'}, '8']},
#   'OBRA 8',
#   {'==': [{'var': 'formData.lot'}, '9']},
#   'OBRA 9',
#   {'==': [{'var': 'formData.lot'}, '10']},
#   'OBRA 10',
#   {'==': [{'var': 'formData.lot'}, '11']},
#   'OBRA 11',
#   {'==': [{'var': 'formData.lot'}, '12']},
#   'OBRA 12',
#   {'==': [{'var': 'formData.lot'}, '13']},
#   'OBRA 13',
#   {'==': [{'var': 'formData.lot'}, '14']},
#   'OBRA 14',
#   {'==': [{'var': 'formData.lot'}, '15']},
#   'OBRA 15',
#   {'==': [{'var': 'formData.lot'}, '16']},
#   'OBRA 16',
#   {'==': [{'var': 'formData.lot'}, '17']},
#   'OBRA 17',
#   {'==': [{'var': 'formData.lot'}, '18']},
#   'OBRA 18',
#   {'==': [{'var': 'formData.lot'}, '19']},
#   'OBRA 19',
#   {'==': [{'var': 'formData.lot'}, '20']},
#   'OBRA 20',
#   {'==': [{'var': 'formData.lot'}, '21']},
#   'OBRA 21',
#   {'==': [{'var': 'formData.lot'}, '22']},
#   'OBRA 22',
#   {'==': [{'var': 'formData.lot'}, '23']},
#   'OBRA 23',
#   {'==': [{'var': 'formData.lot'}, '24']},
#   'OBRA 24',
#   {'==': [{'var': 'formData.lot'}, '25']},
#   'OBRA 25',
#   {'==': [{'var': 'formData.lot'}, '26']},
#   'OBRA 26',
#   {'==': [{'var': 'formData.lot'}, '27']},
#   'OBRA 27',
#   {'==': [{'var': 'formData.lot'}, '28']},
#   'OBRA 28',
#   {'==': [{'var': 'formData.lot'}, '29']},
#   'OBRA 29',
#   {'==': [{'var': 'formData.lot'}, '30']},
#   'OBRA 30',
#   {'==': [{'var': 'formData.lot'}, '31']},
#   'OBRA 31',
#   {'==': [{'var': 'formData.lot'}, '32']},
#   'OBRA 32']}
