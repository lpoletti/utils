# %%
import requests
import json
def get_summary_forum():
    url = f"https://reports.api.clockify.me/v1/workspaces/{str('6388be0aa581104ca1897b5c')}/reports/detailed"
    headers = {'X-Api-Key': 'OGU0NDJjODctYjNiYi00MWNkLWEzYTUtYjYyYjAxZjZkNjRh'}
    data = {
        "dateRangeStart": "2023-05-10T00:00:00",
        "dateRangeEnd": "2023-12-13T23:59:59",
        "detailedFilter": {
            # "groups": ["PROJECT"],
            "sortColumn": "DATE",
            "userGroups": ['6501b600b6a5344b45809b41']
            },
        "exportType": "JSON"
        }

    return requests.post(url, headers=headers, json=data).json()

# %%
get_summary_forum()
# Out:
# {'totals': [{'totalTime': 5196186,
#    'totalBillableTime': 1278606,
#    'entriesCount': 745,
#    'amounts': [{'type': 'EARNED', 'value': 0.0, 'amountByCurrency': []}],
#    'numOfCurrencies': 1,
#    '_id': '',
#    'totalAmount': 0.0,
#    'totalAmountByCurrency': [{'currency': 'USD', 'amount': 0}]}],
#  'timeentries': [{'_id': '657a2d4296d78f36196a2fdf',
#    'description': 'Road 230/319 Pavicolet Amazonas',
#    'userId': '6501b7ef1ef33962ad5f7dfb',
#    'timeInterval': {'start': '2023-12-13T19:16:35-03:00',
#     'end': '2023-12-13T21:08:35-03:00',
#     'duration': 6720},
#    'billable': True,
#    'projectId': '654bcb79c7d5882517f1fce6',
#    'taskId': None,
#    'approvalRequestId': None,
#    'type': 'REGULAR',
#    'isLocked': False,
#    'userName': 'Luan Poletti',
#    'currency': 'USD',
#    'amount': 0.0,
#    'rate': None,
#    'userEmail': 'luan.poletti@kartado.com.br',
#    'projectName': 'Pavicolet',
#    'projectColor': '#673AB7',
# ...
