# %%
# !cat .env
# Out:
# STAGE=PRODUCTION

# %%
import json
from  tqdm.notebook import tqdm

# %% [markdown]
# # 1º CASO NÃO HOUVER CRIAR UM COMPANY_GROUP

# %%
company_group = CompanyGroup.objects.filter(name__icontains='engie').first()
company_group
# Out:
# <CompanyGroup: [cid] Engie>

# %% [markdown]
# # 2º CRIAR A COMPANY

# %%
company_name = 'Demo Energia'

# %%
custom_options=json.loads(json.dumps({
        "Firm": {
            "fields": {
                "canUseEcmIntegration": {
                    "displayIf": {
                        "logic": True
                    }
                }
            }
        },
        "User": {
            "fields": {
                "cpf": {
                    "displayIf": False
                },
                "phone": {
                    "displayIf": False
                },
                "firmName": {
                    "displayIf": False
                },
                "metadata": {
                    "role": {
                        "displayIf": {
                            "logic": True
                        }
                    },
                    "occupation": {
                        "displayIf": {
                            "logic": True
                        }
                    },
                    "boardRegistration": {
                        "displayIf": {
                            "logic": True
                        }
                    }
                },
                "birthDate": {
                    "displayIf": False
                },
                "isInternal": {
                    "displayIf": {
                        "logic": True
                    }
                },
                "samlNameid": {
                    "displayIf": {
                        "logic": True
                    }
                },
                "supervisor": {
                    "displayIf": {
                        "isInternal": [True]
                    }
                },
                "responsible": {
                    "displayIf": {
                        "isInternal": [False]
                    }
                }
            }
        },
        "contract": {
            "fields": {
                "extra_info": {
                    "additional_control": {
                        "apiName": "additional_control",
                        "dataType": "select",
                        "displayName": "Controle Adicional",
                        "selectOptions": {
                            "options": [{
                                "name": "Comunica\u00e7\u00e3o Socioambiental",
                                "value": "1"
                            }, {
                                "name": "Comunidades Ind\u00edgenas e/ou Outros Grupos \u00c9tnicos",
                                "value": "2"
                            }, {
                                "name": "Educa\u00e7\u00e3o Ambiental e Visitas \u00e0 Usina",
                                "value": "3"
                            }, {
                                "name": "Fundo de Desenvolvimento Regional",
                                "value": "4"
                            }, {
                                "name": "Patrim\u00f4nio Cultural, Hist\u00f3rico e Arqueol\u00f3gico",
                                "value": "5"
                            }, {
                                "name": "Recomposi\u00e7\u00e3o da Infra-Estrutura",
                                "value": "6"
                            }, {
                                "name": "Reloca\u00e7\u00e3o de Popula\u00e7\u00f5es Urbanas",
                                "value": "7"
                            }, {
                                "name": "Remanejamento da Popula\u00e7\u00e3o Rural",
                                "value": "8"
                            }, {
                                "name": "Reorganiza\u00e7\u00e3o das Atividades Econ\u00f4micas",
                                "value": "9"
                            }, {
                                "name": "Sa\u00fade da Popula\u00e7\u00e3o Afetada",
                                "value": "10"
                            }, {
                                "name": "Conserva\u00e7\u00e3o da Fauna Terrestre e Alada",
                                "value": "11"
                            }, {
                                "name": "Conserva\u00e7\u00e3o da Flora",
                                "value": "12"
                            }, {
                                "name": "Conserva\u00e7\u00e3o da Ictiofauna",
                                "value": "13"
                            }, {
                                "name": "Consolida\u00e7\u00e3o de \u00c1reas de Preserva\u00e7\u00e3o Permanente e Reserva Legal",
                                "value": "14"
                            }, {
                                "name": "Efluentes",
                                "value": "15"
                            }, {
                                "name": "Emiss\u00f5es Atmosf\u00e9ricas",
                                "value": "16"
                            }, {
                                "name": "Estabiliza\u00e7\u00e3o dos Taludes Marginais",
                                "value": "17"
                            }, {
                                "name": "Estudos de Dispers\u00e3o Atmosf\u00e9rica",
                                "value": "18"
                            }, {
                                "name": "Gerenciamento de Res\u00edduos",
                                "value": "19"
                            }, {
                                "name": "Horto Florestal e Viveiro de Produ\u00e7\u00e3o de Mudas",
                                "value": "20"
                            }, {
                                "name": "Limpeza da \u00c1rea dos Reservat\u00f3rios",
                                "value": "21"
                            }, {
                                "name": "Macr\u00f3fitas Aqu\u00e1ticas",
                                "value": "22"
                            }, {
                                "name": "Mexilh\u00e3o Dourado",
                                "value": "23"
                            }, {
                                "name": "Monitoramento das Condi\u00e7\u00f5es Climatol\u00f3gicas",
                                "value": "24"
                            }, {
                                "name": "Monitoramento das Condi\u00e7\u00f5es Hidrometeorol\u00f3gicas",
                                "value": "25"
                            }, {
                                "name": "Monitoramento das Condi\u00e7\u00f5es Hidrossedimentol\u00f3gicas",
                                "value": "26"
                            }, {
                                "name": "Monitoramento das Condi\u00e7\u00f5es Meteorol\u00f3gicas",
                                "value": "27"
                            }, {
                                "name": "Monitoramento das Condi\u00e7\u00f5es Sismol\u00f3gicas",
                                "value": "28"
                            }, {
                                "name": "Qualidade da \u00c1gua da Chuva",
                                "value": "29"
                            }, {
                                "name": "Qualidade das \u00c1guas Subterr\u00e2neas",
                                "value": "30"
                            }, {
                                "name": "Qualidade das \u00c1guas Superficiais",
                                "value": "31"
                            }, {
                                "name": "Qualidade do Ar",
                                "value": "32"
                            }, {
                                "name": "Qualidade do Solo",
                                "value": "33"
                            }, {
                                "name": "Recupera\u00e7\u00e3o de \u00c1reas Degradadas",
                                "value": "34"
                            }, {
                                "name": "Ru\u00eddos",
                                "value": "35"
                            }, {
                                "name": "Unidades de Conserva\u00e7\u00e3o",
                                "value": "36"
                            }, {
                                "name": "Uso, Ocupa\u00e7\u00e3o e Fiscaliza\u00e7\u00e3o Ambiental e Socio-Patrimonial do Entorno do Reservat\u00f3rio",
                                "value": "37"
                            }, {
                                "name": "Emerg\u00eancias Ambientais",
                                "value": "38"
                            }, {
                                "name": "Geoweb Ambiental (Sistema de Informa\u00e7\u00f5es Georreferenciadas)",
                                "value": "39"
                            }, {
                                "name": "Licenciamento Ambiental",
                                "value": "40"
                            }, {
                                "name": "MDL - Mecanismo de Desenvolvimento Limpo",
                                "value": "41"
                            }, {
                                "name": "Mudan\u00e7as Clim\u00e1ticas",
                                "value": "42"
                            }, {
                                "name": "Sistema de Gest\u00e3o Ambiental (NBR ISO 14.001)",
                                "value": "43"
                            }, {
                                "name": "Usos M\u00faltiplos do Reservat\u00f3rio",
                                "value": "44"
                            }, {
                                "name": "Servi\u00e7os Especiais e Extraordin\u00e1rios",
                                "value": "45"
                            }, {
                                "name": "Ingresso Imobiliza\u00e7\u00e3o em Curso",
                                "value": "46"
                            }, {
                                "name": "Baixas Imobiliza\u00e7\u00e3o em Curso - Ingressos de Exerc\u00edcios Anteriores - Meio Ambiente",
                                "value": "47"
                            }, {
                                "name": "Gest\u00e3o sociopatrimonial ",
                                "value": "48"
                            }]
                        }
                    }
                }
            }
        },
        "dashboard": {
            "fields": {
                "occurrenceKind": {
                    "apiName": "occurrenceKind",
                    "dataType": "select",
                    "displayName": "Natureza",
                    "selectOptions": {
                        "options": [{
                            "name": "Ocorr\u00eancia",
                            "value": "1"
                        }, {
                            "name": "Requisi\u00e7\u00e3o",
                            "value": "2"
                        }, {
                            "name": "Comunica\u00e7\u00e3o",
                            "value": "3"
                        }, {
                            "name": "Relat\u00f3rio",
                            "value": "4"
                        }, {
                            "name": "Vistoria",
                            "value": "5"
                        }, {
                            "name": "Condi\u00e7\u00f5es Extraordin\u00e1rias",
                            "value": "15"
                        }, {
                            "name": "Seguran\u00e7a do Trabalho",
                            "value": "17"
                        }]
                    }
                }
            }
        },
        "procedure": {
            "fields": {
                "responsibleAction": {
                    "apiName": "responsibleAction",
                    "dataType": "select",
                    "displayName": "Delega\u00e7\u00e3o para pr\u00f3xima a\u00e7\u00e3o",
                    "selectOptions": {
                        "options": [{
                            "name": "Respons\u00e1veis pelo Servi\u00e7o",
                            "value": "responsible"
                        }, {
                            "name": "Gestores de Entregas e Tarefas",
                            "value": "manager"
                        }, {
                            "name": "Equipes envolvidas nesse Servi\u00e7o",
                            "value": "serviceFirm"
                        }, {
                            "name": "Outras Equipes",
                            "value": "firm"
                        }]
                    }
                }
            }
        },
        "searchTag": {
            "fields": {
                "kind": {
                    "apiName": "kind",
                    "dataType": "select",
                    "displayName": "Natureza",
                    "selectOptions": {
                        "options": [{
                            "name": "Ambiental",
                            "value": 1
                        }, {
                            "name": "Humana e material",
                            "value": 2
                        }, {
                            "name": "Patrimonial",
                            "value": 3
                        }]
                    }
                },
                "type": {
                    "apiName": "type",
                    "dataType": "select",
                    "displayName": "Tipo",
                    "selectOptions": {
                        "options": [{
                            "name": "Geral",
                            "value": 1
                        }, {
                            "name": "Vistoria t\u00e9cnica",
                            "value": 2
                        }, {
                            "name": "Resumo executivo",
                            "value": 3
                        }, {
                            "name": "Visita t\u00e9cnica a parte interessada",
                            "value": 4
                        }, {
                            "name": "Di\u00e1logo com a sociedade",
                            "value": 5
                        }, {
                            "name": "Vistoria",
                            "value": 6
                        }, {
                            "name": "Verifica\u00e7\u00e3o de servi\u00e7os",
                            "value": 7
                        }, {
                            "name": "An\u00e1lise",
                            "value": 8
                        }]
                    }
                },
                "subject": {
                    "apiName": "subject",
                    "dataType": "select",
                    "displayName": "Assunto",
                    "selectOptions": {
                        "options": [{
                            "name": "Acidente em \u00c1rea Sob Gest\u00e3o do Empreendimento",
                            "value": 1
                        }, {
                            "name": "Dano em Cercas",
                            "value": 2
                        }, {
                            "name": "Deslizamento de Taludes Marginais",
                            "value": 3
                        }, {
                            "name": "Efeitos Erosivos",
                            "value": 4
                        }, {
                            "name": "Guia de Fornecimento de Mudas",
                            "value": 5
                        }, {
                            "name": "Inc\u00eandios Florestais",
                            "value": 6
                        }, {
                            "name": "Ocorr\u00eancia Envolvendo a Ictiofauna",
                            "value": 7
                        }, {
                            "name": "Ocorr\u00eancias Gerais [NOVO]",
                            "value": 8
                        }, {
                            "name": "Prolifera\u00e7\u00e3o de Macr\u00f3fitas Aqu\u00e1ticas",
                            "value": 9
                        }, {
                            "name": "Prolifera\u00e7\u00e3o de Plantas Aqu\u00e1ticas",
                            "value": 10
                        }, {
                            "name": "Requisi\u00e7\u00e3o administrativa",
                            "value": 11
                        }, {
                            "name": "Requisi\u00e7\u00e3o de Mudas",
                            "value": 12
                        }, {
                            "name": "Requisi\u00e7\u00e3o de vistoria",
                            "value": 13
                        }, {
                            "name": "Requisi\u00e7\u00e3o T\u00e9cnica",
                            "value": 14
                        }, {
                            "name": "Resgate de Fauna",
                            "value": 15
                        }, {
                            "name": "Reuni\u00e3o de equipes",
                            "value": 16
                        }, {
                            "name": "Uso e ocupa\u00e7\u00e3o irregular",
                            "value": 17
                        }, {
                            "name": "Verifica\u00e7\u00e3o de Conformidade do Servi\u00e7o Executado",
                            "value": 18
                        }, {
                            "name": "Vistoria Extraordin\u00e1ria",
                            "value": 19
                        }, {
                            "name": "Vistoria T\u00e9cnica",
                            "value": 20
                        }, {
                            "name": "Abalos s\u00edsmicos",
                            "value": 21
                        }, {
                            "name": "Abalroamento",
                            "value": 22
                        }, {
                            "name": "Acidente",
                            "value": 23
                        }, {
                            "name": "Acordo amig\u00e1vel",
                            "value": 24
                        }, {
                            "name": "Acordo judicial",
                            "value": 25
                        }, {
                            "name": "Afogamento",
                            "value": 26
                        }, {
                            "name": "\u00c1guas subterr\u00e2neas",
                            "value": 27
                        }, {
                            "name": "\u00c1guas superficiais",
                            "value": 28
                        }, {
                            "name": "Alagamentos",
                            "value": 29
                        }, {
                            "name": "Apoio \u00e0 popula\u00e7\u00e3o",
                            "value": 30
                        }, {
                            "name": "Aprisionamento",
                            "value": 31
                        }, {
                            "name": "Ca\u00e7a/pesca",
                            "value": 32
                        }, {
                            "name": "Climatologia",
                            "value": 33
                        }, {
                            "name": "Constru\u00e7\u00e3o e reparo de cercas",
                            "value": 34
                        }, {
                            "name": "Contamina\u00e7\u00e3o",
                            "value": 35
                        }, {
                            "name": "Deslizamento",
                            "value": 36
                        }, {
                            "name": "Despejo",
                            "value": 37
                        }, {
                            "name": "Efluentes",
                            "value": 38
                        }, {
                            "name": "Encalhe",
                            "value": 39
                        }, {
                            "name": "Engenharia Natural",
                            "value": 40
                        }, {
                            "name": "Eros\u00e3o",
                            "value": 41
                        }, {
                            "name": "Estiagem",
                            "value": 42
                        }, {
                            "name": "Fiscaliza\u00e7\u00e3o",
                            "value": 43
                        }, {
                            "name": "Hidrometeorologia",
                            "value": 44
                        }, {
                            "name": "Hidrossedimentologia",
                            "value": 45
                        }, {
                            "name": "Ictiofauna",
                            "value": 46
                        }, {
                            "name": "Inadimpl\u00eancia na permiss\u00e3o de uso",
                            "value": 47
                        }, {
                            "name": "Inc\u00eandio",
                            "value": 48
                        }, {
                            "name": "Macr\u00f3fitas aqu\u00e1ticas",
                            "value": 49
                        }, {
                            "name": "Naufr\u00e1gio",
                            "value": 50
                        }, {
                            "name": "Notifica\u00e7\u00e3o extrajudicial",
                            "value": 51
                        }, {
                            "name": "Outro",
                            "value": 52
                        }, {
                            "name": "Perecimento",
                            "value": 53
                        }, {
                            "name": "Potabilidade",
                            "value": 54
                        }, {
                            "name": "Prolifera\u00e7\u00e3o",
                            "value": 55
                        }, {
                            "name": "Recupera\u00e7\u00e3o de \u00e1reas",
                            "value": 56
                        }, {
                            "name": "Reintegra\u00e7\u00e3o de posse",
                            "value": 57
                        }, {
                            "name": "Sismologia",
                            "value": 58
                        }, {
                            "name": "Supress\u00e3o",
                            "value": 59
                        }, {
                            "name": "Taludes marginais",
                            "value": 60
                        }, {
                            "name": "Topografia",
                            "value": 61
                        }, {
                            "name": "Uso e ocupa\u00e7\u00e3o irregular",
                            "value": 62
                        }, {
                            "name": "Vandalismo",
                            "value": 63
                        }, {
                            "name": "Vazamento",
                            "value": 64
                        }]
                    }
                },
                "register": {
                    "apiName": "register",
                    "dataType": "select",
                    "displayName": "Registro",
                    "selectOptions": {
                        "options": [{
                            "name": "Ocorr\u00eancia",
                            "value": 1
                        }, {
                            "name": "Comunica\u00e7\u00e3o",
                            "value": 2
                        }, {
                            "name": "Requisi\u00e7\u00e3o",
                            "value": 3
                        }, {
                            "name": "Relat\u00f3rio",
                            "value": 4
                        }]
                    }
                }
            }
        },
        "canvasList": {
            "fields": {
                "kind": {
                    "apiName": "kind",
                    "dataType": "select",
                    "displayName": "Tipo",
                    "selectOptions": {
                        "options": [{
                            "name": "Lista Edit\u00e1vel",
                            "value": "EditableList"
                        }, {
                            "name": "Lista de Equipes",
                            "value": "FirmList"
                        }, {
                            "name": "Lista Detalhada",
                            "value": "DetailedList"
                        }, {
                            "name": "Lista de Entregas",
                            "value": "ActionList"
                        }]
                    }
                }
            }
        },
        "watchPoint": {
            "fields": {
                "river": {
                    "displayIf": {
                        "placeOnDam": ["1", "2"]
                    }
                },
                "placeOnDam": {
                    "apiName": "placeOnDam",
                    "dataType": "select",
                    "displayName": "Local",
                    "selectOptions": {
                        "options": [{
                            "name": "Reservat\u00f3rio",
                            "value": "1"
                        }, {
                            "name": "Jusante",
                            "value": "2"
                        }, {
                            "name": "Montante",
                            "value": "3"
                        }, {
                            "name": "\u00c1rea Industrial",
                            "value": "4"
                        }, {
                            "name": "\u00c1rea circunvizinha",
                            "value": "5"
                        }, {
                            "name": "\u00c1rea de preserva\u00e7\u00e3o permanente",
                            "value": "6"
                        }, {
                            "name": "\u00c1rea Remanescente",
                            "value": "7"
                        }, {
                            "name": "\u00c1rea de terceiros",
                            "value": "8"
                        }, {
                            "name": "Faixa de Oscila\u00e7\u00e3o",
                            "value": "9"
                        }, {
                            "name": "Casa de M\u00e1quinas",
                            "value": "10"
                        }, {
                            "name": "Canal de Fuga",
                            "value": "11"
                        }, {
                            "name": "Canal de Adu\u00e7\u00e3o",
                            "value": "12"
                        }, {
                            "name": "Tomada d'\u00c1gua",
                            "value": "13"
                        }, {
                            "name": "Vertedouro",
                            "value": "14"
                        }, {
                            "name": "Log Boom",
                            "value": "15"
                        }, {
                            "name": "Bacia de Dissipa\u00e7\u00e3o",
                            "value": "16"
                        }, {
                            "name": "Canteiro de Obra",
                            "value": "17"
                        }, {
                            "name": "Lagoas Marginais",
                            "value": "18"
                        }]
                    }
                }
            }
        },
        "materialItem": {
            "fields": {
                "provider": {
                    "apiName": "provider",
                    "dataType": "select",
                    "displayName": "Desembolso",
                    "selectOptions": {
                        "options": [{
                            "name": "Engie",
                            "value": "1"
                        }, {
                            "name": "Cons\u00f3rcio",
                            "value": "2"
                        }]
                    }
                },
                "resourceKind": {
                    "apiName": "resourceKind",
                    "dataType": "select",
                    "displayName": "Natureza",
                    "selectOptions": {
                        "options": [{
                            "name": "Servi\u00e7o Intelectual",
                            "value": "1"
                        }, {
                            "name": "Servi\u00e7o com Aplica\u00e7\u00e3o de Material",
                            "value": "2"
                        }, {
                            "name": "Servi\u00e7o sem Aplica\u00e7\u00e3o de Material",
                            "value": "3"
                        }, {
                            "name": "Material com Aplica\u00e7\u00e3o Direta",
                            "value": "4"
                        }, {
                            "name": "Reposi\u00e7\u00e3o de Estoque",
                            "value": "5"
                        }]
                    }
                }
            }
        },
        "serviceOrder": {
            "fields": {
                "kind": {
                    "apiName": "kind",
                    "dataType": "select",
                    "displayName": "Tipo",
                    "selectOptions": {
                        "options": [{
                            "name": "Patrimonial",
                            "value": "LAND"
                        }, {
                            "name": "Ambiental",
                            "value": "ENVIRONMENT"
                        }]
                    }
                },
                "priority": {
                    "trend": {
                        "apiName": "trend",
                        "dataType": "select",
                        "displayName": "Tend\u00eancia",
                        "selectOptions": {
                            "options": [{
                                "name": "Ir\u00e1 piorar rapidamente",
                                "value": "5"
                            }, {
                                "name": "Ir\u00e1 piorar a curto prazo",
                                "value": "4"
                            }, {
                                "name": "Ir\u00e1 piorar a m\u00e9dio prazo",
                                "value": "3"
                            }, {
                                "name": "Ir\u00e1 piorar a longo prazo",
                                "value": "2"
                            }, {
                                "name": "N\u00e3o ir\u00e1 mudar",
                                "value": "1"
                            }]
                        }
                    },
                    "urgency": {
                        "apiName": "urgency",
                        "dataType": "select",
                        "displayName": "Urg\u00eancia",
                        "selectOptions": {
                            "options": [{
                                "name": "Precisa de a\u00e7\u00e3o imediata",
                                "value": "5"
                            }, {
                                "name": "Muito urgente",
                                "value": "4"
                            }, {
                                "name": "Urgente, merece aten\u00e7\u00e3o no curto prazo",
                                "value": "3"
                            }, {
                                "name": "Pouco urgente",
                                "value": "2"
                            }, {
                                "name": "Pode esperar",
                                "value": "1"
                            }]
                        }
                    },
                    "seriousness": {
                        "apiName": "seriousness",
                        "dataType": "select",
                        "displayName": "Gravidade",
                        "selectOptions": {
                            "options": [{
                                "name": "Extremamente grave",
                                "value": "5"
                            }, {
                                "name": "Muito grave",
                                "value": "4"
                            }, {
                                "name": "Grave",
                                "value": "3"
                            }, {
                                "name": "Pouco grave",
                                "value": "2"
                            }, {
                                "name": "Sem gravidade",
                                "value": "1"
                            }]
                        }
                    }
                },
                "process_type": {
                    "apiName": "processType",
                    "dataType": "select",
                    "displayName": "Processo",
                    "selectOptions": {
                        "options": [{
                            "name": "Corre\u00e7\u00e3o de uso e ocupa\u00e7\u00e3o",
                            "value": "1",
                            "displayIf": {
                                "kind": ["LAND"]
                            }
                        }, {
                            "name": "Regulariza\u00e7\u00e3o Fundi\u00e1ria",
                            "value": "2",
                            "displayIf": {
                                "kind": ["LAND"]
                            }
                        }, {
                            "name": "Servi\u00e7os ambientais",
                            "value": "3",
                            "displayIf": {
                                "kind": ["ENVIRONMENT"]
                            }
                        }, {
                            "name": "Outros",
                            "value": "4",
                            "displayIf": {
                                "kind": ["LAND", "ENVIRONMENT"]
                            }
                        }]
                    }
                },
                "occurrenceKind": {
                    "apiName": "occurrenceKind",
                    "dataType": "select",
                    "displayName": "Natureza",
                    "selectOptions": {
                        "options": [{
                            "name": "Ocorr\u00eancia",
                            "value": "1"
                        }, {
                            "name": "Requisi\u00e7\u00e3o",
                            "value": "2"
                        }, {
                            "name": "Comunica\u00e7\u00e3o",
                            "value": "3"
                        }, {
                            "name": "Relat\u00f3rio",
                            "value": "4"
                        }, {
                            "name": "Vistoria",
                            "value": "5"
                        }, {
                            "name": "Condi\u00e7\u00f5es Extraordin\u00e1rias",
                            "value": "15"
                        }, {
                            "name": "Controles Operacionais",
                            "value": "16"
                        }, {
                            "name": "Seguran\u00e7a do Trabalho",
                            "value": "17"
                        }]
                    }
                }
            }
        },
        "actionResource": {
            "fields": {
                "provider": {
                    "apiName": "provider",
                    "dataType": "select",
                    "displayName": "Desembolso",
                    "selectOptions": {
                        "options": [{
                            "name": "Engie",
                            "value": "1"
                        }, {
                            "name": "Cons\u00f3rcio",
                            "value": "2"
                        }]
                    }
                },
                "resource": {
                    "disableIf": {
                        "resourceKind": ["1", "2", "3"]
                    }
                },
                "resourceKind": {
                    "apiName": "resourceKind",
                    "dataType": "select",
                    "displayName": "Natureza",
                    "selectOptions": {
                        "options": [{
                            "name": "Servi\u00e7o Intelectual",
                            "value": "1"
                        }, {
                            "name": "Servi\u00e7o com Aplica\u00e7\u00e3o de Material",
                            "value": "2"
                        }, {
                            "name": "Servi\u00e7o sem Aplica\u00e7\u00e3o de Material",
                            "value": "3"
                        }, {
                            "name": "Material com Aplica\u00e7\u00e3o Direta",
                            "value": "4"
                        }, {
                            "name": "Reposi\u00e7\u00e3o de Estoque",
                            "value": "5"
                        }]
                    }
                },
                "additional_control": {
                    "apiName": "additional_control",
                    "dataType": "select",
                    "displayName": "Controle Adicional",
                    "selectOptions": {
                        "options": [{
                            "name": "Comunica\u00e7\u00e3o Socioambiental",
                            "value": "1"
                        }, {
                            "name": "Comunidades Ind\u00edgenas e/ou Outros Grupos \u00c9tnicos",
                            "value": "2"
                        }, {
                            "name": "Educa\u00e7\u00e3o Ambiental e Visitas \u00e0 Usina",
                            "value": "3"
                        }, {
                            "name": "Fundo de Desenvolvimento Regional",
                            "value": "4"
                        }, {
                            "name": "Patrim\u00f4nio Cultural, Hist\u00f3rico e Arqueol\u00f3gico",
                            "value": "5"
                        }, {
                            "name": "Recomposi\u00e7\u00e3o da Infra-Estrutura",
                            "value": "6"
                        }, {
                            "name": "Reloca\u00e7\u00e3o de Popula\u00e7\u00f5es Urbanas",
                            "value": "7"
                        }, {
                            "name": "Remanejamento da Popula\u00e7\u00e3o Rural",
                            "value": "8"
                        }, {
                            "name": "Reorganiza\u00e7\u00e3o das Atividades Econ\u00f4micas",
                            "value": "9"
                        }, {
                            "name": "Sa\u00fade da Popula\u00e7\u00e3o Afetada",
                            "value": "10"
                        }, {
                            "name": "Conserva\u00e7\u00e3o da Fauna Terrestre e Alada",
                            "value": "11"
                        }, {
                            "name": "Conserva\u00e7\u00e3o da Flora",
                            "value": "12"
                        }, {
                            "name": "Conserva\u00e7\u00e3o da Ictiofauna",
                            "value": "13"
                        }, {
                            "name": "Consolida\u00e7\u00e3o de \u00c1reas de Preserva\u00e7\u00e3o Permanente e Reserva Legal",
                            "value": "14"
                        }, {
                            "name": "Efluentes",
                            "value": "15"
                        }, {
                            "name": "Emiss\u00f5es Atmosf\u00e9ricas",
                            "value": "16"
                        }, {
                            "name": "Estabiliza\u00e7\u00e3o dos Taludes Marginais",
                            "value": "17"
                        }, {
                            "name": "Estudos de Dispers\u00e3o Atmosf\u00e9rica",
                            "value": "18"
                        }, {
                            "name": "Gerenciamento de Res\u00edduos",
                            "value": "19"
                        }, {
                            "name": "Horto Florestal e Viveiro de Produ\u00e7\u00e3o de Mudas",
                            "value": "20"
                        }, {
                            "name": "Limpeza da \u00c1rea dos Reservat\u00f3rios",
                            "value": "21"
                        }, {
                            "name": "Macr\u00f3fitas Aqu\u00e1ticas",
                            "value": "22"
                        }, {
                            "name": "Mexilh\u00e3o Dourado",
                            "value": "23"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Climatol\u00f3gicas",
                            "value": "24"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Hidrometeorol\u00f3gicas",
                            "value": "25"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Hidrossedimentol\u00f3gicas",
                            "value": "26"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Meteorol\u00f3gicas",
                            "value": "27"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Sismol\u00f3gicas",
                            "value": "28"
                        }, {
                            "name": "Qualidade da \u00c1gua da Chuva",
                            "value": "29"
                        }, {
                            "name": "Qualidade das \u00c1guas Subterr\u00e2neas",
                            "value": "30"
                        }, {
                            "name": "Qualidade das \u00c1guas Superficiais",
                            "value": "31"
                        }, {
                            "name": "Qualidade do Ar",
                            "value": "32"
                        }, {
                            "name": "Qualidade do Solo",
                            "value": "33"
                        }, {
                            "name": "Recupera\u00e7\u00e3o de \u00c1reas Degradadas",
                            "value": "34"
                        }, {
                            "name": "Ru\u00eddos",
                            "value": "35"
                        }, {
                            "name": "Unidades de Conserva\u00e7\u00e3o",
                            "value": "36"
                        }, {
                            "name": "Uso, Ocupa\u00e7\u00e3o e Fiscaliza\u00e7\u00e3o Ambiental e Socio-Patrimonial do Entorno do Reservat\u00f3rio",
                            "value": "37"
                        }, {
                            "name": "Emerg\u00eancias Ambientais",
                            "value": "38"
                        }, {
                            "name": "Geoweb Ambiental (Sistema de Informa\u00e7\u00f5es Georreferenciadas)",
                            "value": "39"
                        }, {
                            "name": "Licenciamento Ambiental",
                            "value": "40"
                        }, {
                            "name": "MDL - Mecanismo de Desenvolvimento Limpo",
                            "value": "41"
                        }, {
                            "name": "Mudan\u00e7as Clim\u00e1ticas",
                            "value": "42"
                        }, {
                            "name": "Sistema de Gest\u00e3o Ambiental (NBR ISO 14.001)",
                            "value": "43"
                        }, {
                            "name": "Usos M\u00faltiplos do Reservat\u00f3rio",
                            "value": "44"
                        }, {
                            "name": "Servi\u00e7os Especiais e Extraordin\u00e1rios",
                            "value": "45"
                        }, {
                            "name": "Ingresso Imobiliza\u00e7\u00e3o em Curso",
                            "value": "46"
                        }, {
                            "name": "Baixas Imobiliza\u00e7\u00e3o em Curso - Ingressos de Exerc\u00edcios Anteriores - Meio Ambiente",
                            "value": "47"
                        }, {
                            "name": "Gest\u00e3o sociopatrimonial ",
                            "value": "48"
                        }]
                    }
                },
                "exceptionalResourceButton": {
                    "displayIf": {
                        "resourceKind": ["1", "2", "3"]
                    }
                }
            }
        },
        "monitoringPlan": {
            "fields": {
                "specificity": {
                    "apiName": "specificity",
                    "dataType": "select",
                    "displayName": "Especificidade",
                    "selectOptions": {
                        "options": [{
                            "name": "AS - \u00c1guas Superfiais",
                            "value": "1"
                        }, {
                            "name": "IC - Ictiofauna",
                            "value": "2"
                        }, {
                            "name": "PO - Potabilidade",
                            "value": "3"
                        }, {
                            "name": "EF - Efuentes",
                            "value": "4"
                        }, {
                            "name": "RF - Restaura\u00e7\u00e3o florestal",
                            "value": "5"
                        }, {
                            "name": "FA - Fauna aqu\u00e1tica",
                            "value": "6"
                        }, {
                            "name": "FT - Fauna terrestre",
                            "value": "7"
                        }]
                    }
                }
            }
        },
        "occurrenceType": {
            "fields": {
                "occurrenceKind": {
                    "apiName": "occurrenceKind",
                    "dataType": "select",
                    "displayName": "Natureza",
                    "selectOptions": {
                        "options": [{
                            "name": "Ocorr\u00eancia",
                            "value": "1"
                        }, {
                            "name": "Requisi\u00e7\u00e3o",
                            "value": "2"
                        }, {
                            "name": "Comunica\u00e7\u00e3o",
                            "value": "3"
                        }, {
                            "name": "Relat\u00f3rio",
                            "value": "4"
                        }, {
                            "name": "Vistoria",
                            "value": "5"
                        }, {
                            "name": "Seguran\u00e7a do Trabalho",
                            "value": "17"
                        }]
                    }
                }
            }
        },
        "monitoringPoint": {
            "fields": {
                "zone": {
                    "apiName": "zone",
                    "dataType": "select",
                    "displayName": "Zona",
                    "selectOptions": {
                        "options": [{
                            "name": "N\u00e3o aplic\u00e1vel",
                            "value": "1"
                        }, {
                            "name": "Outra",
                            "value": "2"
                        }]
                    }
                },
                "depth": {
                    "apiName": "depth",
                    "dataType": "select",
                    "displayName": "Profundidade",
                    "selectOptions": {
                        "options": [{
                            "name": "Superf\u00edcie",
                            "value": "1"
                        }, {
                            "name": "Fundo",
                            "value": "2"
                        }, {
                            "name": "Meio",
                            "value": "3"
                        }]
                    }
                },
                "river": {
                    "displayIf": {
                        "placeOnDam": ["1", "2", "3"]
                    }
                },
                "segment": {
                    "apiName": "segment",
                    "dataType": "select",
                    "displayName": "Trecho",
                    "selectOptions": {
                        "options": [{
                            "name": "Inferior",
                            "value": "1"
                        }, {
                            "name": "M\u00e9dio",
                            "value": "2"
                        }, {
                            "name": "Superior",
                            "value": "3"
                        }, {
                            "name": "Outro",
                            "value": "4"
                        }]
                    }
                },
                "position": {
                    "apiName": "position",
                    "dataType": "select",
                    "displayName": "Posi\u00e7\u00e3o",
                    "selectOptions": {
                        "options": [{
                            "name": "Limn\u00e9tica ou Pel\u00e1gica",
                            "value": "1"
                        }, {
                            "name": "Outra",
                            "value": "2"
                        }]
                    }
                },
                "placeOnDam": {
                    "apiName": "placeOnDam",
                    "dataType": "select",
                    "displayName": "Local",
                    "selectOptions": {
                        "options": [{
                            "name": "Reservat\u00f3rio",
                            "value": "1"
                        }, {
                            "name": "Jusante",
                            "value": "2"
                        }, {
                            "name": "Montante",
                            "value": "3"
                        }, {
                            "name": "\u00c1rea Industrial",
                            "value": "4"
                        }, {
                            "name": "\u00c1rea circunvizinha",
                            "value": "5"
                        }, {
                            "name": "\u00c1rea de preserva\u00e7\u00e3o permanente",
                            "value": "6"
                        }, {
                            "name": "\u00c1rea Remanescente",
                            "value": "7"
                        }, {
                            "name": "\u00c1rea de terceiros",
                            "value": "8"
                        }, {
                            "name": "Faixa de Oscila\u00e7\u00e3o",
                            "value": "9"
                        }, {
                            "name": "Casa de M\u00e1quinas",
                            "value": "10"
                        }, {
                            "name": "Canal de Fuga",
                            "value": "11"
                        }, {
                            "name": "Canal de Adu\u00e7\u00e3o",
                            "value": "12"
                        }, {
                            "name": "Tomada d'\u00c1gua",
                            "value": "13"
                        }, {
                            "name": "Vertedouro",
                            "value": "14"
                        }, {
                            "name": "Log Boom",
                            "value": "15"
                        }, {
                            "name": "Bacia de Dissipa\u00e7\u00e3o",
                            "value": "16"
                        }, {
                            "name": "Canteiro de Obra",
                            "value": "17"
                        }, {
                            "name": "Lagoas Marginais",
                            "value": "18"
                        }]
                    }
                },
                "stratification": {
                    "apiName": "stratification",
                    "dataType": "select",
                    "displayName": "Estratifica\u00e7\u00e3o",
                    "selectOptions": {
                        "options": [{
                            "name": "Epil\u00edmnio",
                            "value": "1"
                        }, {
                            "name": "Outra",
                            "value": "2"
                        }]
                    }
                }
            }
        },
        "occurrenceRecord": {
            "fields": {
                "river": {
                    "displayIf": {
                        "placeOnDam": ["1", "2", "3"]
                    }
                },
                "origin": {
                    "apiName": "origin",
                    "dataType": "select",
                    "displayName": "Tipo da Comunica\u00e7\u00e3o",
                    "selectOptions": {
                        "options": [{
                            "name": "Agradecimento",
                            "value": "1",
                            "displayIf": {
                                "occurrenceKind": ["3"]
                            }
                        }, {
                            "name": "Den\u00fancia",
                            "value": "2"
                        }, {
                            "name": "Elogio",
                            "value": "3",
                            "displayIf": {
                                "occurrenceKind": ["3"]
                            }
                        }, {
                            "name": "Informa\u00e7\u00e3o",
                            "value": "4",
                            "displayIf": {
                                "occurrenceKind": ["3"]
                            }
                        }, {
                            "name": "Inspe\u00e7\u00e3o",
                            "value": "5"
                        }, {
                            "name": "Reclama\u00e7\u00e3o",
                            "value": "6",
                            "displayIf": {
                                "occurrenceKind": ["3"]
                            }
                        }, {
                            "name": "Solicita\u00e7\u00e3o",
                            "value": "7",
                            "displayIf": {
                                "occurrenceKind": ["1", "3"]
                            }
                        }]
                    }
                },
                "placeOnDam": {
                    "apiName": "placeOnDam",
                    "dataType": "select",
                    "displayName": "Local",
                    "selectOptions": {
                        "options": [{
                            "name": "Reservat\u00f3rio",
                            "value": "1"
                        }, {
                            "name": "Jusante",
                            "value": "2"
                        }, {
                            "name": "Montante",
                            "value": "3"
                        }, {
                            "name": "\u00c1rea Industrial",
                            "value": "4"
                        }, {
                            "name": "\u00c1rea circunvizinha",
                            "value": "5"
                        }, {
                            "name": "\u00c1rea de preserva\u00e7\u00e3o permanente",
                            "value": "6"
                        }, {
                            "name": "\u00c1rea Remanescente",
                            "value": "7"
                        }, {
                            "name": "\u00c1rea de terceiros",
                            "value": "8"
                        }, {
                            "name": "Faixa de Oscila\u00e7\u00e3o",
                            "value": "9"
                        }, {
                            "name": "Casa de M\u00e1quinas",
                            "value": "10"
                        }, {
                            "name": "Canal de Fuga",
                            "value": "11"
                        }, {
                            "name": "Canal de Adu\u00e7\u00e3o",
                            "value": "12"
                        }, {
                            "name": "Tomada d'\u00c1gua",
                            "value": "13"
                        }, {
                            "name": "Vertedouro",
                            "value": "14"
                        }, {
                            "name": "Log Boom",
                            "value": "15"
                        }, {
                            "name": "Bacia de Dissipa\u00e7\u00e3o",
                            "value": "16"
                        }, {
                            "name": "Canteiro de Obra",
                            "value": "17"
                        }, {
                            "name": "Lagoas Marginais",
                            "value": "18"
                        }]
                    }
                },
                "originMedia": {
                    "apiName": "originMedia",
                    "dataType": "select",
                    "displayIf": {
                        "origin": ["1", "2", "3", "4", "6", "7"]
                    },
                    "displayName": "Ve\u00edculo de Comunica\u00e7\u00e3o",
                    "selectOptions": {
                        "options": [{
                            "name": "Carta",
                            "value": "1"
                        }, {
                            "name": "E-mail",
                            "value": "2"
                        }, {
                            "name": "Fax",
                            "value": "3"
                        }, {
                            "name": "Internet",
                            "value": "4"
                        }, {
                            "name": "Jornal",
                            "value": "5"
                        }, {
                            "name": "Of\u00edcio",
                            "value": "6"
                        }, {
                            "name": "R\u00e1dio",
                            "value": "7"
                        }, {
                            "name": "Telefone",
                            "value": "8"
                        }, {
                            "name": "TV",
                            "value": "9"
                        }, {
                            "name": "Verbal",
                            "value": "10"
                        }]
                    }
                },
                "involvedParts": {
                    "apiName": "condition",
                    "dataType": "select",
                    "displayName": "Condi\u00e7\u00e3o da parte envolvida",
                    "selectOptions": {
                        "options": [{
                            "name": "Infrator(a)",
                            "value": "1"
                        }, {
                            "name": "Infrator(a) n\u00e3o identificado",
                            "value": "2"
                        }, {
                            "name": "Presta servi\u00e7os ao infrator",
                            "value": "3"
                        }, {
                            "name": "V\u00ednculo familiar com o infrator",
                            "value": "4"
                        }, {
                            "name": "Informante",
                            "value": "5"
                        }, {
                            "name": "V\u00edtima (acidente)",
                            "value": "6"
                        }, {
                            "name": "Denunciante",
                            "value": "7"
                        }, {
                            "name": "Inspetor",
                            "value": "8"
                        }, {
                            "name": "Solicitante",
                            "value": "9"
                        }, {
                            "name": "Preposto(a) T\u00e9cnico(a)",
                            "value": "10"
                        }, {
                            "name": "Encarregado(a) de Campo",
                            "value": "11"
                        }, {
                            "name": "Colaborador(a)",
                            "value": "12"
                        }, {
                            "name": "Estagi\u00e1rio(a)",
                            "value": "13"
                        }, {
                            "name": "Outro",
                            "value": "14"
                        }]
                    }
                },
                "occurrenceKind": {
                    "apiName": "occurrenceKind",
                    "dataType": "select",
                    "displayName": "Natureza",
                    "selectOptions": {
                        "options": [{
                            "name": "Ocorr\u00eancia",
                            "value": "1"
                        }, {
                            "name": "Requisi\u00e7\u00e3o",
                            "value": "2"
                        }, {
                            "name": "Comunica\u00e7\u00e3o",
                            "value": "3"
                        }, {
                            "name": "Relat\u00f3rio",
                            "value": "4"
                        }, {
                            "name": "Vistoria",
                            "value": "5"
                        }, {
                            "name": "Seguran\u00e7a do Trabalho",
                            "value": "17"
                        }]
                    }
                },
                "involvedPartsFields": [{
                    "id": 1,
                    "apiName": "name",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "Nome completo"
                }, {
                    "id": 2,
                    "apiName": "rg",
                    "dataType": "boolean",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "RG"
                }, {
                    "id": 3,
                    "apiName": "descriptionRg",
                    "dataType": "string",
                    "displayIf": {
                        "and": [{
                            "===": [{
                                "var": {
                                    "cat": ["data.rg"]
                                }
                            }, True]
                        }, {
                            "in": [{
                                    "var": "data.involvedParts"
                                },
                                ["1", "2", "3", "4", "5", "6"]
                            ]
                        }]
                    },
                    "displayName": "N\u00famero do RG"
                }, {
                    "id": 4,
                    "apiName": "cpf",
                    "dataType": "boolean",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "CPF"
                }, {
                    "id": 5,
                    "apiName": "descriptionCpf",
                    "dataType": "string",
                    "displayIf": {
                        "and": [{
                            "===": [{
                                "var": {
                                    "cat": ["data.cpf"]
                                }
                            }, True]
                        }, {
                            "in": [{
                                    "var": "data.involvedParts"
                                },
                                ["1", "2", "3", "4", "5", "6"]
                            ]
                        }]
                    },
                    "displayName": "N\u00famero do CPF"
                }, {
                    "id": 6,
                    "apiName": "phone",
                    "dataType": "boolean",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "Telefone"
                }, {
                    "id": 7,
                    "apiName": "descriptionPhone",
                    "dataType": "string",
                    "displayIf": {
                        "and": [{
                            "===": [{
                                "var": {
                                    "cat": ["data.phone"]
                                }
                            }, True]
                        }, {
                            "in": [{
                                    "var": "data.involvedParts"
                                },
                                ["1", "2", "3", "4", "5", "6"]
                            ]
                        }]
                    },
                    "displayName": "N\u00famero de Telefone"
                }, {
                    "id": 8,
                    "apiName": "email",
                    "dataType": "boolean",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "E-mail"
                }, {
                    "id": 9,
                    "apiName": "descriptionEmail",
                    "dataType": "string",
                    "displayIf": {
                        "and": [{
                            "===": [{
                                "var": {
                                    "cat": ["data.email"]
                                }
                            }, True]
                        }, {
                            "in": [{
                                    "var": "data.involvedParts"
                                },
                                ["1", "2", "3", "4", "5", "6"]
                            ]
                        }]
                    },
                    "displayName": "E-mail"
                }, {
                    "id": 10,
                    "apiName": "address",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "Logradouro"
                }, {
                    "id": 11,
                    "apiName": "addressNumber",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "N\u00famero"
                }, {
                    "id": 12,
                    "apiName": "district",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "Bairro"
                }, {
                    "id": 13,
                    "apiName": "addressAdditional",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "Complemento"
                }, {
                    "id": 14,
                    "apiName": "uf",
                    "dataType": "UF",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "UF"
                }, {
                    "id": 15,
                    "apiName": "city",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "Cidade"
                }, {
                    "id": 16,
                    "apiName": "cep",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["1", "2", "3", "4", "5", "6"]
                        ]
                    },
                    "displayName": "CEP"
                }, {
                    "id": 17,
                    "apiName": "name",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["7", "8", "9"]
                        ]
                    },
                    "displayName": "Nome"
                }, {
                    "id": 18,
                    "apiName": "phone",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["7", "8", "9"]
                        ]
                    },
                    "displayName": "Telefone"
                }, {
                    "id": 19,
                    "apiName": "cellphone",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["7", "8", "9"]
                        ]
                    },
                    "displayName": "Celular"
                }, {
                    "id": 20,
                    "apiName": "email",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["7", "8", "9"]
                        ]
                    },
                    "displayName": "E-mail"
                }, {
                    "id": 21,
                    "apiName": "qualification",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["7", "8", "9"]
                        ]
                    },
                    "displayName": "Qualifica\u00e7\u00e3o"
                }, {
                    "id": 22,
                    "apiName": "originMedia",
                    "dataType": "select",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["7", "8", "9"]
                        ]
                    },
                    "displayName": "Meio de Comunica\u00e7\u00e3o",
                    "selectOptions": {
                        "options": [{
                            "name": "Carta",
                            "value": "1"
                        }, {
                            "name": "E-mail",
                            "value": "2"
                        }, {
                            "name": "Fax",
                            "value": "3"
                        }, {
                            "name": "Internet",
                            "value": "4"
                        }, {
                            "name": "Jornal",
                            "value": "5"
                        }, {
                            "name": "Of\u00edcio",
                            "value": "6"
                        }, {
                            "name": "R\u00e1dio",
                            "value": "7"
                        }, {
                            "name": "Telefone",
                            "value": "8"
                        }, {
                            "name": "TV",
                            "value": "9"
                        }, {
                            "name": "Verbal",
                            "value": "10"
                        }]
                    }
                }, {
                    "id": 23,
                    "apiName": "name",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["10", "11", "12", "13", "14"]
                        ]
                    },
                    "displayName": "Nome completo"
                }, {
                    "id": 24,
                    "apiName": "company",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["10", "11", "12", "13", "14"]
                        ]
                    },
                    "displayName": "Empresa"
                }, {
                    "id": 25,
                    "apiName": "date",
                    "dataType": "timestamp",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["10", "11", "12", "13", "14"]
                        ]
                    },
                    "displayName": "Data"
                }, {
                    "id": 26,
                    "apiName": "assignment",
                    "dataType": "string",
                    "displayIf": {
                        "in": [{
                                "var": "data.involvedParts"
                            },
                            ["10", "11", "12", "13", "14"]
                        ]
                    },
                    "displayName": "Atribui\u00e7\u00e3o"
                }],
                "territorialAdministration": {
                    "apiName": "territorialAdministration",
                    "dataType": "select",
                    "displayName": "Administra\u00e7\u00e3o territorial",
                    "selectOptions": {
                        "options": [{
                            "name": "\u00c1rea fora dos limites de concess\u00e3o/empreendimento",
                            "value": "1"
                        }, {
                            "name": "\u00c1rea da concess\u00e3o",
                            "value": "2"
                        }, {
                            "name": "\u00c1rea sob gest\u00e3o do empreendimento/arrendamento",
                            "value": "3"
                        }]
                    }
                }
            },
            "groups": {
                "origin": {
                    "displayIf": {
                        "logic": {
                            "var": "formData.includeOrigin"
                        }
                    }
                },
                "informer": {
                    "displayIf": {
                        "origin": ["1", "2", "3", "4", "6", "7"]
                    }
                },
                "location": {
                    "displayIf": {
                        "occurrenceKind": ["1", "2", "3", "4", "5", "15", "16", "17"]
                    }
                },
                "hydrology": {
                    "displayIf": {
                        "logic": {
                            "var": "formData.includeHydrology"
                        }
                    }
                }
            }
        },
        "humanResourceItem": {
            "fields": {
                "provider": {
                    "apiName": "provider",
                    "dataType": "select",
                    "displayName": "Desembolso",
                    "selectOptions": {
                        "options": [{
                            "name": "Engie",
                            "value": "1"
                        }, {
                            "name": "Cons\u00f3rcio",
                            "value": "2"
                        }]
                    }
                },
                "resourceKind": {
                    "apiName": "resourceKind",
                    "dataType": "select",
                    "displayName": "Natureza",
                    "selectOptions": {
                        "options": [{
                            "name": "M\u00e3o de obra pr\u00f3pria",
                            "value": "1"
                        }, {
                            "name": "M\u00e3o de obra estagi\u00e1rio",
                            "value": "2"
                        }]
                    }
                },
                "additional_control": {
                    "apiName": "additional_control",
                    "dataType": "select",
                    "displayName": "Controle Adicional",
                    "selectOptions": {
                        "options": [{
                            "name": "Comunica\u00e7\u00e3o Socioambiental",
                            "value": "1"
                        }, {
                            "name": "Comunidades Ind\u00edgenas e/ou Outros Grupos \u00c9tnicos",
                            "value": "2"
                        }, {
                            "name": "Educa\u00e7\u00e3o Ambiental e Visitas \u00e0 Usina",
                            "value": "3"
                        }, {
                            "name": "Fundo de Desenvolvimento Regional",
                            "value": "4"
                        }, {
                            "name": "Patrim\u00f4nio Cultural, Hist\u00f3rico e Arqueol\u00f3gico",
                            "value": "5"
                        }, {
                            "name": "Recomposi\u00e7\u00e3o da Infra-Estrutura",
                            "value": "6"
                        }, {
                            "name": "Reloca\u00e7\u00e3o de Popula\u00e7\u00f5es Urbanas",
                            "value": "7"
                        }, {
                            "name": "Remanejamento da Popula\u00e7\u00e3o Rural",
                            "value": "8"
                        }, {
                            "name": "Reorganiza\u00e7\u00e3o das Atividades Econ\u00f4micas",
                            "value": "9"
                        }, {
                            "name": "Sa\u00fade da Popula\u00e7\u00e3o Afetada",
                            "value": "10"
                        }, {
                            "name": "Conserva\u00e7\u00e3o da Fauna Terrestre e Alada",
                            "value": "11"
                        }, {
                            "name": "Conserva\u00e7\u00e3o da Flora",
                            "value": "12"
                        }, {
                            "name": "Conserva\u00e7\u00e3o da Ictiofauna",
                            "value": "13"
                        }, {
                            "name": "Consolida\u00e7\u00e3o de \u00c1reas de Preserva\u00e7\u00e3o Permanente e Reserva Legal",
                            "value": "14"
                        }, {
                            "name": "Efluentes",
                            "value": "15"
                        }, {
                            "name": "Emiss\u00f5es Atmosf\u00e9ricas",
                            "value": "16"
                        }, {
                            "name": "Estabiliza\u00e7\u00e3o dos Taludes Marginais",
                            "value": "17"
                        }, {
                            "name": "Estudos de Dispers\u00e3o Atmosf\u00e9rica",
                            "value": "18"
                        }, {
                            "name": "Gerenciamento de Res\u00edduos",
                            "value": "19"
                        }, {
                            "name": "Horto Florestal e Viveiro de Produ\u00e7\u00e3o de Mudas",
                            "value": "20"
                        }, {
                            "name": "Limpeza da \u00c1rea dos Reservat\u00f3rios",
                            "value": "21"
                        }, {
                            "name": "Macr\u00f3fitas Aqu\u00e1ticas",
                            "value": "22"
                        }, {
                            "name": "Mexilh\u00e3o Dourado",
                            "value": "23"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Climatol\u00f3gicas",
                            "value": "24"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Hidrometeorol\u00f3gicas",
                            "value": "25"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Hidrossedimentol\u00f3gicas",
                            "value": "26"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Meteorol\u00f3gicas",
                            "value": "27"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Sismol\u00f3gicas",
                            "value": "28"
                        }, {
                            "name": "Qualidade da \u00c1gua da Chuva",
                            "value": "29"
                        }, {
                            "name": "Qualidade das \u00c1guas Subterr\u00e2neas",
                            "value": "30"
                        }, {
                            "name": "Qualidade das \u00c1guas Superficiais",
                            "value": "31"
                        }, {
                            "name": "Qualidade do Ar",
                            "value": "32"
                        }, {
                            "name": "Qualidade do Solo",
                            "value": "33"
                        }, {
                            "name": "Recupera\u00e7\u00e3o de \u00c1reas Degradadas",
                            "value": "34"
                        }, {
                            "name": "Ru\u00eddos",
                            "value": "35"
                        }, {
                            "name": "Unidades de Conserva\u00e7\u00e3o",
                            "value": "36"
                        }, {
                            "name": "Uso, Ocupa\u00e7\u00e3o e Fiscaliza\u00e7\u00e3o Ambiental e Socio-Patrimonial do Entorno do Reservat\u00f3rio",
                            "value": "37"
                        }, {
                            "name": "Emerg\u00eancias Ambientais",
                            "value": "38"
                        }, {
                            "name": "Geoweb Ambiental (Sistema de Informa\u00e7\u00f5es Georreferenciadas)",
                            "value": "39"
                        }, {
                            "name": "Licenciamento Ambiental",
                            "value": "40"
                        }, {
                            "name": "MDL - Mecanismo de Desenvolvimento Limpo",
                            "value": "41"
                        }, {
                            "name": "Mudan\u00e7as Clim\u00e1ticas",
                            "value": "42"
                        }, {
                            "name": "Sistema de Gest\u00e3o Ambiental (NBR ISO 14.001)",
                            "value": "43"
                        }, {
                            "name": "Usos M\u00faltiplos do Reservat\u00f3rio",
                            "value": "44"
                        }, {
                            "name": "Servi\u00e7os Especiais e Extraordin\u00e1rios",
                            "value": "45"
                        }, {
                            "name": "Ingresso Imobiliza\u00e7\u00e3o em Curso",
                            "value": "46"
                        }, {
                            "name": "Baixas Imobiliza\u00e7\u00e3o em Curso - Ingressos de Exerc\u00edcios Anteriores - Meio Ambiente",
                            "value": "47"
                        }, {
                            "name": "Gest\u00e3o sociopatrimonial ",
                            "value": "48"
                        }]
                    }
                }
            }
        },
        "additionalDocument": {
            "fields": {
                "river": {
                    "displayIf": {
                        "placeOnDam": ["1", "2", "3"]
                    }
                },
                "origin": {
                    "apiName": "origin",
                    "dataType": "select",
                    "displayName": "Tipo da Comunica\u00e7\u00e3o",
                    "selectOptions": {
                        "options": [{
                            "name": "Agradecimento",
                            "value": "1",
                            "displayIf": {
                                "occurrenceKind": ["3"]
                            }
                        }, {
                            "name": "Den\u00fancia",
                            "value": "2"
                        }, {
                            "name": "Elogio",
                            "value": "3",
                            "displayIf": {
                                "occurrenceKind": ["3"]
                            }
                        }, {
                            "name": "Informa\u00e7\u00e3o",
                            "value": "4",
                            "displayIf": {
                                "occurrenceKind": ["3"]
                            }
                        }, {
                            "name": "Inspe\u00e7\u00e3o",
                            "value": "5"
                        }, {
                            "name": "Reclama\u00e7\u00e3o",
                            "value": "6",
                            "displayIf": {
                                "occurrenceKind": ["3"]
                            }
                        }, {
                            "name": "Solicita\u00e7\u00e3o",
                            "value": "7",
                            "displayIf": {
                                "occurrenceKind": ["1", "3"]
                            }
                        }]
                    }
                },
                "placeOnDam": {
                    "apiName": "placeOnDam",
                    "dataType": "select",
                    "displayName": "Local",
                    "selectOptions": {
                        "options": [{
                            "name": "Reservat\u00f3rio",
                            "value": "1"
                        }, {
                            "name": "Jusante",
                            "value": "2"
                        }, {
                            "name": "Montante",
                            "value": "3"
                        }, {
                            "name": "\u00c1rea Industrial",
                            "value": "4"
                        }, {
                            "name": "\u00c1rea circunvizinha",
                            "value": "5"
                        }, {
                            "name": "\u00c1rea de preserva\u00e7\u00e3o permanente",
                            "value": "6"
                        }, {
                            "name": "\u00c1rea Remanescente",
                            "value": "7"
                        }, {
                            "name": "\u00c1rea de terceiros",
                            "value": "8"
                        }, {
                            "name": "Faixa de Oscila\u00e7\u00e3o",
                            "value": "9"
                        }, {
                            "name": "Casa de M\u00e1quinas",
                            "value": "10"
                        }, {
                            "name": "Canal de Fuga",
                            "value": "11"
                        }, {
                            "name": "Canal de Adu\u00e7\u00e3o",
                            "value": "12"
                        }, {
                            "name": "Tomada d'\u00c1gua",
                            "value": "13"
                        }, {
                            "name": "Vertedouro",
                            "value": "14"
                        }, {
                            "name": "Log Boom",
                            "value": "15"
                        }, {
                            "name": "Bacia de Dissipa\u00e7\u00e3o",
                            "value": "16"
                        }, {
                            "name": "Canteiro de Obra",
                            "value": "17"
                        }, {
                            "name": "Lagoas Marginais",
                            "value": "18"
                        }]
                    }
                },
                "originMedia": {
                    "apiName": "originMedia",
                    "dataType": "select",
                    "displayIf": {
                        "origin": ["1", "2", "3", "4", "6", "7"]
                    },
                    "displayName": "Ve\u00edculo de Comunica\u00e7\u00e3o",
                    "selectOptions": {
                        "options": [{
                            "name": "Carta",
                            "value": "1"
                        }, {
                            "name": "E-mail",
                            "value": "2"
                        }, {
                            "name": "Fax",
                            "value": "3"
                        }, {
                            "name": "Internet",
                            "value": "4"
                        }, {
                            "name": "Jornal",
                            "value": "5"
                        }, {
                            "name": "Of\u00edcio",
                            "value": "6"
                        }, {
                            "name": "R\u00e1dio",
                            "value": "7"
                        }, {
                            "name": "Telefone",
                            "value": "8"
                        }, {
                            "name": "TV",
                            "value": "9"
                        }, {
                            "name": "Verbal",
                            "value": "10"
                        }]
                    }
                },
                "occurrenceKind": {
                    "apiName": "occurrenceKind",
                    "dataType": "select",
                    "displayName": "Natureza",
                    "selectOptions": {
                        "options": [{
                            "name": "Ocorr\u00eancia",
                            "value": "1"
                        }, {
                            "name": "Requisi\u00e7\u00e3o",
                            "value": "2"
                        }, {
                            "name": "Comunica\u00e7\u00e3o",
                            "value": "3"
                        }, {
                            "name": "Relat\u00f3rio",
                            "value": "4"
                        }, {
                            "name": "Vistoria",
                            "value": "5"
                        }, {
                            "name": "Condi\u00e7\u00f5es Extraordin\u00e1rias",
                            "value": "15"
                        }, {
                            "name": "Seguran\u00e7a do Trabalho",
                            "value": "17"
                        }]
                    }
                }
            },
            "groups": {
                "origin": {
                    "displayIf": {
                        "occurrenceKind": ["1"],
                        "relationships.occurrenceType.data.id": ["43db5fa5-db4b-4846-ae91-e17399328444", "41d4a42e-a146-4dfb-a64b-70d7223e1ac9"]
                    }
                },
                "informer": {
                    "displayIf": {
                        "origin": ["1", "2", "3", "4", "6", "7"]
                    }
                },
                "location": {
                    "displayIf": {
                        "occurrenceKind": ["1", "2", "3", "4", "5", "15", "16", "17"]
                    }
                },
                "hydrology": {
                    "displayIf": {
                        "logic": {
                            "var": "formData.includeHydrology"
                        }
                    }
                }
            }
        },
        "operationalControl": {
            "fields": {
                "kind": {
                    "apiName": "kind",
                    "dataType": "select",
                    "displayName": "Tipo",
                    "selectOptions": {
                        "options": [{
                            "name": "Horto Florestal",
                            "value": "701"
                        }, {
                            "name": "Seguran\u00e7a de Barragens",
                            "value": "702"
                        }, {
                            "name": "Hidr\u00f4metros",
                            "value": "703"
                        }, {
                            "name": "Res\u00edduos",
                            "value": "704"
                        }, {
                            "name": "Educa\u00e7\u00e3o ambiental",
                            "value": "705"
                        }, {
                            "name": "Programa de visitas",
                            "value": "706"
                        }, {
                            "name": "Cadastro de institui\u00e7\u00f5es e parceiros",
                            "value": "707"
                        }, {
                            "name": "Salvamento de fauna",
                            "value": "708"
                        }, {
                            "name": "Cadastro de esp\u00e9cies",
                            "value": "709"
                        }]
                    }
                }
            }
        },
        "serviceOrderResource": {
            "fields": {
                "provider": {
                    "apiName": "provider",
                    "dataType": "select",
                    "displayName": "Desembolso",
                    "selectOptions": {
                        "options": [{
                            "name": "Engie",
                            "value": "1"
                        }, {
                            "name": "Cons\u00f3rcio",
                            "value": "2"
                        }]
                    }
                },
                "resource": {
                    "disableIf": {
                        "resourceKind": ["1", "2", "3"]
                    }
                },
                "resourceKind": {
                    "apiName": "resourceKind",
                    "dataType": "select",
                    "displayName": "Natureza",
                    "selectOptions": {
                        "options": [{
                            "name": "Servi\u00e7o Intelectual",
                            "value": "1"
                        }, {
                            "name": "Servi\u00e7o com Aplica\u00e7\u00e3o de Material",
                            "value": "2"
                        }, {
                            "name": "Servi\u00e7o sem Aplica\u00e7\u00e3o de Material",
                            "value": "3"
                        }, {
                            "name": "Material com Aplica\u00e7\u00e3o Direta",
                            "value": "4"
                        }, {
                            "name": "Reposi\u00e7\u00e3o de Estoque",
                            "value": "5"
                        }]
                    }
                },
                "additional_control": {
                    "apiName": "additional_control",
                    "dataType": "select",
                    "displayName": "Controle Adicional",
                    "selectOptions": {
                        "options": [{
                            "name": "Comunica\u00e7\u00e3o Socioambiental",
                            "value": "1"
                        }, {
                            "name": "Comunidades Ind\u00edgenas e/ou Outros Grupos \u00c9tnicos",
                            "value": "2"
                        }, {
                            "name": "Educa\u00e7\u00e3o Ambiental e Visitas \u00e0 Usina",
                            "value": "3"
                        }, {
                            "name": "Fundo de Desenvolvimento Regional",
                            "value": "4"
                        }, {
                            "name": "Patrim\u00f4nio Cultural, Hist\u00f3rico e Arqueol\u00f3gico",
                            "value": "5"
                        }, {
                            "name": "Recomposi\u00e7\u00e3o da Infra-Estrutura",
                            "value": "6"
                        }, {
                            "name": "Reloca\u00e7\u00e3o de Popula\u00e7\u00f5es Urbanas",
                            "value": "7"
                        }, {
                            "name": "Remanejamento da Popula\u00e7\u00e3o Rural",
                            "value": "8"
                        }, {
                            "name": "Reorganiza\u00e7\u00e3o das Atividades Econ\u00f4micas",
                            "value": "9"
                        }, {
                            "name": "Sa\u00fade da Popula\u00e7\u00e3o Afetada",
                            "value": "10"
                        }, {
                            "name": "Conserva\u00e7\u00e3o da Fauna Terrestre e Alada",
                            "value": "11"
                        }, {
                            "name": "Conserva\u00e7\u00e3o da Flora",
                            "value": "12"
                        }, {
                            "name": "Conserva\u00e7\u00e3o da Ictiofauna",
                            "value": "13"
                        }, {
                            "name": "Consolida\u00e7\u00e3o de \u00c1reas de Preserva\u00e7\u00e3o Permanente e Reserva Legal",
                            "value": "14"
                        }, {
                            "name": "Efluentes",
                            "value": "15"
                        }, {
                            "name": "Emiss\u00f5es Atmosf\u00e9ricas",
                            "value": "16"
                        }, {
                            "name": "Estabiliza\u00e7\u00e3o dos Taludes Marginais",
                            "value": "17"
                        }, {
                            "name": "Estudos de Dispers\u00e3o Atmosf\u00e9rica",
                            "value": "18"
                        }, {
                            "name": "Gerenciamento de Res\u00edduos",
                            "value": "19"
                        }, {
                            "name": "Horto Florestal e Viveiro de Produ\u00e7\u00e3o de Mudas",
                            "value": "20"
                        }, {
                            "name": "Limpeza da \u00c1rea dos Reservat\u00f3rios",
                            "value": "21"
                        }, {
                            "name": "Macr\u00f3fitas Aqu\u00e1ticas",
                            "value": "22"
                        }, {
                            "name": "Mexilh\u00e3o Dourado",
                            "value": "23"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Climatol\u00f3gicas",
                            "value": "24"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Hidrometeorol\u00f3gicas",
                            "value": "25"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Hidrossedimentol\u00f3gicas",
                            "value": "26"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Meteorol\u00f3gicas",
                            "value": "27"
                        }, {
                            "name": "Monitoramento das Condi\u00e7\u00f5es Sismol\u00f3gicas",
                            "value": "28"
                        }, {
                            "name": "Qualidade da \u00c1gua da Chuva",
                            "value": "29"
                        }, {
                            "name": "Qualidade das \u00c1guas Subterr\u00e2neas",
                            "value": "30"
                        }, {
                            "name": "Qualidade das \u00c1guas Superficiais",
                            "value": "31"
                        }, {
                            "name": "Qualidade do Ar",
                            "value": "32"
                        }, {
                            "name": "Qualidade do Solo",
                            "value": "33"
                        }, {
                            "name": "Recupera\u00e7\u00e3o de \u00c1reas Degradadas",
                            "value": "34"
                        }, {
                            "name": "Ru\u00eddos",
                            "value": "35"
                        }, {
                            "name": "Unidades de Conserva\u00e7\u00e3o",
                            "value": "36"
                        }, {
                            "name": "Uso, Ocupa\u00e7\u00e3o e Fiscaliza\u00e7\u00e3o Ambiental e Socio-Patrimonial do Entorno do Reservat\u00f3rio",
                            "value": "37"
                        }, {
                            "name": "Emerg\u00eancias Ambientais",
                            "value": "38"
                        }, {
                            "name": "Geoweb Ambiental (Sistema de Informa\u00e7\u00f5es Georreferenciadas)",
                            "value": "39"
                        }, {
                            "name": "Licenciamento Ambiental",
                            "value": "40"
                        }, {
                            "name": "MDL - Mecanismo de Desenvolvimento Limpo",
                            "value": "41"
                        }, {
                            "name": "Mudan\u00e7as Clim\u00e1ticas",
                            "value": "42"
                        }, {
                            "name": "Sistema de Gest\u00e3o Ambiental (NBR ISO 14.001)",
                            "value": "43"
                        }, {
                            "name": "Usos M\u00faltiplos do Reservat\u00f3rio",
                            "value": "44"
                        }, {
                            "name": "Servi\u00e7os Especiais e Extraordin\u00e1rios",
                            "value": "45"
                        }, {
                            "name": "Ingresso Imobiliza\u00e7\u00e3o em Curso",
                            "value": "46"
                        }, {
                            "name": "Baixas Imobiliza\u00e7\u00e3o em Curso - Ingressos de Exerc\u00edcios Anteriores - Meio Ambiente",
                            "value": "47"
                        }, {
                            "name": "Gest\u00e3o sociopatrimonial ",
                            "value": "48"
                        }, {
                            "name": "Seguran\u00e7a de barragens",
                            "value": "49"
                        }]
                    }
                },
                "exceptionalResourceButton": {
                    "displayIf": {
                        "resourceKind": ["1", "2", "3"]
                    }
                }
            }
        },
        "OperationalControlRecord": {
            "fields": {
                "river": {
                    "displayIf": {
                        "placeOnDam": ["1", "2", "3"]
                    }
                },
                "placeOnDam": {
                    "apiName": "placeOnDam",
                    "dataType": "select",
                    "displayName": "Local",
                    "selectOptions": {
                        "options": [{
                            "name": "Reservat\u00f3rio",
                            "value": "1"
                        }, {
                            "name": "Jusante",
                            "value": "2"
                        }, {
                            "name": "Montante",
                            "value": "3"
                        }, {
                            "name": "\u00c1rea Industrial",
                            "value": "4"
                        }, {
                            "name": "\u00c1rea circunvizinha",
                            "value": "5"
                        }, {
                            "name": "\u00c1rea de preserva\u00e7\u00e3o permanente",
                            "value": "6"
                        }, {
                            "name": "\u00c1rea Remanescente",
                            "value": "7"
                        }, {
                            "name": "\u00c1rea de terceiros",
                            "value": "8"
                        }, {
                            "name": "Faixa de Oscila\u00e7\u00e3o",
                            "value": "9"
                        }, {
                            "name": "Casa de M\u00e1quinas",
                            "value": "10"
                        }, {
                            "name": "Canal de Fuga",
                            "value": "11"
                        }, {
                            "name": "Canal de Adu\u00e7\u00e3o",
                            "value": "12"
                        }, {
                            "name": "Tomada d'\u00c1gua",
                            "value": "13"
                        }, {
                            "name": "Vertedouro",
                            "value": "14"
                        }, {
                            "name": "Log Boom",
                            "value": "15"
                        }, {
                            "name": "Bacia de Dissipa\u00e7\u00e3o",
                            "value": "16"
                        }, {
                            "name": "Canteiro de Obra",
                            "value": "17"
                        }, {
                            "name": "Lagoas Marginais",
                            "value": "18"
                        }]
                    }
                }
            },
            "groups": {
                "location": {
                    "displayIf": {
                        "relationships.occurrenceType.data.id": ["f200613b-8862-4a24-8c16-d6babd215fd7"]
                    }
                }
            }
        },
        "serviceOrderActionStatus": {
            "fields": {
                "kind": {
                    "apiName": "kind",
                    "dataType": "select",
                    "displayName": "Tipo",
                    "selectOptions": {
                        "options": [{
                            "name": "A\u00e7\u00e3o",
                            "value": "ACTION_STATUS"
                        }, {
                            "name": "Registro",
                            "value": "OCCURRENCE_RECORD_STATUS"
                        }, {
                            "name": "Objeto",
                            "value": "CONTRACT_STATUS"
                        }]
                    }
                }
            }
        },
        "administrativeInformation": {
            "fields": {
                "extra_info": {
                    "additional_control": {
                        "apiName": "additional_control",
                        "dataType": "select",
                        "displayName": "Controle Adicional",
                        "selectOptions": {
                            "options": [{
                                "name": "Comunica\u00e7\u00e3o Socioambiental",
                                "value": "1"
                            }, {
                                "name": "Comunidades Ind\u00edgenas e/ou Outros Grupos \u00c9tnicos",
                                "value": "2"
                            }, {
                                "name": "Educa\u00e7\u00e3o Ambiental e Visitas \u00e0 Usina",
                                "value": "3"
                            }, {
                                "name": "Fundo de Desenvolvimento Regional",
                                "value": "4"
                            }, {
                                "name": "Patrim\u00f4nio Cultural, Hist\u00f3rico e Arqueol\u00f3gico",
                                "value": "5"
                            }, {
                                "name": "Recomposi\u00e7\u00e3o da Infra-Estrutura",
                                "value": "6"
                            }, {
                                "name": "Reloca\u00e7\u00e3o de Popula\u00e7\u00f5es Urbanas",
                                "value": "7"
                            }, {
                                "name": "Remanejamento da Popula\u00e7\u00e3o Rural",
                                "value": "8"
                            }, {
                                "name": "Reorganiza\u00e7\u00e3o das Atividades Econ\u00f4micas",
                                "value": "9"
                            }, {
                                "name": "Sa\u00fade da Popula\u00e7\u00e3o Afetada",
                                "value": "10"
                            }, {
                                "name": "Conserva\u00e7\u00e3o da Fauna Terrestre e Alada",
                                "value": "11"
                            }, {
                                "name": "Conserva\u00e7\u00e3o da Flora",
                                "value": "12"
                            }, {
                                "name": "Conserva\u00e7\u00e3o da Ictiofauna",
                                "value": "13"
                            }, {
                                "name": "Consolida\u00e7\u00e3o de \u00c1reas de Preserva\u00e7\u00e3o Permanente e Reserva Legal",
                                "value": "14"
                            }, {
                                "name": "Efluentes",
                                "value": "15"
                            }, {
                                "name": "Emiss\u00f5es Atmosf\u00e9ricas",
                                "value": "16"
                            }, {
                                "name": "Estabiliza\u00e7\u00e3o dos Taludes Marginais",
                                "value": "17"
                            }, {
                                "name": "Estudos de Dispers\u00e3o Atmosf\u00e9rica",
                                "value": "18"
                            }, {
                                "name": "Gerenciamento de Res\u00edduos",
                                "value": "19"
                            }, {
                                "name": "Horto Florestal e Viveiro de Produ\u00e7\u00e3o de Mudas",
                                "value": "20"
                            }, {
                                "name": "Limpeza da \u00c1rea dos Reservat\u00f3rios",
                                "value": "21"
                            }, {
                                "name": "Macr\u00f3fitas Aqu\u00e1ticas",
                                "value": "22"
                            }, {
                                "name": "Mexilh\u00e3o Dourado",
                                "value": "23"
                            }, {
                                "name": "Monitoramento das Condi\u00e7\u00f5es Climatol\u00f3gicas",
                                "value": "24"
                            }, {
                                "name": "Monitoramento das Condi\u00e7\u00f5es Hidrometeorol\u00f3gicas",
                                "value": "25"
                            }, {
                                "name": "Monitoramento das Condi\u00e7\u00f5es Hidrossedimentol\u00f3gicas",
                                "value": "26"
                            }, {
                                "name": "Monitoramento das Condi\u00e7\u00f5es Meteorol\u00f3gicas",
                                "value": "27"
                            }, {
                                "name": "Monitoramento das Condi\u00e7\u00f5es Sismol\u00f3gicas",
                                "value": "28"
                            }, {
                                "name": "Qualidade da \u00c1gua da Chuva",
                                "value": "29"
                            }, {
                                "name": "Qualidade das \u00c1guas Subterr\u00e2neas",
                                "value": "30"
                            }, {
                                "name": "Qualidade das \u00c1guas Superficiais",
                                "value": "31"
                            }, {
                                "name": "Qualidade do Ar",
                                "value": "32"
                            }, {
                                "name": "Qualidade do Solo",
                                "value": "33"
                            }, {
                                "name": "Recupera\u00e7\u00e3o de \u00c1reas Degradadas",
                                "value": "34"
                            }, {
                                "name": "Ru\u00eddos",
                                "value": "35"
                            }, {
                                "name": "Unidades de Conserva\u00e7\u00e3o",
                                "value": "36"
                            }, {
                                "name": "Uso, Ocupa\u00e7\u00e3o e Fiscaliza\u00e7\u00e3o Ambiental e Socio-Patrimonial do Entorno do Reservat\u00f3rio",
                                "value": "37"
                            }, {
                                "name": "Emerg\u00eancias Ambientais",
                                "value": "38"
                            }, {
                                "name": "Geoweb Ambiental (Sistema de Informa\u00e7\u00f5es Georreferenciadas)",
                                "value": "39"
                            }, {
                                "name": "Licenciamento Ambiental",
                                "value": "40"
                            }, {
                                "name": "MDL - Mecanismo de Desenvolvimento Limpo",
                                "value": "41"
                            }, {
                                "name": "Mudan\u00e7as Clim\u00e1ticas",
                                "value": "42"
                            }, {
                                "name": "Sistema de Gest\u00e3o Ambiental (NBR ISO 14.001)",
                                "value": "43"
                            }, {
                                "name": "Usos M\u00faltiplos do Reservat\u00f3rio",
                                "value": "44"
                            }, {
                                "name": "Servi\u00e7os Especiais e Extraordin\u00e1rios",
                                "value": "45"
                            }, {
                                "name": "Ingresso Imobiliza\u00e7\u00e3o em Curso",
                                "value": "46"
                            }, {
                                "name": "Baixas Imobiliza\u00e7\u00e3o em Curso - Ingressos de Exerc\u00edcios Anteriores - Meio Ambiente",
                                "value": "47"
                            }, {
                                "name": "Gest\u00e3o sociopatrimonial ",
                                "value": "48"
                            }]
                        }
                    }
                }
            }
        }
    }))

# %%
metadata = json.loads(json.dumps({
        "vg_sync": {
            "vg_code": 13621,
            "org_code": 10471
        },
        "regional": "RERU",
        "extra_actions": {
            "create": {
                "dest_status": "6f6cdc39-cbcf-4649-84ca-9807f2a61645"
            },
            "reject": {
                "dest_status": "ff9face2-8bd7-4ab3-8f1d-8df52d733574"
            },
            "approve": {
                "dest_status": "4f89dd8b-dbe9-4cae-be66-ea7ffa2af61b"
            },
            "requestReview": {
                "dest_status": "08199255-6eaf-4415-838b-56357287152e",
                "return_to_creator": True
            },
            "sendToApproval": {
                "dest_firm": "ed9132c6-b426-44a4-973d-31d85081e40d",
                "dest_status": "20134139-c77b-4404-8b9c-6697af03d07c"
            },
            "requestReviewAction": {
                "dest_status": "77261a11-7b39-4cb4-8f4c-d0f545bcf1e6",
                "return_to_creator": True
            }
        },
        "pdf_map_tiles": {
            "satellite": "0b28a8c8-bc1d-47e0-b45b-23fd237799b3"
        },
        "BM_name_format": "{prefixo}-BM-{anoCompleto}.{serialAno:04}",
        "CM_name_format": "{prefixo}-CM-{anoCompleto}.{serialAno:04}",
        "OC_name_format": {
            "default": {
                "type": "OC",
                "format": "{prefixo}-OC-{anoCompleto}.{serialAno:04}"
            }
        },
        "OS_name_format": "{prefixo}-OS-{anoCompleto}.{serialAno:04}",
        "PM_name_format": "{prefixo}-PM-{anoCompleto}.{serialAno:04}",
        "RO_name_format": "{prefixo}-RG-{anoCompleto}.{serialAno:04}",
        "company_prefix": "UHIT",
        "COM_name_format": "{prefixo}-COM-{anoCompleto}.{serialAno:04}",
        "DOC_name_format": "{prefixo}-DOC-{anoCompleto}.{serialAno:04}",
        "land_used_value": "1",
        "special_filters": {
            "concluidos": {
                "status_ids": ["ff9face2-8bd7-4ab3-8f1d-8df52d733574", "ec17e549-77bc-4d0d-8fc2-a86132b86f49"]
            },
            "homologados": {
                "status_ids": ["4f89dd8b-dbe9-4cae-be66-ea7ffa2af61b"]
            },
            "em_tratamento": {
                "has_service_order": True
            },
            "em_homologacao": {
                "status_ids": ["6f6cdc39-cbcf-4649-84ca-9807f2a61645", "20134139-c77b-4404-8b9c-6697af03d07c", "08199255-6eaf-4415-838b-56357287152e"]
            }
        },
        "application_name": "",
        "land_search_tags": ["823bb87f-ba42-43e0-a837-e09985bccaa0", "07e71ad1-112a-4900-abd9-636f85729c75"],
        "properties_label": "Propriedades envolvidas",
        "properties_shape": "5e7e5cf3-3463-418c-8af9-adf6117d431d",
        "sst_forms_status": ["ec17e549-77bc-4d0d-8fc2-a86132b86f49", "4f89dd8b-dbe9-4cae-be66-ea7ffa2af61b"],
        "land_action_names": [{
            "name": "Identificar a titularidade do im\u00f3vel",
            "timedelta": {
                "weeks": 2
            }
        }, {
            "name": "Confirmar o infrator",
            "timedelta": {
                "weeks": 3
            }
        }, {
            "name": "Esclarecer o limite da ocupa\u00e7\u00e3o",
            "timedelta": {
                "weeks": 4
            }
        }, {
            "name": "Realizar acordo verbal",
            "timedelta": {
                "weeks": 5
            }
        }, {
            "name": "Atestar o cumprimento do acordo verbal",
            "timedelta": {
                "weeks": 6
            }
        }, {
            "name": "Notificar o infrator extrajudicialmente",
            "timedelta": {
                "weeks": 7
            }
        }, {
            "name": "Atestar o cumprimento da NE",
            "timedelta": {
                "weeks": 8
            }
        }, {
            "name": "Ajuizar a\u00e7\u00e3o possess\u00f3ria",
            "timedelta": {
                "weeks": 9
            }
        }, {
            "name": "Atender as provid\u00eancias judiciais",
            "timedelta": {
                "weeks": 10
            }
        }, {
            "name": "Atestar a desocupa\u00e7\u00e3o",
            "timedelta": {
                "weeks": 11
            }
        }, {
            "name": "Ajuizar a\u00e7\u00e3o de execu\u00e7\u00e3o",
            "timedelta": {
                "weeks": 12
            }
        }, {
            "name": "Atestar o cumprimento do mandado",
            "timedelta": {
                "weeks": 14
            }
        }],
        "properties_columns": [{
            "label": "Obra",
            "source": "OBRA"
        }, {
            "label": "Sequencial",
            "source": "SEQUENCIAL"
        }, {
            "label": "Identificador",
            "source": "IDENTIFICADOR"
        }],
        "report_email_firms": ["a35f9b79-ea8c-47f7-83b8-5be653aeca4b", "ed9132c6-b426-44a4-973d-31d85081e40d"],
        "land_used_search_tags": ["823bb87f-ba42-43e0-a837-e09985bccaa0", "0a427bff-0dcc-4bac-b980-2374958ffb7f", "07e71ad1-112a-4900-abd9-636f85729c75"],
        "environment_search_tags": ["07e71ad1-112a-4900-abd9-636f85729c75", "8449de91-cabe-4acb-a04b-f1157b8cec71"],
        "approve_service_order_at": "4f89dd8b-dbe9-4cae-be66-ea7ffa2af61b",
        "send_approval_step_email": True,
        "done_occurrence_record_at": ["4f89dd8b-dbe9-4cae-be66-ea7ffa2af61b", "ff9face2-8bd7-4ab3-8f1d-8df52d733574"],
        "lock_occurrence_record_at": ["ecab3378-1a0b-4b91-8cef-d4dcfc6d1a59", "4f89dd8b-dbe9-4cae-be66-ea7ffa2af61b", "b2c845e7-4900-4981-885a-977e7cf3ade3", "33ccc2d4-a195-49db-a6e5-ad5edfce0e09", "ff9face2-8bd7-4ab3-8f1d-8df52d733574", "fbb50a7a-b212-48be-ab59-b8efafd2f618", "214a42cb-760b-4478-8a08-7056a7f5f76b", "20134139-c77b-4404-8b9c-6697af03d07c", "f36912bb-70b1-4b9b-a1ca-1b899ebd8dcd", "c9865781-fb2b-48b7-8b93-3c87152f2418"],
        "properties_dialog_columns": [{
            "label": "Obra",
            "source": "OBRA"
        }, {
            "label": "Sequencial",
            "source": "SEQUENCIAL"
        }, {
            "label": "Identificador",
            "source": "IDENTIFICADOR"
        }, {
            "label": "Propriet\u00e1rio",
            "source": "PROPRIETARIO"
        }, {
            "label": "Munic\u00edpio",
            "source": "MUNICIPIO"
        }],
        "unlock_occurrence_record_at": ["08199255-6eaf-4415-838b-56357287152e"]
    }))

# %%
company = Company(name=company_name,company_group=company_group,custom_options=custom_options,metadata=metadata)

# %%
company.save()

# %%
company = Company.objects.get(name="Demo Energia")
company
# Out:
# <Company: 5a7918ca-d799-4f6b-8b48-28bfab77a52a: Demo Energia>

# %% [markdown]
# # 3º CRIAÇÃO DOS MAPAS PADRÃO (TILELAYER)

# %%
tile = TileLayer.objects.filter(name__in=["Satélite",'Mapa Claro','Mapa Escuro','OpenStreetMap','Relevo','Padrão'])

# %%
for a in tile:
    a.companies.add(company)

# %% [markdown]
# # 4º CRIAR USER PERMISSIONS

# %%
permissions=json.loads('{"City": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "Firm": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": false}, "ToDo": {"can_edit": true, "can_view": true, "queryset": "self", "can_create": false, "can_delete": false}, "User": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": false, "can_use_rh_api": true, "can_edit_all_fields": true}, "River": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "Entity": {"can_edit": false, "can_view": true, "queryset": "all", "can_create": false, "can_delete": false}, "Company": {"can_edit": true, "can_view": true, "queryset": "self", "can_create": true, "can_delete": true}, "Contract": {"can_edit": true, "can_view": true, "queryset": "entity", "can_create": true, "can_delete": true, "can_view_money": true}, "HelpChat": {"can_view": true}, "Location": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "Resource": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "WorkPlan": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "Dashboard": {"can_edit": false, "can_view": true, "queryset": "all", "can_create": false, "can_delete": false, "can_view_map": true, "can_view_heat_map": true, "can_view_tech_plots": true, "can_view_financial_indicators": true}, "EcmSearch": {"can_view": true}, "Procedure": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": false, "allowed_status_transitions": {"08199255-6eaf-4415-838b-56357287152e": ["08199255-6eaf-4415-838b-56357287152e", "20134139-c77b-4404-8b9c-6697af03d07c", "4f89dd8b-dbe9-4cae-be66-ea7ffa2af61b", "ff9face2-8bd7-4ab3-8f1d-8df52d733574"], "20134139-c77b-4404-8b9c-6697af03d07c": ["20134139-c77b-4404-8b9c-6697af03d07c", "4f89dd8b-dbe9-4cae-be66-ea7ffa2af61b", "08199255-6eaf-4415-838b-56357287152e", "ff9face2-8bd7-4ab3-8f1d-8df52d733574"], "214a42cb-760b-4478-8a08-7056a7f5f76b": ["ecab3378-1a0b-4b91-8cef-d4dcfc6d1a59", "b2c845e7-4900-4981-885a-977e7cf3ade3", "77261a11-7b39-4cb4-8f4c-d0f545bcf1e6", "33ccc2d4-a195-49db-a6e5-ad5edfce0e09", "fbb50a7a-b212-48be-ab59-b8efafd2f618", "214a42cb-760b-4478-8a08-7056a7f5f76b"], "33ccc2d4-a195-49db-a6e5-ad5edfce0e09": ["ecab3378-1a0b-4b91-8cef-d4dcfc6d1a59", "b2c845e7-4900-4981-885a-977e7cf3ade3", "77261a11-7b39-4cb4-8f4c-d0f545bcf1e6", "33ccc2d4-a195-49db-a6e5-ad5edfce0e09", "fbb50a7a-b212-48be-ab59-b8efafd2f618", "214a42cb-760b-4478-8a08-7056a7f5f76b"], "4f89dd8b-dbe9-4cae-be66-ea7ffa2af61b": ["4f89dd8b-dbe9-4cae-be66-ea7ffa2af61b"], "6f6cdc39-cbcf-4649-84ca-9807f2a61645": ["20134139-c77b-4404-8b9c-6697af03d07c", "6f6cdc39-cbcf-4649-84ca-9807f2a61645"], "77261a11-7b39-4cb4-8f4c-d0f545bcf1e6": ["ecab3378-1a0b-4b91-8cef-d4dcfc6d1a59", "b2c845e7-4900-4981-885a-977e7cf3ade3", "77261a11-7b39-4cb4-8f4c-d0f545bcf1e6", "33ccc2d4-a195-49db-a6e5-ad5edfce0e09", "fbb50a7a-b212-48be-ab59-b8efafd2f618", "214a42cb-760b-4478-8a08-7056a7f5f76b"], "b2c845e7-4900-4981-885a-977e7cf3ade3": ["ecab3378-1a0b-4b91-8cef-d4dcfc6d1a59", "b2c845e7-4900-4981-885a-977e7cf3ade3", "77261a11-7b39-4cb4-8f4c-d0f545bcf1e6", "33ccc2d4-a195-49db-a6e5-ad5edfce0e09", "fbb50a7a-b212-48be-ab59-b8efafd2f618", "214a42cb-760b-4478-8a08-7056a7f5f76b"], "ecab3378-1a0b-4b91-8cef-d4dcfc6d1a59": ["ecab3378-1a0b-4b91-8cef-d4dcfc6d1a59", "b2c845e7-4900-4981-885a-977e7cf3ade3", "77261a11-7b39-4cb4-8f4c-d0f545bcf1e6", "33ccc2d4-a195-49db-a6e5-ad5edfce0e09", "fbb50a7a-b212-48be-ab59-b8efafd2f618", "214a42cb-760b-4478-8a08-7056a7f5f76b"], "fbb50a7a-b212-48be-ab59-b8efafd2f618": ["ecab3378-1a0b-4b91-8cef-d4dcfc6d1a59", "b2c845e7-4900-4981-885a-977e7cf3ade3", "77261a11-7b39-4cb4-8f4c-d0f545bcf1e6", "33ccc2d4-a195-49db-a6e5-ad5edfce0e09", "fbb50a7a-b212-48be-ab59-b8efafd2f618", "214a42cb-760b-4478-8a08-7056a7f5f76b"], "ff9face2-8bd7-4ab3-8f1d-8df52d733574": ["ff9face2-8bd7-4ab3-8f1d-8df52d733574"]}}, "SearchTag": {"can_view": true, "queryset": "all"}, "ShapeFile": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "TileLayer": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "CanvasCard": {"can_edit": true, "can_view": true, "queryset": "self", "can_create": true, "can_delete": true}, "CanvasList": {"can_edit": true, "can_view": true, "queryset": "self", "can_create": true, "can_delete": true}, "Permission": {"can_edit": false, "can_view": true, "queryset": "all", "can_create": false, "can_delete": false}, "QueuedPush": {"can_view": true}, "SubCompany": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": false}, "UserInFirm": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "UserManual": {"null": null, "can_view": true}, "EcmDownload": {"can_view": true}, "EngieSearch": {"can_view": true}, "ApprovalFlow": {"can_edit": true, "can_view": true, "queryset": "self", "can_create": true, "can_delete": true}, "ApprovalStep": {"can_edit": true, "can_view": true, "queryset": "self", "can_create": true, "can_delete": true}, "CompanyGroup": {"can_edit": false, "can_view": true, "queryset": "all", "can_create": false, "can_delete": false}, "MaterialItem": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true, "can_view_money": true}, "ServiceOrder": {"can_edit": "entity", "can_view": true, "queryset": "all", "can_create": true, "can_delete": false, "can_be_manager": true, "can_view_money": true, "can_view_canvas": true, "can_be_responsible": true, "can_view_pending_procedures": "all"}, "AccessRequest": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true, "can_approve": true}, "HumanResource": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "MaterialUsage": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": false, "can_approve": true, "can_view_money": true}, "ProcedureFile": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "UserInCompany": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "MonitoringPlan": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "OccurrenceType": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": false, "can_delete": false}, "ParameterGroup": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "UserPermission": {"can_edit": false, "can_view": true, "queryset": "all", "can_create": false, "can_delete": false}, "ContractService": {"can_edit": true, "can_view": true, "queryset": "entity", "can_create": true, "can_delete": true, "can_view_money": true}, "MonitoringCycle": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "MonitoringPoint": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "MonitoringRecord": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "OccurrenceRecord": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": false, "can_approve": true, "can_vg_sync": true, "disableSubMenus": false, "canViewInvolvedParts": true, "can_view_geolocation": true, "canViewHidrologySection": true, "can_view_involved_parts": true, "canViewProceduresSection": true, "can_view_hidrology_section": true, "can_view_procedures_section": true}, "OperationalCycle": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "CustomizationMenu": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "HumanResourceItem": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true, "can_view_money": true}, "MonitoringCollect": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "ProcedureResource": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": false, "can_approve": true, "can_view_money": true}, "AdditionalDocument": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": false, "can_approve": true}, "ApprovalTransition": {"can_edit": true, "can_view": true, "queryset": "self", "can_create": true, "can_delete": true}, "HumanResourceUsage": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": false, "can_approve": true, "can_view_money": true}, "MonitoringCampaign": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "MonitoringSchedule": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "OperationalControl": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "ServiceOrderAction": {"can_edit": "entity", "can_view": true, "queryset": "all", "can_create": "entity", "can_delete": true}, "MeasurementBulletin": {"can_edit": false, "can_view": true, "queryset": "all", "can_create": false, "can_delete": false, "can_approve": true, "can_view_money": true}, "MonitoringFrequency": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "OccurrenceTypeSpecs": {"can_edit": false, "can_view": true, "queryset": "all", "can_create": false, "can_delete": false}, "ServiceOrderWatcher": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "OccurrenceRecordFile": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "ServiceOrderResource": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true, "can_view_money": true}, "ContractItemUnitPrice": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true, "can_view_money": true}, "OccurrenceRecordWatcher": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "OperationalControlRecord": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true, "can_vg_sync": true}, "ServiceOrderActionStatus": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}, "AdministrativeInformation": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true, "can_view_money": true}, "ServiceOrderActionStatusSpecs": {"can_edit": true, "can_view": true, "queryset": "all", "can_create": true, "can_delete": true}}')
name = 'HOMOLOGADOR'

# %%
user_permission = UserPermission(name=name, permissions=permissions)
user_permission.save()
user_permission.companies.add(company)

# %% [markdown]
# # 5º CRIAR USER_IN_COMPANY

# %%
user=User.objects.get(username='rlcs')
# Out:
# <User: rlcs - Kartado CS>

# %%
UserInCompany(user=user,
              company=company,
              permissions=user_permission)

# %% [markdown]
# # 6º CRIAR SUB_COMPANY

# %%
subcompany_type = 'HIRING' # or HIRED
name = "Energia Kartado"
cnpj='00000000000000'

# %%
sub_company = SubCompany(subcompany_type=subcompany_type,
                         company=company,
                         name=name,
                         cnpj=cnpj,
                         responsible = user)

# %% [markdown]
# # 7º CRIAR EQUIPE

# %%
firm = Firm(name="Equipe Energia Kartado",
           manager=user,
           company=company,
           sub_company=sub_company,
           active=True,
           can_use_ecm_integration=True)

# %% [markdown]
# # 8º Criar Approvals Flow/Step/Transition AccessRequest

# %%
flow = ApprovalFlow(
    name="Fluxo Usuários",
    target_model="companies.AccessRequest",
    company=company
)
flow.save()

# %%
step1 = ApprovalStep(
    name="Aguardando Aprovação do Supervisor",
    approval_flow=flow,
    field_options={"required": ["relationships.permissions.data.id"]},
    responsible_supervisor = True
)
step1.save()

# %%
step3 = ApprovalStep(
    name="Aguardando Aprovação do Usuário-Chave do Sistema",
    approval_flow=flow,
    field_options={"required": ["relationships.permissions.data.id"]},
)
step3.save()

# %%
step4 = ApprovalStep(
    name="Aprovado",
    approval_flow=flow,
    field_options={"required": ["relationships.permissions.data.id"]}
)
step4.save()

# %%
step5 = ApprovalStep(
    name="Negado",
    approval_flow=flow,
    field_options={"required": ["relationships.permissions.data.id"]}
)
step5.save()

# %% [markdown]
# Cria as transições entre os passos

# %%
transition1 = ApprovalTransition(
    name="Aprovar",
    origin=step1,
    destination=step3,
    condition={"===": [{"var": "request.action"}, "Aprovar"]},
    callback={},
)
transition1.save()

# %%
transition2 = ApprovalTransition(
    name="Rejeitar",
    origin=step1,
    destination=step5,
    condition={"===": [{"var": "request.action"}, "Rejeitar"]},
    callback={'change_fields': [{'name': 'done', 'value': True}]},
)
transition2.save()

# %%
transition3 = ApprovalTransition(
    name="Aprovar",
    origin=step3,
    destination=step4,
    condition={"===": [{"var": "request.action"}, "Aprovar"]},
    callback={"change_fields": [{"name": "approved", "value": True}, {"name": "done", "value": True}], "create_user_in_company": True},
)
transition3.save()

# %%
transition4 = ApprovalTransition(
    name="Rejeitar",
    origin=step3,
    destination=step5,
    condition={"===": [{"var": "request.action"}, "Rejeitar"]},
    callback={'change_fields': [{'name': 'done', 'value': True}]},
)
transition4.save()

# %% [markdown]
# Se existir, você pode atualizar essas solicitações para estarem no primeiro passo. Será necessário aprová-las através da interface

# %%
AccessRequest.objects.filter(company=company, approval_step__isnull=True).update(approval_step=step1)

# %% [markdown]
# # 9º Criar Approvals Flow/Step/Transition OccurrenceRecord

# %%
Arquivo: KNB - Create ApprovalFlow for Reporting (with reviewal) Basico Inicial Parte 2

# %% [markdown]
# # 10º Criar OccurrenceType/OccurrenceTypeSpecs

# %% [markdown]
# # 11º Criar SearchTags

# %% [markdown]
# # 12º Criar SearchTagsOccurrenceType
