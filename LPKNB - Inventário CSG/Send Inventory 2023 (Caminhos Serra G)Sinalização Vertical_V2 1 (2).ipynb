# %% [markdown]
# # Inventário

# %% [markdown]
# Deve-se executar as seis primeiras células para carregar funções utilizadas para rodar o script

# %%
import json
import os
from openpyxl import load_workbook
from datetime import timedelta
import random
from copy import deepcopy
from django.contrib.gis.geos import LineString, Point
from django.contrib.admin.utils import flatten
import math
import datetime
import locale
from tqdm.notebook import tqdm
from PIL import Image
from io import BytesIO
from django.contrib.gis.geos import Point, LineString as DjangoLineString
import pytz
from simple_history.utils import bulk_create_with_history
from helpers.histories import bulk_update_with_history
from helpers.route_maker import dic_to_ordered_list, unequal_point_pairs

# %%
#encontra a latitude e longitude e retorna 

def km_to_coordinates(road, km):

    road_marks = dic_to_ordered_list(road.marks)
    selected_pair = None

    for pair in unequal_point_pairs(road_marks):
        if pair[0]["km"] > km and pair[1]["km"] < km:
            selected_pair = pair
            break
        elif pair[1]["km"] > km and pair[0]["km"] < km:
            selected_pair = pair
            break
        elif pair[0]["km"] == km:
            return Point(pair[0]["point"]["coordinates"]), road
        elif pair[1]["km"] == km:
            return Point(pair[1]["point"]["coordinates"]), road

    # Calculate total length
    start_km = min([selected_pair[0]["km"], selected_pair[1]["km"]])
    end_km = max([selected_pair[0]["km"], selected_pair[1]["km"]])
    segment_mark_length = end_km - start_km
    distance_from_min = km - start_km
    # Check if km is decreasing
    invert_km = selected_pair[1]["km"] <= selected_pair[0]["km"]

    # Cut segment
    start_key = min((selected_pair[0]["index"], selected_pair[1]["index"]))
    end_key = max((selected_pair[0]["index"], selected_pair[1]["index"]))

    points = []
    for key in range(start_key, end_key + 1):
        points.append(
            Point(road.path[key][0], road.path[key][1], road.path[key][2])
        )

    segment = LineString(points, srid=4326)
    # Apply km inversion correction
    if invert_km:
        segment_distance = (
            1 - (distance_from_min / segment_mark_length)
        ) * segment.length
    else:
        segment_distance = (
            distance_from_min / segment_mark_length
        ) * segment.length
    # Find point
    point = segment.interpolate(segment_distance)

    return Point(point.x, point.y), road

# %%
#verifica se o km está dentro da rodovia

def check_valid_road(road, km):

    road_marks = dic_to_ordered_list(road.marks)

    for pair in unequal_point_pairs(road_marks):
        if pair[0]["km"] >= km and pair[1]["km"] <= km:
            return True
        elif pair[1]["km"] >= km and pair[0]["km"] <= km:
            return True

    return False

# %%
def get_connected_reference(company, resource, key, value):
    value=value.strip()
    select_options = company.custom_options[resource]['fields'][key]['selectOptions']['options']
    return next(a['value'] for a in select_options if a['name'].lower() == value.lower())

# %%
def get_road_coordinates(road_name, km, direction, company):
    road_set = Road.objects.filter(
        name__contains=road_name, direction=int(direction), company=company
    )
#     print(road_set)

    # If roads in specified direction are not found, search road only
    # by name and order then by direction
    road_set_generic = Road.objects.filter(
        name__contains=road_name, company=company
    ).order_by("direction")

    # Check if KM range in road_set
#     print("Searching KM on direction...")
    valid = False
    for road in road_set:
        if check_valid_road(road, km):
#             print("Found KM on Road {}".format(road))
            valid = True
            break

    if not valid:
#         print("Searching KM without direction...")
        for road in road_set_generic:
            if check_valid_road(road, km):
#                 print("Found KM on Road {}".format(road))
                valid = True
                break

    if not valid:
        return Point(0, 0), None

    try:
        return km_to_coordinates(road, km)
    except Exception:
        return Point(0, 0), None

# %%
get_road_coordinates('ERS-122',0.37,'0',Company.objects.get(name='Caminhos da Serra Gaúcha'))
# Out:
# (<Point object at 0x7059d4ceac10>, <Road: 2059: ERS-122>)

# %%
def findIndex(flist, func):
    for i,v in enumerate(flist):
        if func(v): 
            return i
    return -1

# %%
def point_to_km(lng, lat, road):
    point = Point(lng, lat, srid=4326)
    if isinstance(road,str):
        roads = Road.objects.filter(company=company,name__icontains=road).annotate(distance=Distance(point, 'path')).order_by('distance')
        road = roads[0]
    else:
        road = roads[0]
    path = loads(road.path.geojson)
    point_geojson = loads(point.geojson)
    road_marks = list(road.marks.values())
    snap_point = nearest_point_on_line(path, point_geojson)
    

    road_markers = sorted([a for a in road_marks if 'index' in a or ('index' in a and a['index'] == 0)], key=lambda x: int(x['key']))
#     road_markers = sorted([a for a in road_marks if a['index'] or a['index'] == 0], key=lambda x: int(x['key']))
    rm_index = findIndex(road_markers, lambda x: x['index'] > snap_point['properties']['index'])
    
    if (rm_index == -1):
        rm_index = len(road_markers) - 1;
    
    km_marker_start = road_markers[rm_index - 1]
    km_marker_end = road_markers[rm_index]
    
    if km_marker_start['index'] == road_markers[-1]['index']: 
        snap = road_markers[-1]
        km = snap['km']
    elif km_marker_end['index'] == road_markers[0]['index']:
        snap = road_markers[0]
        km = snap['km']
    else:
        test = path['coordinates'][km_marker_start['index']:km_marker_end['index'] + 1]
        marker_path = LineString(test)
        snap = nearest_point_on_line(marker_path, point_geojson)        
        ls_length = length(marker_path, units="km")
        km = ((snap['properties']['location'] / ls_length)        
            * (km_marker_end['km'] - km_marker_start['km'])
            + km_marker_start['km'])
    
    return road, road.name, point, round(km, 3)

# %%
from collections import defaultdict
from django.db.models.signals import *


class DisableSignals(object):
    def __init__(self, disabled_signals=None):
        self.stashed_signals = defaultdict(list)
        self.disabled_signals = disabled_signals or [
            pre_init, post_init,
            pre_save, post_save,
            pre_delete, post_delete,
            pre_migrate, post_migrate,
        ]

    def __enter__(self):
        for signal in self.disabled_signals:
            self.disconnect(signal)

    def __exit__(self, exc_type, exc_val, exc_tb):
        for signal in list(self.stashed_signals):
            self.reconnect(signal)

    def disconnect(self, signal):
        self.stashed_signals[signal] = signal.receivers
        signal.receivers = []

    def reconnect(self, signal):
        signal.receivers = self.stashed_signals.get(signal, [])
        del self.stashed_signals[signal]

# %%
def get_sign(field, sign_field, occ, value):
#     if sign_field == 'Cor':
#         value=value.capitalize() if value != 'Amarela fluorescente (VII)' else value
#     elif sign_field == 'Tipo de Película':
#         value=value
    values = occ.form_fields['fields']
    item_translation = flatten([item['innerFields'] for item in values if item['displayName']==field])
#     print(item_translation)
    mid_translation = flatten([item['selectOptions']['options'] for item in item_translation if item['displayName'] == sign_field])
#     print(mid_translation)
    final_translation = {item['name']: item['value'] for item in mid_translation}
#     print(final_translation)
    return final_translation[value]

# %%
def get_value(field, occ, value):
    values = occ.form_fields['fields']
    item_translation = flatten([item['selectOptions']['options'] for item in values if item['displayName']==field])
#     print(item_translation)

    final_translation = {item['name']: item['value'] for item in item_translation}
#     print(final_translation)
    return final_translation[value]

# %% [markdown]
#  Verificando se está no ambiente de produção

# %%
# !cat .env
# Out:
# cat: .env: No such file or directory

# %% [markdown]
# Escolhendo nome do arquivo Excel para carregar o Inventário

# %%
filename='Sinalizacao Vertical_CSG_Kartado parte 1'
road_name='ERS-122'

# %% [markdown]
# Escolhendo a aba da planilha do Excel

# %%
wb = load_workbook(filename + '.xlsx')
sheetname = wb.sheetnames[1]
ws = wb[sheetname]
ws
# Out:
# /home/luan/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# <Worksheet "Sinalização Vertical">

# %% [markdown]
# Testando planilha carregada do Excel

# %%
print(ws['A1'].value)
# Out:
# Código do Inventário para vinculo com apontamento

# %% [markdown]
# Carregando os valores no script

# %%
header = []
values = []

for index, row in enumerate(ws.rows):
    if index == 0:
        header = list([a.value for a in row])
        continue
    obj = {}
    for col_index, cell in enumerate(row):
        value = cell.value
        obj[header[col_index]] = value
#     if obj['Rodovia'] is not None:           
   
#         obj['img'] = [a for a in ws._images if a.anchor._from.row == index]

#         try:
#             for a in obj['img']:
#                 a.name = 'CSG'
# #             obj['img'][0].name='Verso'
#         except:
#             pass

        
    values.append(obj)

# %% [markdown]
# Teste de valores importados da planilha

# %%
ficha_path = r'csg_monitoracao_2024/'

# %%
for a in values:
    a['img'] = []
#         print(a)
    for i in range(1,11):
        # Imagem Geral
        if a.get('Foto_'+str(i)) is not None:

            a['img'].append({
                'foto': ficha_path+a.get('Foto_'+str(i)),
                'data_foto': a.get('Data Foto_'+str(i)),
                'tipo_foto': a.get('Tipo Foto_'+str(i)),
                'des_foto': a.get('Descrição Foto_'+str(i))
            })

# %%
len(values),values[1]
# Out:
# (998,
#  {'Código do Inventário para vinculo com apontamento': None,
#   'Latitude': -29.664653479121625,
#   'Longitude': -51.26029604114592,
#   'km': '000+370',
#   'km final': None,
#   'km de Projeto': None,
#   'km final de Projeto': None,
#   'Status': 'Executado',
#   'Equipe': 'Egati',
#   'Encontrado em': None,
#   'Executado em': None,
#   'Prazo': None,
#   'Sentido': 'Crescente',
#   'Classe': 'Sinalização Vertical',
#   'Faixa': 'Não se aplica',
#   'Rodovia': 'ERS-122',
#   'Código': 'INDICATIVA',
#   'Lado': 'Esquerdo',
#   'Data da medição atual': datetime.datetime(2024, 1, 4, 0, 0),
#   'Fabricante': 'SINASC',
#   'Data de fabricação': datetime.datetime(2023, 10, 1, 0, 0),
#   'Tipo de suporte': 'PERFIL C METÁLICO',
#   'Estado do suporte': 'BOM',
#   'Observações': None,
#   'Monitoração': '1 MONITORAÇÃO',
#   'Recurso_1': None,
#   'Quantidade_1': None,
#   'Recurso_2': None,
#   'Quantidade_2': None,
#   'Recurso_3': None,
#   'Quantidade_3': None,
#   'Recurso_4': None,
#   'Quantidade_4': None,
#   'Recurso_5': None,
#   'Quantidade_5': None,
#   'Recurso_6': None,
#   'Quantidade_6': None,
#   'Recurso_7': None,
#   'Quantidade_7': None,
#   'Recurso_8': None,
#   'Quantidade_8': None,
#   'Recurso_9': None,
#   'Quantidade_9': None,
#   'Recurso_10': None,
#   'Quantidade_10': None,
#   'Foto_1': 'Vertical_000+340_409_CaminhosDaSerraGaucha_20231104_081132.jpg',
#   'Data Foto_1': None,
#   'Tipo Foto_1': None,
#   'Descrição Foto_1': None,
#   'Foto_2': 'Vertical_000+340_409_CaminhosDaSerraGaucha_20231104_081141.jpg',
#   'Data Foto_2': None,
#   'Tipo Foto_2': None,
#   'Descrição Foto_2': None,
#   'Foto_3': 'Vertical_000+340_409_CaminhosDaSerraGaucha_20231104_081151.jpg',
#   'Data Foto_3': None,
#   'Tipo Foto_3': None,
#   'Descrição Foto_3': None,
#   'Foto_4': 'Vertical_000+340_409_CaminhosDaSerraGaucha_20231104_081159.jpg',
#   'Data Foto_4': None,
#   'Tipo Foto_4': None,
#   'Descrição Foto_4': None,
#   'Foto_5': None,
#   'Data Foto_5': None,
#   'Tipo Foto_5': None,
#   'Descrição Foto_5': None,
#   'Foto_6': None,
#   'Data Foto_6': None,
#   'Tipo Foto_6': None,
#   'Descrição Foto_6': None,
#   'Foto_7': None,
#   'Data Foto_7': None,
#   'Tipo Foto_7': None,
#   'Descrição Foto_7': None,
#   'Foto_8': None,
#   'Data Foto_8': None,
#   'Tipo Foto_8': None,
#   'Descrição Foto_8': None,
#   'Foto_9': None,
#   'Data Foto_9': None,
#   'Tipo Foto_9': None,
#   'Descrição Foto_9': None,
#   'Foto_10': None,
#   'Data Foto_10': None,
#   'Tipo Foto_10': None,
#   'Descrição Foto_10': None,
#   'Retrorrefletância_1: Cor': 'Verde',
#   'Retrorrefletância_1: Tipo de Película': 'III',
#   'Retrorrefletância_1: Leitura 1 (cd/lx/m²)': 273,
#   'Retrorrefletância_1: Leitura 2 (cd/lx/m²)': 273,
#   'Retrorrefletância_1: Leitura 3 (cd/lx/m²)': 273,
#   'Retrorrefletância_1: Leitura 4 (cd/lx/m²)': 261,
#   'Retrorrefletância_1: Leitura 5 (cd/lx/m²)': 284,
#   'Retrorrefletância_1: Média das leituras': 272.8,
#   'Retrorrefletância_1: Valor Inicial': 50,
#   'Retrorrefletância_1: Valor Residual': 40,
#   'Retrorrefletância_2: Cor': 'Branco',
#   'Retrorrefletância_2: Tipo de Película': 'X',
#   'Retrorrefletância_2: Leitura 1 (cd/lx/m²)': 1335,
#   'Retrorrefletância_2: Leitura 2 (cd/lx/m²)': 1441,
#   'Retrorrefletância_2: Leitura 3 (cd/lx/m²)': 1441,
#   'Retrorrefletância_2: Leitura 4 (cd/lx/m²)': 1441,
#   'Retrorrefletância_2: Leitura 5 (cd/lx/m²)': 1441,
#   'Retrorrefletância_2: Média das leituras': 1419.8,
#   'Retrorrefletância_2: Valor Inicial': 580,
#   'Retrorrefletância_2: Valor Residual': 464,
#   'Retrorrefletância_3: Cor': None,
#   'Retrorrefletância_3: Tipo de Película': None,
#   'Retrorrefletância_3: Leitura 1 (cd/lx/m²)': None,
#   'Retrorrefletância_3: Leitura 2 (cd/lx/m²)': None,
#   'Retrorrefletância_3: Leitura 3 (cd/lx/m²)': None,
#   'Retrorrefletância_3: Leitura 4 (cd/lx/m²)': None,
#   'Retrorrefletância_3: Leitura 5 (cd/lx/m²)': None,
#   'Retrorrefletância_3: Média das leituras': None,
#   'Retrorrefletância_3: Valor Inicial': None,
#   'Retrorrefletância_3: Valor Residual': None,
#   'Retrorrefletância_4: Cor': None,
#   'Retrorrefletância_4: Tipo de Película': None,
#   'Retrorrefletância_4: Leitura 1 (cd/lx/m²)': None,
#   'Retrorrefletância_4: Leitura 2 (cd/lx/m²)': None,
#   'Retrorrefletância_4: Leitura 3 (cd/lx/m²)': None,
#   'Retrorrefletância_4: Leitura 4 (cd/lx/m²)': None,
#   'Retrorrefletância_4: Leitura 5 (cd/lx/m²)': None,
#   'Retrorrefletância_4: Média das leituras': None,
#   'Retrorrefletância_4: Valor Inicial': None,
#   'Retrorrefletância_4: Valor Residual': None,
#   'Retrorrefletância_5: Cor': None,
#   'Retrorrefletância_5: Tipo de Película': None,
#   'Retrorrefletância_5: Leitura 1 (cd/lx/m²)': None,
#   'Retrorrefletância_5: Leitura 2 (cd/lx/m²)': None,
#   'Retrorrefletância_5: Leitura 3 (cd/lx/m²)': None,
#   'Retrorrefletância_5: Leitura 4 (cd/lx/m²)': None,
#   'Retrorrefletância_5: Leitura 5 (cd/lx/m²)': None,
#   'Retrorrefletância_5: Média das leituras': None,
#   'Retrorrefletância_5: Valor Inicial': None,
#   'Retrorrefletância_5: Valor Residual': None,
#   'Retrorrefletância_6: Cor': None,
#   'Retrorrefletância_6: Tipo de Película': None,
#   'Retrorrefletância_6: Leitura 1 (cd/lx/m²)': None,
#   'Retrorrefletância_6: Leitura 2 (cd/lx/m²)': None,
#   'Retrorrefletância_6: Leitura 3 (cd/lx/m²)': None,
#   'Retrorrefletância_6: Leitura 4 (cd/lx/m²)': None,
#   'Retrorrefletância_6: Leitura 5 (cd/lx/m²)': None,
#   'Retrorrefletância_6: Média das leituras': None,
#   'Retrorrefletância_6: Valor Inicial': None,
#   'Retrorrefletância_6: Valor Residual': None,
#   'Retrorrefletância_7: Cor': None,
#   'Retrorrefletância_7: Tipo de Película': None,
#   'Retrorrefletância_7: Leitura 1 (cd/lx/m²)': None,
#   'Retrorrefletância_7: Leitura 2 (cd/lx/m²)': None,
#   'Retrorrefletância_7: Leitura 3 (cd/lx/m²)': None,
#   'Retrorrefletância_7: Leitura 4 (cd/lx/m²)': None,
#   'Retrorrefletância_7: Leitura 5 (cd/lx/m²)': None,
#   'Retrorrefletância_7: Média das leituras': None,
#   'Retrorrefletância_7: Valor Inicial': None,
#   'Retrorrefletância_7: Valor Residual': None,
#   'Retrorrefletância_8: Cor': None,
#   'Retrorrefletância_8: Tipo de Película': None,
#   'Retrorrefletância_8: Leitura 1 (cd/lx/m²)': None,
#   'Retrorrefletância_8: Leitura 2 (cd/lx/m²)': None,
#   'Retrorrefletância_8: Leitura 3 (cd/lx/m²)': None,
#   'Retrorrefletância_8: Leitura 4 (cd/lx/m²)': None,
#   'Retrorrefletância_8: Leitura 5 (cd/lx/m²)': None,
#   'Retrorrefletância_8: Média das leituras': None,
#   'Retrorrefletância_8: Valor Inicial': None,
#   'Retrorrefletância_8: Valor Residual': None,
#   'Retrorrefletância_9: Cor': None,
#   'Retrorrefletância_9: Tipo de Película': None,
#   'Retrorrefletância_9: Leitura 1 (cd/lx/m²)': None,
#   'Retrorrefletância_9: Leitura 2 (cd/lx/m²)': None,
#   'Retrorrefletância_9: Leitura 3 (cd/lx/m²)': None,
#   'Retrorrefletância_9: Leitura 4 (cd/lx/m²)': None,
#   'Retrorrefletância_9: Leitura 5 (cd/lx/m²)': None,
#   'Retrorrefletância_9: Média das leituras': None,
#   'Retrorrefletância_9: Valor Inicial': None,
#   'Retrorrefletância_9: Valor Residual': None,
#   'Retrorrefletância_10: Cor': None,
#   'Retrorrefletância_10: Tipo de Película': None,
#   'Retrorrefletância_10: Leitura 1 (cd/lx/m²)': None,
#   'Retrorrefletância_10: Leitura 2 (cd/lx/m²)': None,
#   'Retrorrefletância_10: Leitura 3 (cd/lx/m²)': None,
#   'Retrorrefletância_10: Leitura 4 (cd/lx/m²)': None,
#   'Retrorrefletância_10: Leitura 5 (cd/lx/m²)': None,
#   'Retrorrefletância_10: Média das leituras': None,
#   'Retrorrefletância_10: Valor Inicial': None,
#   'Retrorrefletância_10: Valor Residual': None,
#   'img': [{'foto': 'csg_monitoracao_2024/Vertical_000+340_409_CaminhosDaSerraGaucha_20231104_081132.jpg',
#     'data_foto': None,
#     'tipo_foto': None,
#     'des_foto': None},
#    {'foto': 'csg_monitoracao_2024/Vertical_000+340_409_CaminhosDaSerraGaucha_20231104_081141.jpg',
#     'data_foto': None,
#     'tipo_foto': None,
#     'des_foto': None},
#    {'foto': 'csg_monitoracao_2024/Vertical_000+340_409_CaminhosDaSerraGaucha_20231104_081151.jpg',
#     'data_foto': None,
#     'tipo_foto': None,
#     'des_foto': None},
#    {'foto': 'csg_monitoracao_2024/Vertical_000+340_409_CaminhosDaSerraGaucha_20231104_081159.jpg',
#     'data_foto': None,
#     'tipo_foto': None,
#     'des_foto': None}]})

# %% [markdown]
# Definindo valores da importação

# %%
# company = Company.objects.get(name='Caminhos da Serra Gaúcha')
company = Company.objects.get(name='Caminhos da Serra Gaúcha')
firm=Firm.objects.get(uuid='7e50d5c5-4019-4165-ab39-39782fec0118')
#Classe Sinalização Vertical
occurrence_type=OccurrenceType.objects.get(uuid='eb083398-37d5-43a0-b245-423d3c847afe')

user=User.objects.get(username='rlcs')
status=ServiceOrderActionStatus.objects.get(companies=company, name='Executado')
# step=ApprovalStep.objects.get(approval_flow__company=company, name='Em Elaboração')
# firm=Firm.objects.get(uuid='0edd2ecc-8d5e-4444-898b-0069a3e9c354')

sign_name='Retrorrefletância'
company,occurrence_type,firm
# Out:
# (<Company: 4edb7778-e350-4e77-8e1e-de5f87b1da7f: Caminhos da Serra Gaúcha>,
#  <OccurrenceType: Sinalização Vertical - ['Demo Concessionárias', 'Caminhos da Serra Gaúcha']>,
#  <Firm: [4edb7778-e350-4e77-8e1e-de5f87b1da7f: Caminhos da Serra Gaúcha] 7e50d5c5-4019-4165-ab39-39782fec0118: Egati>)

# %%
# for a in tqdm(values):
#     a['Retrorrefletância'] = list(filter(None, [{'color': get_sign(sign_name,'Cor',occurrence_type,a['Cor_1'].capitalize()) if a['Cor_1'] is not None else None, 'first': a['Leitura 1 (cd/lx/m2)_1'], 'second': a['Leitura 2 (cd/lx/m2)_1'], 'third': a['Leitura 3 (cd/lx/m2)_1'], 'fourth': a['Leitura 4 (cd/lx/m2)_1'], 'fifth': a['Leitura 5 (cd/lx/m2)_1'], 'average': a['Média das leituras_1'], 'initial_value': a['Valor Inicial_1'], 'residual_value': a['Valor Residual_1']} if a['Cor_1'] is not None else None,
#                                   {'color': get_sign(sign_name,'Cor',occurrence_type,a['Cor_2'].capitalize()) if a['Cor_2'] is not None else None, 'first': a['Leitura 1 (cd/lx/m2)_2'], 'second': a['Leitura 2 (cd/lx/m2)_2'], 'third': a['Leitura 3 (cd/lx/m2)_2'], 'fourth': a['Leitura 4 (cd/lx/m2)_2'], 'fifth': a['Leitura 5 (cd/lx/m2)_2'], 'average': a['Média das leituras_2'], 'initial_value': a['Valor Inicial_2'], 'residual_value': a['Valor Residual_2']} if a['Cor_2'] is not None else None,
#                                   {'color': get_sign(sign_name,'Cor',occurrence_type,a['Cor_3'].capitalize()) if a['Cor_3'] is not None else None, 'first': a['Leitura 1 (cd/lx/m2)_3'], 'second': a['Leitura 2 (cd/lx/m2)_3'], 'third': a['Leitura 3 (cd/lx/m2)_3'], 'fourth': a['Leitura 4 (cd/lx/m2)_3'], 'fifth': a['Leitura 5 (cd/lx/m2)_3'], 'average': a['Média das leituras_3'], 'initial_value': a['Valor Inicial_3'], 'residual_value': a['Valor Residual_3']} if a['Cor_3'] is not None else None]))

# %%
for a in occurrence_type.form_fields['fields']:
    print(a['apiName'])
    if a['dataType'] == 'arrayOfObjects':
        for inner in a['innerFields']:
            print('\t',inner['apiName'],inner['displayName'])
# Out:
# code
# side
# datemeasurement
# manufacturer
# datemanufacture
# typesupport
# statesupport
# retro
# 	 color Cor
# 	 typeOfFilm Tipo de Película
# 	 first Leitura 1 (cd/lx/m²)
# 	 second Leitura 2 (cd/lx/m²)
# 	 third Leitura 3 (cd/lx/m²)
# 	 fourth Leitura 4 (cd/lx/m²)
# 	 fifth Leitura 5 (cd/lx/m²)
# 	 average Média das leituras
# 	 initialValue Valor Inicial
# 	 residualValue Valor Residual
# notes
# monitoringId

# %%
# verifica se cada uma das chaves 'Cor_1', 'Cor_2' e 'Cor_3' está presente e não é None antes de tentar acessar

for a in tqdm(values):
    retrorrefletancia_list = []
    
    if 'Retrorrefletância_1: Cor' in a.keys() and a['Retrorrefletância_1: Cor'] is not None:
        retrorrefletancia_list.append({'color': get_sign(sign_name, 'Cor', occurrence_type, a['Retrorrefletância_1: Cor'].capitalize()),
                                       'first': a['Retrorrefletância_1: Leitura 1 (cd/lx/m²)'],
                                       'second': a['Retrorrefletância_1: Leitura 2 (cd/lx/m²)'],
                                       'third': a['Retrorrefletância_1: Leitura 3 (cd/lx/m²)'],
                                       'fourth': a['Retrorrefletância_1: Leitura 4 (cd/lx/m²)'],
                                       'fifth': a['Retrorrefletância_1: Leitura 5 (cd/lx/m²)'],
                                       'average': a['Retrorrefletância_1: Média das leituras'],
                                       'initial_value': a['Retrorrefletância_1: Valor Inicial'],
                                       'residual_value': a['Retrorrefletância_1: Valor Residual'],
                                      'type_of_film': get_sign(sign_name, 'Tipo de Película', occurrence_type, a['Retrorrefletância_1: Tipo de Película'])})
    
#     if 'Retrorrefletância_2: Cor' in a.keys() and a['Retrorrefletância_2: Cor'] is not None:
#         retrorrefletancia_list.append({'color': get_sign(sign_name, 'Cor', occurrence_type, a['Cor_2'].capitalize()),
#                                        'first': a['Leitura 1 (cd/lx/m2)_2'],
#                                        'second': a['Leitura 2 (cd/lx/m2)_2'],
#                                        'third': a['Leitura 3 (cd/lx/m2)_2'],
#                                        'fourth': a['Leitura 4 (cd/lx/m2)_2'],
#                                        'fifth': a['Leitura 5 (cd/lx/m2)_2'],
#                                        'average': a['Média das leituras_2'],
#                                        'initial_value': a['Valor Inicial_2'],
#                                        'residual_value': a['Valor Residual_2']})
    
#     if 'Retrorrefletância_3: Cor' in a.keys() and a['Retrorrefletância_3: Cor'] is not None:
#         retrorrefletancia_list.append({'color': get_sign(sign_name, 'Cor', occurrence_type, a['Cor_3'].capitalize()),
#                                        'first': a['Leitura 1 (cd/lx/m2)_3'],
#                                        'second': a['Leitura 2 (cd/lx/m2)_3'],
#                                        'third': a['Leitura 3 (cd/lx/m2)_3'],
#                                        'fourth': a['Leitura 4 (cd/lx/m2)_3'],
#                                        'fifth': a['Leitura 5 (cd/lx/m2)_3'],
#                                        'average': a['Média das leituras_3'],
#                                        'initial_value': a['Valor Inicial_3'],
#                                        'residual_value': a['Valor Residual_3']})
    
    a['Retrorrefletância'] = list(filter(None, retrorrefletancia_list))
# Out:
#   0%|          | 0/998 [00:00<?, ?it/s]

# %% [markdown]
# Criando itens de Inventário

# %%
values[0]
# Out:
# {'Código do Inventário para vinculo com apontamento': None,
#  'Latitude': -29.66598406434059,
#  'Longitude': -51.257022907957435,
#  'km': '000+000',
#  'km final': None,
#  'km de Projeto': None,
#  'km final de Projeto': None,
#  'Status': 'Executado',
#  'Equipe': 'Egati',
#  'Encontrado em': None,
#  'Executado em': None,
#  'Prazo': None,
#  'Sentido': 'Crescente',
#  'Classe': 'Sinalização Vertical',
#  'Faixa': 'Não se aplica',
#  'Rodovia': 'ERS-122',
#  'Código': 'M.K.',
#  'Lado': 'Esquerdo',
#  'Data da medição atual': datetime.datetime(2024, 1, 4, 0, 0),
#  'Fabricante': 'FS METAL',
#  'Data de fabricação': None,
#  'Tipo de suporte': 'POSTE MADEIRA RETÂNGULAR',
#  'Estado do suporte': 'BOM',
#  'Observações': None,
#  'Monitoração': '1 MONITORAÇÃO',
#  'Recurso_1': None,
#  'Quantidade_1': None,
#  'Recurso_2': None,
#  'Quantidade_2': None,
#  'Recurso_3': None,
#  'Quantidade_3': None,
#  'Recurso_4': None,
#  'Quantidade_4': None,
#  'Recurso_5': None,
#  'Quantidade_5': None,
#  'Recurso_6': None,
#  'Quantidade_6': None,
#  'Recurso_7': None,
#  'Quantidade_7': None,
#  'Recurso_8': None,
#  'Quantidade_8': None,
#  'Recurso_9': None,
#  'Quantidade_9': None,
#  'Recurso_10': None,
#  'Quantidade_10': None,
#  'Foto_1': 'Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073011.jpg',
#  'Data Foto_1': None,
#  'Tipo Foto_1': None,
#  'Descrição Foto_1': None,
#  'Foto_2': 'Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073024.jpg',
#  'Data Foto_2': None,
#  'Tipo Foto_2': None,
#  'Descrição Foto_2': None,
#  'Foto_3': 'Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073035.jpg',
#  'Data Foto_3': None,
#  'Tipo Foto_3': None,
#  'Descrição Foto_3': None,
#  'Foto_4': 'Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073042.jpg',
#  'Data Foto_4': None,
#  'Tipo Foto_4': None,
#  'Descrição Foto_4': None,
#  'Foto_5': 'Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073100.jpg',
#  'Data Foto_5': None,
#  'Tipo Foto_5': None,
#  'Descrição Foto_5': None,
#  'Foto_6': None,
#  'Data Foto_6': None,
#  'Tipo Foto_6': None,
#  'Descrição Foto_6': None,
#  'Foto_7': None,
#  'Data Foto_7': None,
#  'Tipo Foto_7': None,
#  'Descrição Foto_7': None,
#  'Foto_8': None,
#  'Data Foto_8': None,
#  'Tipo Foto_8': None,
#  'Descrição Foto_8': None,
#  'Foto_9': None,
#  'Data Foto_9': None,
#  'Tipo Foto_9': None,
#  'Descrição Foto_9': None,
#  'Foto_10': None,
#  'Data Foto_10': None,
#  'Tipo Foto_10': None,
#  'Descrição Foto_10': None,
#  'Retrorrefletância_1: Cor': 'Azul',
#  'Retrorrefletância_1: Tipo de Película': 'X',
#  'Retrorrefletância_1: Leitura 1 (cd/lx/m²)': 133,
#  'Retrorrefletância_1: Leitura 2 (cd/lx/m²)': 124,
#  'Retrorrefletância_1: Leitura 3 (cd/lx/m²)': 131,
#  'Retrorrefletância_1: Leitura 4 (cd/lx/m²)': 122,
#  'Retrorrefletância_1: Leitura 5 (cd/lx/m²)': 126,
#  'Retrorrefletância_1: Média das leituras': 127.2,
#  'Retrorrefletância_1: Valor Inicial': 26,
#  'Retrorrefletância_1: Valor Residual': 20.8,
#  'Retrorrefletância_2: Cor': 'Branco',
#  'Retrorrefletância_2: Tipo de Película': 'X',
#  'Retrorrefletância_2: Leitura 1 (cd/lx/m²)': 1576,
#  'Retrorrefletância_2: Leitura 2 (cd/lx/m²)': 1522,
#  'Retrorrefletância_2: Leitura 3 (cd/lx/m²)': 1522,
#  'Retrorrefletância_2: Leitura 4 (cd/lx/m²)': 1522,
#  'Retrorrefletância_2: Leitura 5 (cd/lx/m²)': 1522,
#  'Retrorrefletância_2: Média das leituras': 1532.8,
#  'Retrorrefletância_2: Valor Inicial': 580,
#  'Retrorrefletância_2: Valor Residual': 464,
#  'Retrorrefletância_3: Cor': None,
#  'Retrorrefletância_3: Tipo de Película': None,
#  'Retrorrefletância_3: Leitura 1 (cd/lx/m²)': None,
#  'Retrorrefletância_3: Leitura 2 (cd/lx/m²)': None,
#  'Retrorrefletância_3: Leitura 3 (cd/lx/m²)': None,
#  'Retrorrefletância_3: Leitura 4 (cd/lx/m²)': None,
#  'Retrorrefletância_3: Leitura 5 (cd/lx/m²)': None,
#  'Retrorrefletância_3: Média das leituras': None,
#  'Retrorrefletância_3: Valor Inicial': None,
#  'Retrorrefletância_3: Valor Residual': None,
#  'Retrorrefletância_4: Cor': None,
#  'Retrorrefletância_4: Tipo de Película': None,
#  'Retrorrefletância_4: Leitura 1 (cd/lx/m²)': None,
#  'Retrorrefletância_4: Leitura 2 (cd/lx/m²)': None,
#  'Retrorrefletância_4: Leitura 3 (cd/lx/m²)': None,
#  'Retrorrefletância_4: Leitura 4 (cd/lx/m²)': None,
#  'Retrorrefletância_4: Leitura 5 (cd/lx/m²)': None,
#  'Retrorrefletância_4: Média das leituras': None,
#  'Retrorrefletância_4: Valor Inicial': None,
#  'Retrorrefletância_4: Valor Residual': None,
#  'Retrorrefletância_5: Cor': None,
#  'Retrorrefletância_5: Tipo de Película': None,
#  'Retrorrefletância_5: Leitura 1 (cd/lx/m²)': None,
#  'Retrorrefletância_5: Leitura 2 (cd/lx/m²)': None,
#  'Retrorrefletância_5: Leitura 3 (cd/lx/m²)': None,
#  'Retrorrefletância_5: Leitura 4 (cd/lx/m²)': None,
#  'Retrorrefletância_5: Leitura 5 (cd/lx/m²)': None,
#  'Retrorrefletância_5: Média das leituras': None,
#  'Retrorrefletância_5: Valor Inicial': None,
#  'Retrorrefletância_5: Valor Residual': None,
#  'Retrorrefletância_6: Cor': None,
#  'Retrorrefletância_6: Tipo de Película': None,
#  'Retrorrefletância_6: Leitura 1 (cd/lx/m²)': None,
#  'Retrorrefletância_6: Leitura 2 (cd/lx/m²)': None,
#  'Retrorrefletância_6: Leitura 3 (cd/lx/m²)': None,
#  'Retrorrefletância_6: Leitura 4 (cd/lx/m²)': None,
#  'Retrorrefletância_6: Leitura 5 (cd/lx/m²)': None,
#  'Retrorrefletância_6: Média das leituras': None,
#  'Retrorrefletância_6: Valor Inicial': None,
#  'Retrorrefletância_6: Valor Residual': None,
#  'Retrorrefletância_7: Cor': None,
#  'Retrorrefletância_7: Tipo de Película': None,
#  'Retrorrefletância_7: Leitura 1 (cd/lx/m²)': None,
#  'Retrorrefletância_7: Leitura 2 (cd/lx/m²)': None,
#  'Retrorrefletância_7: Leitura 3 (cd/lx/m²)': None,
#  'Retrorrefletância_7: Leitura 4 (cd/lx/m²)': None,
#  'Retrorrefletância_7: Leitura 5 (cd/lx/m²)': None,
#  'Retrorrefletância_7: Média das leituras': None,
#  'Retrorrefletância_7: Valor Inicial': None,
#  'Retrorrefletância_7: Valor Residual': None,
#  'Retrorrefletância_8: Cor': None,
#  'Retrorrefletância_8: Tipo de Película': None,
#  'Retrorrefletância_8: Leitura 1 (cd/lx/m²)': None,
#  'Retrorrefletância_8: Leitura 2 (cd/lx/m²)': None,
#  'Retrorrefletância_8: Leitura 3 (cd/lx/m²)': None,
#  'Retrorrefletância_8: Leitura 4 (cd/lx/m²)': None,
#  'Retrorrefletância_8: Leitura 5 (cd/lx/m²)': None,
#  'Retrorrefletância_8: Média das leituras': None,
#  'Retrorrefletância_8: Valor Inicial': None,
#  'Retrorrefletância_8: Valor Residual': None,
#  'Retrorrefletância_9: Cor': None,
#  'Retrorrefletância_9: Tipo de Película': None,
#  'Retrorrefletância_9: Leitura 1 (cd/lx/m²)': None,
#  'Retrorrefletância_9: Leitura 2 (cd/lx/m²)': None,
#  'Retrorrefletância_9: Leitura 3 (cd/lx/m²)': None,
#  'Retrorrefletância_9: Leitura 4 (cd/lx/m²)': None,
#  'Retrorrefletância_9: Leitura 5 (cd/lx/m²)': None,
#  'Retrorrefletância_9: Média das leituras': None,
#  'Retrorrefletância_9: Valor Inicial': None,
#  'Retrorrefletância_9: Valor Residual': None,
#  'Retrorrefletância_10: Cor': None,
#  'Retrorrefletância_10: Tipo de Película': None,
#  'Retrorrefletância_10: Leitura 1 (cd/lx/m²)': None,
#  'Retrorrefletância_10: Leitura 2 (cd/lx/m²)': None,
#  'Retrorrefletância_10: Leitura 3 (cd/lx/m²)': None,
#  'Retrorrefletância_10: Leitura 4 (cd/lx/m²)': None,
#  'Retrorrefletância_10: Leitura 5 (cd/lx/m²)': None,
#  'Retrorrefletância_10: Média das leituras': None,
#  'Retrorrefletância_10: Valor Inicial': None,
#  'Retrorrefletância_10: Valor Residual': None,
#  'img': [{'foto': 'csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073011.jpg',
#    'data_foto': None,
#    'tipo_foto': None,
#    'des_foto': None},
#   {'foto': 'csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073024.jpg',
#    'data_foto': None,
#    'tipo_foto': None,
#    'des_foto': None},
#   {'foto': 'csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073035.jpg',
#    'data_foto': None,
#    'tipo_foto': None,
#    'des_foto': None},
#   {'foto': 'csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073042.jpg',
#    'data_foto': None,
#    'tipo_foto': None,
#    'des_foto': None},
#   {'foto': 'csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073100.jpg',
#    'data_foto': None,
#    'tipo_foto': None,
#    'des_foto': None}],
#  'Retrorrefletância': [{'color': '1',
#    'first': 133,
#    'second': 124,
#    'third': 131,
#    'fourth': 122,
#    'fifth': 126,
#    'average': 127.2,
#    'initial_value': 26,
#    'residual_value': 20.8,
#    'type_of_film': '4'}]}

# %%
objects=[]
linha=[]

for index, a in enumerate(tqdm(values)):
    km = float(a['km'].replace("+", "."))
    
#     long=str(a['Longitude_Inicial'])[:3]+'.'+str(a['Longitude_Inicial'])[3:]
#     lat=str(a['Latitude_Inicial'])[:3]+'.'+str(a['Latitude_Inicial'])[3:]
#     pista = 'Pista Dupla' if a['Pista'].strip().lower() == 'dupla' or a['Pista'] == 'Dupla' else 'Pista Simples'
#     road,_,point,km =point_to_km(float(long),float(lat),road_name)
    point, road = get_road_coordinates(a['Rodovia'].strip(), km, str(get_connected_reference(company, 'reporting', 'direction', a['Sentido'].capitalize())), company)
    if road_name not in road.name:
        print(f"Rodovia {road} - km:{km} - Linha: {index+2}")
    try:
        
        objects.append((Reporting(
                    company=company,
                    occurrence_type=occurrence_type,
#                     lane=str(get_connected_reference(company, 'reporting', 'lane', pista)),
                    lane=str(get_connected_reference(company, 'reporting', 'lane', a['Faixa'])),
                    road=road,
                    road_name=road.name,
                    direction=str(get_connected_reference(company, 'reporting', 'direction', a['Sentido'])),
#                     direction=str(get_connected_reference(company, 'reporting', 'direction', 'Não se aplica')),
                    created_by=user,
                    found_at=datetime.datetime(2024, 3, 20, 0, 0),
                    km=float(km),
#                     end_km=float(end_km) if a['Longitude_Final'] is not None and a['Latitude_Final'] else None,
                    point=point,
                    firm=firm,
                    status=status,
                    form_data={
                        'code': a['Código'] if a['Código'] is not None else '',
#                         'type_of_film': get_value('Tipo de Película',occurrence_type,a['Tipo de Película']) if a['Tipo de Película'] is not None else None,
                        'side': get_value('Lado',occurrence_type,str(a['Lado']).capitalize()) if a['Lado'] is not None else None,
                        'datemeasurement': a['Data da medição atual'].strftime('%Y-%m-%dT03:00:00.000Z') if a['Data da medição atual'] is not None and a['Data da medição atual'] != '' and a['Data da medição atual'] != 'A-52' else None,
                        'manufacturer': a['Fabricante'] if a['Fabricante'] is not None else None,
                        'datemanufacture': a["Data de fabricação"].strftime('%Y-%m-%dT03:00:00.000Z') if a['Data de fabricação'] is not None and a['Data de fabricação'] != '' else None,
#                         'datemanufacture': a['Data de fabricação'].strftime('%Y-%m-%dT03:00:00.000Z') if a['Data de fabricação'] is not None and a['Data de fabricação'] != '' else None,
                        'typesupport': a['Tipo de suporte'] if a['Tipo de suporte'] is not None else None,
                        'statesupport': a['Estado do suporte'] if a['Estado do suporte'] is not None else None,
                        'retro': a['Retrorrefletância'] if a['Retrorrefletância'] is not None else None,
                        'notes': a['Observações'] if a['Observações'] is not None else ''
                        
                    },
                    ),a['img']))
    except Exception as e:
        linha.append(index+2)
        print(f'Arquivo"{filename}" - Rodovia {road} - Km:{km} - Linha: {index+2} - {objects.eu(e)}')
# Out:
#   0%|          | 0/998 [00:00<?, ?it/s]

# %%
len(objects),objects[0][0].__dict__,objects[0][1]
# Out:
# (998,
#  {'_state': <django.db.models.base.ModelState at 0x7059c89fee50>,
#   'uuid': UUID('e9b446dd-d27d-4de7-bc1f-8cf8d3f41e38'),
#   'number': '',
#   'company_id': UUID('4edb7778-e350-4e77-8e1e-de5f87b1da7f'),
#   'road_name': 'ERS-122',
#   'road_id': 2059,
#   'km': 0.0,
#   'end_km': None,
#   'km_reference': None,
#   'project_km': 0,
#   'project_end_km': None,
#   'point': <Point object at 0x7059c92b7f10>,
#   'direction': '0',
#   'lane': '99',
#   'track': None,
#   'branch': None,
#   'address': {},
#   'created_by_id': UUID('508a66f3-3f58-4c4e-bc9a-fbba6078c02d'),
#   'firm_id': UUID('7e50d5c5-4019-4165-ab39-39782fec0118'),
#   'occurrence_type_id': UUID('eb083398-37d5-43a0-b245-423d3c847afe'),
#   'form_data': {'code': 'M.K.',
#    'side': '2',
#    'datemeasurement': '2024-01-04T03:00:00.000Z',
#    'manufacturer': 'FS METAL',
#    'datemanufacture': None,
#    'typesupport': 'POSTE MADEIRA RETÂNGULAR',
#    'statesupport': 'BOM',
#    'retro': [],
#    'notes': ''},
#   'form_metadata': {},
#   'executed_at': None,
#   'created_at': None,
#   'updated_at': None,
#   'found_at': datetime.datetime(2024, 3, 20, 0, 0),
#   'due_at': None,
#   'status_id': UUID('489214ee-02e9-4bae-9c53-6a641c517e7d'),
#   'job_id': None,
#   'parent_id': None,
#   'active_inspection_id': None,
#   'due_at_manually_specified': False,
#   'end_km_manually_specified': False,
#   'project_end_km_manually_specified': False,
#   'editable': True,
#   'approval_step_id': None,
#   'keywords': '',
#   'lot': None,
#   'technical_opinion': None,
#   'construction_id': None,
#   'pdf_import_id': None,
#   'shared_with_agency': False,
#   'created_recuperations_with_relation': None,
#   '_fieldsignals_originals': {(123531588976064,
#     123531133112176): {'uuid': UUID('e9b446dd-d27d-4de7-bc1f-8cf8d3f41e38'), 'number': '', 'company': UUID('4edb7778-e350-4e77-8e1e-de5f87b1da7f'), 'road_name': 'ERS-122', 'road': 2059, 'km': 0.0, 'project_km': 0.0, 'point': <Point object at 0x7059c92eb690>, 'direction': '0', 'lane': '99', 'address': {}, 'created_by': UUID('508a66f3-3f58-4c4e-bc9a-fbba6078c02d'), 'firm': UUID('7e50d5c5-4019-4165-ab39-39782fec0118'), 'occurrence_type': UUID('eb083398-37d5-43a0-b245-423d3c847afe'), 'form_data': {'code': 'M.K.',
#      'side': '2',
#      'datemeasurement': '2024-01-04T03:00:00.000Z',
#      'manufacturer': 'FS METAL',
#      'datemanufacture': None,
#      'typesupport': 'POSTE MADEIRA RETÂNGULAR',
#      'statesupport': 'BOM',
#      'retro': [],
#      'notes': ''}, 'form_metadata': {}, 'found_at': datetime.datetime(2024, 3, 20, 0, 0), 'status': UUID('489214ee-02e9-4bae-9c53-6a641c517e7d'), 'due_at_manually_specified': False, 'end_km_manually_specified': False, 'project_end_km_manually_specified': False, 'editable': True, 'keywords': '', 'shared_with_agency': False},
#    (123531588975968,
#     123531621808880): {'uuid': UUID('e9b446dd-d27d-4de7-bc1f-8cf8d3f41e38'), 'number': '', 'company': UUID('4edb7778-e350-4e77-8e1e-de5f87b1da7f'), 'road_name': 'ERS-122', 'road': 2059, 'km': 0.0, 'project_km': 0.0, 'point': <Point object at 0x7059c92b7d10>, 'direction': '0', 'lane': '99', 'address': {}, 'created_by': UUID('508a66f3-3f58-4c4e-bc9a-fbba6078c02d'), 'firm': UUID('7e50d5c5-4019-4165-ab39-39782fec0118'), 'occurrence_type': UUID('eb083398-37d5-43a0-b245-423d3c847afe'), 'form_data': {'code': 'M.K.',
#      'side': '2',
#      'datemeasurement': '2024-01-04T03:00:00.000Z',
#      'manufacturer': 'FS METAL',
#      'datemanufacture': None,
#      'typesupport': 'POSTE MADEIRA RETÂNGULAR',
#      'statesupport': 'BOM',
#      'retro': [],
#      'notes': ''}, 'form_metadata': {}, 'found_at': datetime.datetime(2024, 3, 20, 0, 0), 'status': UUID('489214ee-02e9-4bae-9c53-6a641c517e7d'), 'due_at_manually_specified': False, 'end_km_manually_specified': False, 'project_end_km_manually_specified': False, 'editable': True, 'keywords': '', 'shared_with_agency': False}}},
#  [{'foto': 'csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073011.jpg',
#    'data_foto': None,
#    'tipo_foto': None,
#    'des_foto': None},
#   {'foto': 'csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073024.jpg',
#    'data_foto': None,
#    'tipo_foto': None,
#    'des_foto': None},
#   {'foto': 'csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073035.jpg',
#    'data_foto': None,
#    'tipo_foto': None,
#    'des_foto': None},
#   {'foto': 'csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073042.jpg',
#    'data_foto': None,
#    'tipo_foto': None,
#    'des_foto': None},
#   {'foto': 'csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073100.jpg',
#    'data_foto': None,
#    'tipo_foto': None,
#    'des_foto': None}])

# %% [markdown]
# # Script seguinte ira salvar os dados no bd

# %%
from django.db import transaction
import uuid

# %%
fotos_apt=[]
apt=[]
for reporting, images in tqdm(objects):
    apt.append(reporting)
    for image in images:
        reporting_file = ReportingFile(
            created_by=user,
            reporting=reporting,
            description=image.get('des_foto') if image.get('des_foto') else 'CSG',
            datetime=image.get('data_foto', datetime.datetime(2000, 1, 1, 0, 0)) if isinstance(image.get('data_foto'), datetime.datetime) else datetime.datetime(2000, 1, 1, 0, 0),
            kind=image.get('tipo_foto', 'outro').lower() if image.get('tipo_foto') is not None else 'outro',
            km=reporting.km,
            is_shared=False,
            point=reporting.point,
            upload=image.get('foto')
        )
        try:
            reporting_file.upload.size
            fotos_apt.append(reporting_file)
#             reporting_file.save()
        except Exception as e:
            print(reporting, reporting_file, e)
# print(reporting.number)
# Out:
#   0%|          | 0/998 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6053/2158150312.py in <cell line: 3>()
#      16         )
#      17         try:
# ---> 18             reporting_file.upload.size
#      19             fotos_apt.append(reporting_file)
#      20 #             reporting_file.save()
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/models/fields/files.py in size(self)
#      68         if not self._committed:
#      69             return self.file.size
# ---> 70         return self.storage.size(self.name)
#      71
#      72     def open(self, mode='rb'):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/storages/backends/s3boto3.py in size(self, name)
#     548                 return entry.size if hasattr(entry, 'size') else entry.content_length
#     549             return 0
# --> 550         return self.bucket.Object(self._encode_name(name)).content_length
#     551
#     552     def get_modified_time(self, name):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/boto3/resources/factory.py in property_loader(self)
#     337             if self.meta.data is None:
#     338                 if hasattr(self, 'load'):
# --> 339                     self.load()
#     340                 else:
#     341                     raise ResourceLoadException(
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/boto3/resources/factory.py in do_action(self, *args, **kwargs)
#     503             # instance via ``self``.
#     504             def do_action(self, *args, **kwargs):
# --> 505                 response = action(self, *args, **kwargs)
#     506                 self.meta.data = response
#     507             # Create the docstring for the load/reload mehtods.
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/boto3/resources/action.py in __call__(self, parent, *args, **kwargs)
#      81                     operation_name, params)
#      82
# ---> 83         response = getattr(parent.meta.client, operation_name)(*args, **params)
#      84
#      85         logger.debug('Response: %r', response)
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     384                     "%s() only accepts keyword arguments." % py_operation_name)
#     385             # The "self" in this scope is referring to the BaseClient.
# --> 386             return self._make_api_call(operation_name, kwargs)
#     387
#     388         _api_call.__name__ = str(py_operation_name)
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     689             http, parsed_response = event_response
#     690         else:
# --> 691             http, parsed_response = self._make_request(
#     692                 operation_model, request_dict, request_context)
#     693
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     709     def _make_request(self, operation_model, request_dict, request_context):
#     710         try:
# --> 711             return self._endpoint.make_request(operation_model, request_dict)
#     712         except Exception as e:
#     713             self.meta.events.emit(
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     132         request = self.create_request(request_dict, operation_model)
#     133         context = request_dict['context']
# --> 134         success_response, exception = self._get_response(
#     135             request, operation_model, context)
#     136         while self._needs_retry(attempts, operation_model, request_dict,
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/botocore/endpoint.py in _get_response(self, request, operation_model, context)
#     164         # If an exception occurs then the success_response is None.
#     165         # If no exception occurs then exception is None.
# --> 166         success_response, exception = self._do_get_response(
#     167             request, operation_model)
#     168         kwargs_to_emit = {
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/botocore/endpoint.py in _do_get_response(self, request, operation_model)
#     198             http_response = first_non_none_response(responses)
#     199             if http_response is None:
# --> 200                 http_response = self._send(request)
#     201         except HTTPClientError as e:
#     202             return (None, e)
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/botocore/endpoint.py in _send(self, request)
#     267
#     268     def _send(self, request):
# --> 269         return self.http_session.send(request)
#     270
#     271
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/botocore/httpsession.py in send(self, request)
#     321
#     322             request_target = self._get_request_target(request.url, proxy_url)
# --> 323             urllib_response = conn.urlopen(
#     324                 method=request.method,
#     325                 url=request_target,
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712
#     713             # Make the request on the httplib connection object.
# --> 714             httplib_response = self._make_request(
#     715                 conn,
#     716                 method,
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     464                     # Python 3 (including for exceptions like SystemExit).
#     465                     # Otherwise it looks like a bug in the code.
# --> 466                     six.raise_from(e, None)
#     467         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459                 # Python 3
#     460                 try:
# --> 461                     httplib_response = conn.getresponse()
#     462                 except BaseException as e:
#     463                     # Remove the TypeError from the exception chain in
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/sentry_sdk/integrations/stdlib.py in getresponse(self, *args, **kwargs)
#     108             return real_getresponse(self, *args, **kwargs)
#     109
# --> 110         rv = real_getresponse(self, *args, **kwargs)
#     111
#     112         span.set_data("status_code", rv.status)
#
# ~/.pyenv/versions/3.8.16/lib/python3.8/http/client.py in getresponse(self)
#    1346         try:
#    1347             try:
# -> 1348                 response.begin()
#    1349             except ConnectionError:
#    1350                 self.close()
#
# ~/.pyenv/versions/3.8.16/lib/python3.8/http/client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# ~/.pyenv/versions/3.8.16/lib/python3.8/http/client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# ~/.pyenv/versions/3.8.16/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/.pyenv/versions/3.8.16/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/.pyenv/versions/3.8.16/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
len(apt),len(fotos_apt),fotos_apt[0].__dict__
# Out:
# (998,
#  3556,
#  {'_state': <django.db.models.base.ModelState at 0x7dd5b49b9370>,
#   'uuid': UUID('c8f6496e-1155-4a2d-a12d-30e604fc6e87'),
#   'reporting_id': UUID('5b50913c-de5e-4e52-b94e-96bd6fb0cff6'),
#   'description': None,
#   'md5': '',
#   'upload': <FieldFile: csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_20231104_073011.jpg>,
#   'uploaded_at': datetime.datetime(2024, 3, 21, 13, 13, 10, 309819, tzinfo=<UTC>),
#   'datetime': datetime.datetime(2000, 1, 1, 0, 0),
#   'created_by_id': UUID('508a66f3-3f58-4c4e-bc9a-fbba6078c02d'),
#   'include_dnit': True,
#   'include_rdo': False,
#   'km': 0.0,
#   'point': <Point object at 0x7dd5bd1dd510>,
#   'kind': 'outro',
#   'is_shared': False})

# %%
fot = bulk_create_with_history(fotos_apt, ReportingFile, default_user=user)
apontamentos = bulk_update_with_history(apt,Reporting, use_django_bulk=True,batch_size=100,user=user)
# Out:
# /home/luan/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1424: RuntimeWarning: DateTimeField ReportingFile.datetime received a naive datetime (2000-01-01 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# ---------------------------------------------------------------------------
# NotNullViolation                          Traceback (most recent call last)
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#
# NotNullViolation: null value in column "description" violates not-null constraint
# DETAIL:  Failing row contains (c8f6496e-1155-4a2d-a12d-30e604fc6e87, null, csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_..., 2024-03-21 13:13:10.309819+00, 508a66f3-3f58-4c4e-bc9a-fbba6078c02d, 5b50913c-de5e-4e52-b94e-96bd6fb0cff6, t, 0, 0101000020E610000011108EC3DEA049C07B7D3EB28AAA3DC0, f, 2000-01-01 02:00:00+00, , outro, f).
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# /tmp/ipykernel_5401/1756578040.py in <cell line: 1>()
# ----> 1 fot = bulk_create_with_history(fotos_apt, ReportingFile, default_user=user)
#       2 apontamentos = bulk_update_with_history(apt,Reporting, use_django_bulk=True,batch_size=100,user=user)
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/simple_history/utils.py in bulk_create_with_history(objs, model, batch_size, default_user, default_change_reason, default_date)
#      83     second_transaction_required = True
#      84     with transaction.atomic(savepoint=False):
# ---> 85         objs_with_id = model_manager.bulk_create(objs, batch_size=batch_size)
#      86         if objs_with_id and objs_with_id[0].pk:
#      87             second_transaction_required = False
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      80         def create_method(name, method):
#      81             def manager_method(self, *args, **kwargs):
# ---> 82                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      83             manager_method.__name__ = method.__name__
#      84             manager_method.__doc__ = method.__doc__
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/models/query.py in bulk_create(self, objs, batch_size, ignore_conflicts)
#     466             objs_with_pk, objs_without_pk = partition(lambda o: o.pk is None, objs)
#     467             if objs_with_pk:
# --> 468                 self._batched_insert(objs_with_pk, fields, batch_size, ignore_conflicts=ignore_conflicts)
#     469                 for obj_with_pk in objs_with_pk:
#     470                     obj_with_pk._state.adding = False
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/models/query.py in _batched_insert(self, objs, fields, batch_size, ignore_conflicts)
#    1200         for item in [objs[i:i + batch_size] for i in range(0, len(objs), batch_size)]:
#    1201             if bulk_return and not ignore_conflicts:
# -> 1202                 inserted_id = self._insert(
#    1203                     item, fields=fields, using=self.db, return_id=True,
#    1204                     ignore_conflicts=ignore_conflicts,
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/models/query.py in _insert(self, objs, fields, return_id, raw, using, ignore_conflicts)
#    1184         query = sql.InsertQuery(self.model, ignore_conflicts=ignore_conflicts)
#    1185         query.insert_values(fields, objs, raw=raw)
# -> 1186         return query.get_compiler(using=using).execute_sql(return_id)
#    1187     _insert.alters_data = True
#    1188     _insert.queryset_only = False
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/models/sql/compiler.py in execute_sql(self, return_id)
#    1375         with self.connection.cursor() as cursor:
#    1376             for sql, params in self.as_sql():
# -> 1377                 cursor.execute(sql, params)
#    1378             if not return_id:
#    1379                 return
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/sentry_sdk/integrations/django/__init__.py in execute(self, sql, params)
#     575             hub, self.cursor, sql, params, paramstyle="format", executemany=False
#     576         ):
# --> 577             return real_execute(self, sql, params)
#     578
#     579     def executemany(self, sql, param_list):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      65
#      66     def execute(self, sql, params=None):
# ---> 67         return self._execute_with_wrappers(sql, params, many=False, executor=self._execute)
#      68
#      69     def executemany(self, sql, param_list):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/backends/utils.py in _execute_with_wrappers(self, sql, params, many, executor)
#      74         for wrapper in reversed(self.db.execute_wrappers):
#      75             executor = functools.partial(wrapper, executor)
# ---> 76         return executor(sql, params, many, context)
#      77
#      78     def _execute(self, sql, params, *ignored_wrapper_args):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      82                 return self.cursor.execute(sql)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#      86     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/utils.py in __exit__(self, exc_type, exc_value, traceback)
#      87                 if dj_exc_type not in (DataError, IntegrityError):
#      88                     self.wrapper.errors_occurred = True
# ---> 89                 raise dj_exc_value.with_traceback(traceback) from exc_value
#      90
#      91     def __call__(self, func):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.8/lib/python3.8/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      82                 return self.cursor.execute(sql)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#      86     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# IntegrityError: null value in column "description" violates not-null constraint
# DETAIL:  Failing row contains (c8f6496e-1155-4a2d-a12d-30e604fc6e87, null, csg_monitoracao_2024/Vertical_000+000_409_CaminhosDaSerraGaucha_..., 2024-03-21 13:13:10.309819+00, 508a66f3-3f58-4c4e-bc9a-fbba6078c02d, 5b50913c-de5e-4e52-b94e-96bd6fb0cff6, t, 0, 0101000020E610000011108EC3DEA049C07B7D3EB28AAA3DC0, f, 2000-01-01 02:00:00+00, , outro, f).

# %%
ficha_path
# Out:
# 'csg_monitoracao_2024/'

# %% [markdown]
# Anexando as imagens

# %%
for reporting, images in tqdm(objects):
    for image in images:
        reporting_file = ReportingFile(
            created_by=user,
            reporting=reporting,
            description=image.name,
            km=reporting.km,
            point=reporting.point
        )
        reporting_file.save()
        image_io = BytesIO(image._data())
        im = Image.open(image_io)
        if im.mode in ("RGBA", "P"):
            im = im.convert("RGB")
        thumb_io = BytesIO()
        im.save(thumb_io, format='jpeg', quality=90)
        reporting_file.upload.save(image.name + '.jpeg', thumb_io)
# Out:
#   0%|          | 0/127 [00:00<?, ?it/s]

# %%
Reporting.objects.filter(company=company,occurrence_type=occurrence_type,road__name__contains='122').delete()
# Out:
# (10105, {'reportings.ReportingFile': 5061, 'reportings.Reporting': 5044})

# %%
for a in reps:
    print(a.number)
# Out:
# CSG-Inv-2023.02059
# CSG-Inv-2023.02060
# CSG-Inv-2023.02506
# CSG-Inv-2023.02535

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_58511/215739760.py in <module>
# ----> 1 pr=DailyReportContractUsage.objects.get(uuid="93a7c009-1791-4a48-afd4-61e8c7666535").count()
#
# AttributeError: 'DailyReportContractUsage' object has no attribute 'count'

# %%
# Out:
# (1, {'daily_reports.DailyReportContractUsage': 1})

# %%
company = Company.objects.get(name="Caminhos da Serra Gaúcha")

# %%
filename = "retificacaoPistaDupla122.xlsx"
wb = load_workbook(filename)
ws = wb[wb.sheetnames[1]]
ws
# Out:
# /home/luan/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# <Worksheet "Sinalização Vertical">

# %%
header = []
values = []

for index, row in enumerate(ws.rows):
    if index == 0:
        header = list([a.value for a in row])
        continue
    obj = {}
    for col_index, cell in enumerate(row):
        value = cell.value
        obj[header[col_index]] = value
    values.append(obj)
values[0]
# Out:
# {'km': None,
#  'km final': None,
#  'km de Projeto': None,
#  'km final de Projeto': None,
#  'Latitude_Inicial': -29.6650463888889,
#  'Longitude_Inicial': -51.258245,
#  'Latitude_Final': None,
#  'Longitude_Final': None,
#  'Status': 'Identificado',
#  'Equipe/Empreiteira': 'Cadastro incial',
#  'Encontrado em': None,
#  'Executado em': None,
#  'Sentido': 'Crescente',
#  'Pista': 'Dupla',
#  'Classe': 'Sinalização Vertical',
#  'Lado': 'Direito',
#  'Faixa': 'Não se aplica',
#  'Rodovia': 'ERS-122',
#  'Código': 'DEL',
#  'Data da medição atual': datetime.datetime(2023, 1, 19, 0, 0),
#  'Fabricante': 'SINARODO',
#  'Data de fabricação': None,
#  'Tipo de suporte': 'MADEIRA',
#  'Estado do suporte': 'DANIFICADO',
#  'Tipo de Película': 'I',
#  'Cor_1': 'AMARELO',
#  'Leitura 1 (cd/lx/m2)_1': 6.5,
#  'Leitura 2 (cd/lx/m2)_1': 4.5,
#  'Leitura 3 (cd/lx/m2)_1': 5.7,
#  'Leitura 4 (cd/lx/m2)_1': 5.4,
#  'Leitura 5 (cd/lx/m2)_1': 5,
#  'Média das leituras_1': 5.42,
#  'Valor mínimo_1': 50,
#  'Valor Residual_1': 25,
#  'Cor_2': None,
#  'Leitura 1 (cd/lx/m2)_2': None,
#  'Leitura 2 (cd/lx/m2)_2': None,
#  'Leitura 3 (cd/lx/m2)_2': None,
#  'Leitura 4 (cd/lx/m2)_2': None,
#  'Leitura 5 (cd/lx/m2)_2': None,
#  'Média das leituras_2': '',
#  'Valor mínimo_2': '',
#  'Valor Residual_2': '',
#  'Cor_3': None,
#  'Leitura 1 (cd/lx/m2)_3': None,
#  'Leitura 2 (cd/lx/m2)_3': None,
#  'Leitura 3 (cd/lx/m2)_3': None,
#  'Leitura 4 (cd/lx/m2)_3': None,
#  'Leitura 5 (cd/lx/m2)_3': None,
#  'Média das leituras_3': '',
#  'Valor mínimo_3': '',
#  'Valor Residual_3': '',
#  'Observações': 'PLACA TODA DESGASTADA',
#  'Data Foto_1': None,
#  'Tipo Foto_1': None,
#  'Descrição Foto_1': None,
#  'Foto_2': None,
#  'Data Foto_2': None,
#  'Tipo Foto_2': None,
#  'Descrição Foto_2': None,
#  'Foto_3': None,
#  'Data Foto_3': None,
#  'Tipo Foto_3': None,
#  'Descrição Foto_3': None,
#  'Foto_4': None,
#  'Data Foto_4': None,
#  'Tipo Foto_4': None,
#  'Descrição Foto_4': None,
#  'Foto_5': None,
#  'Data Foto_5': None,
#  'Tipo Foto_5': None,
#  'Descrição Foto_5': None,
#  'Foto_6': None,
#  'Data Foto_6': None,
#  'Tipo Foto_6': None,
#  'Descrição Foto_6': None,
#  'Foto_7': None,
#  'Data Foto_7': None,
#  'Tipo Foto_7': None,
#  'Descrição Foto_7': None,
#  'Foto_8': None,
#  'Data Foto_8': None,
#  'Tipo Foto_8': None,
#  'Descrição Foto_8': None,
#  'Foto_9': None,
#  'Data Foto_9': None,
#  'Tipo Foto_9': None,
#  'Descrição Foto_9': None,
#  'Foto_10': None,
#  'Data Foto_10': None,
#  'Tipo Foto_10': None,
#  'Descrição Foto_10': None}

# %%
road=Road.objects.get(id=2059)
road
# Out:
# <Road: 2059: ERS-122>

# %%
point_to_km(-51.0483375,-28.6201603,'122')
# Out:
# (<Road: 2104: ERS-122>, 'ERS-122', <Point object at 0x7fd091592370>, 167.745)

# %%
values[0]['Latitude_Inicial'],values[0]['Longitude_Inicial']
road,_,point,km =point_to_km(float(values[0]['Longitude_Inicial']),float(values[0]['Latitude_Inicial']),road)
road,point,km
# Out:
# (<Road: 2059: ERS-122>, <Point object at 0x7ffab6f0c400>, 0.195)

# %%
rep_edit=[]
rep_edit_filter=[]
for a in tqdm(values):
    road,_,point,km =point_to_km(float(a['Longitude_Inicial']),float(a['Latitude_Inicial']),road)
    direction = str(get_connected_reference(company, 'reporting', 'direction', a['Sentido']))
    lane='Pista Dupla' if a['Pista'].strip().lower() == 'dupla' or a['Pista'] == 'Dupla' else 'Pista Simples'
    
    try:
        rep = Reporting.objects.get(point=point,company=company,occurrence_type=occurrence_type)
    except:
        reps=Reporting.objects.filter(point=point,company=company,occurrence_type=occurrence_type)
        for b in reps:
            rep_edit_filter.append(b)
        
        
#     if '122' not in road.name:
#         rep.lane = str(get_connected_reference(company, 'reporting', 'lane', lane))
#         rep_edit.append(rep)
#         print(road,rep,km,a['Sentido'])
#     else:
#         try:
#             rep.lane = str(get_connected_reference(company, 'reporting', 'lane', lane))
#             rep.road=road
#             rep.road_name=road.name
#             rep_edit.append(rep)
#         except:
#             print(road,rep,km,direction,lane)
# Out:
#   0%|          | 0/5044 [00:00<?, ?it/s]

# %%
len(set(rep_edit_filter))
# Out:
# 2217

# %%
for c in rep_edit_filter:
    print(c)
# Out:
# [Caminhos da Serra Gaúcha] CSG-Inv-2023.
00:00
# [Caminhos da Serra Gaúcha] CSG-Inv-2023.11684 - 2023-06-26 16:37:26.448561+00:00
# [Caminhos da Serra Gaúcha] CSG-Inv-2023.11683 - 2023-06-26 16:37:24.780939+00:00

# %%
user=User.objects.get(username="rlcs")

# %%
apt=bulk_update_with_history(rep_edit,Reporting, use_django_bulk=True,batch_size=1250,user=user)

# %%
rep=Reporting.objects.filter(company=company,occurrence_type=occurrence_type, road__name__contains='122').filter(form_data__code='DEL').filter(form_data__typesupport='MADEIRA')

# %%
rep.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_109173/3236234301.py in <module>
# ----> 1 rep.count()
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/django/db/models/query.py in count(self)
#     390             return len(self._result_cache)
#     391
# --> 392         return self.query.get_count(using=self.db)
#     393
#     394     def get(self, *args, **kwargs):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/django/db/models/sql/query.py in get_count(self, using)
#     511         obj = self.clone()
#     512         obj.add_annotation(Count('*'), alias='__count', is_summary=True)
# --> 513         number = obj.get_aggregation(using, ['__count'])['__count']
#     514         if number is None:
#     515             number = 0
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/django/db/models/sql/query.py in get_aggregation(self, using, added_aggregate_names)
#     496         outer_query.select_related = False
#     497         compiler = outer_query.get_compiler(using)
# --> 498         result = compiler.execute_sql(SINGLE)
#     499         if result is None:
#     500             result = [None] * len(outer_query.annotation_select)
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/django/db/models/sql/compiler.py in execute_sql(self, result_type, chunked_fetch, chunk_size)
#    1140             cursor = self.connection.cursor()
#    1141         try:
# -> 1142             cursor.execute(sql, params)
#    1143         except Exception:
#    1144             # Might fail for server-side cursors (e.g. connection closed)
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/sentry_sdk/integrations/django/__init__.py in execute(self, sql, params)
#     560             hub, self.cursor, sql, params, paramstyle="format", executemany=False
#     561         ):
# --> 562             return real_execute(self, sql, params)
#     563
#     564     def executemany(self, sql, param_list):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      65
#      66     def execute(self, sql, params=None):
# ---> 67         return self._execute_with_wrappers(sql, params, many=False, executor=self._execute)
#      68
#      69     def executemany(self, sql, param_list):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/django/db/backends/utils.py in _execute_with_wrappers(self, sql, params, many, executor)
#      74         for wrapper in reversed(self.db.execute_wrappers):
#      75             executor = functools.partial(wrapper, executor)
# ---> 76         return executor(sql, params, many, context)
#      77
#      78     def _execute(self, sql, params, *ignored_wrapper_args):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      82                 return self.cursor.execute(sql)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#      86     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/psycopg2/_json.py in getquoted(self)
#      77
#      78     def getquoted(self):
# ---> 79         s = self.dumps(self.adapted)
#      80         qs = QuotedString(s)
#      81         if self._conn is not None:
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/django/contrib/postgres/fields/jsonb.py in dumps(self, obj)
#      25     def dumps(self, obj):
#      26         options = {'cls': self.encoder} if self.encoder else {}
# ---> 27         return json.dumps(obj, **options)
#      28
#      29
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type datetime is not JSON serializable

# %%
rep[3].form_data
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_109173/831371523.py in <module>
# ----> 1 rep[3].form_data
#
# ~/.cache/pypoetry/virtualenvs/apps-ZFymp6kh-py3.7/lib/python3.7/site-packages/django/db/models/query.py in __getitem__(self, k)
#     307         qs.query.set_limits(k, k + 1)
#     308         qs._fetch_all()
# --> 309         return qs._result_cache[0]
#     310
#     311     def __and__(self, other):
#
# IndexError: list index out of range
