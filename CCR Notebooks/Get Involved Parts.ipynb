# %%
# %load_ext autoreload
# %autoreload 2

# %%
company = Company.objects.get(name="PRE-UHE-ITA")

# %%
involved_parts = {
	"apiName": "condition",
	"dataType": "select",
	"displayName": "Condição da parte envolvida",
	"selectOptions": {
		"options": [{
			"name": "Infrator(a)",
			"value": "1"
		}, {
			"name": "Infrator(a) não identificado",
			"value": "2"
		}, {
			"name": "Presta serviços ao infrator",
			"value": "3"
		}, {
			"name": "Vínculo familiar com o infrator",
			"value": "4"
		}, {
			"name": "Informante",
			"value": "5"
		}, {
			"name": "Vítima (acidente)",
			"value": "6"
		}, {
			"name": "Denunciante",
			"value": "7"
		}, {
			"name": "Inspetor",
			"value": "8"
		}, {
			"name": "Solicitante",
			"value": "9"
		}, {
			"name": "Preposto(a) Técnico(a)",
			"value": "10"
		}, {
			"name": "Encarregado(a) de Campo",
			"value": "11"
		}, {
			"name": "Colaborador(a)",
			"value": "12"
		}, {
			"name": "Estagiário(a)",
			"value": "13"
		}, {
			"name": "Outro",
			"value": "14"
		}]
	}
}

# %%
involved_parts_fields =  [{
 		"id": 1,
 		"apiName": "name",
 		"dataType": "string",
 		"displayName": "Nome completo",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	}, {
 		"id": 2,
 		"apiName": "rg",
 		"dataType": "boolean",
 		"displayName": "RG",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	},
 	{
 		"id": 3,
 		"apiName": "descriptionRg",
 		"dataType": "string",
 		"displayName": "Número do RG",
 		"displayIf": {
 			"and": [{
 				"===": [{
 						"var": {
 							"cat": [
 								"data.rg"
 							]
 						}
 					},
 					True
 				]
 			}, {
 				"in": [{
 						"var": "data.involvedParts"
 					},
 					[
 						"1",
 						"2",
 						"3",
 						"4",
 						"5",
 						"6"
 					]
 				]
 			}]
 		}
 	},
 	{
 		"id": 4,
 		"apiName": "cpf",
 		"dataType": "boolean",
 		"displayName": "CPF",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	},
 	{
 		"id": 5,
 		"apiName": "descriptionCpf",
 		"dataType": "string",
 		"displayName": "Número do CPF",
 		"displayIf": {
 			"and": [{
 				"===": [{
 						"var": {
 							"cat": [
 								"data.cpf"
 							]
 						}
 					},
 					True
 				]
 			}, {
 				"in": [{
 						"var": "data.involvedParts"
 					},
 					[
 						"1",
 						"2",
 						"3",
 						"4",
 						"5",
 						"6"
 					]
 				]
 			}]
 		}
 	}, {
 		"id": 6,
 		"apiName": "phone",
 		"dataType": "boolean",
 		"displayName": "Telefone",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	},
 	{
 		"id": 7,
 		"apiName": "descriptionPhone",
 		"dataType": "string",
 		"displayName": "Número de Telefone",
 		"displayIf": {
 			"and": [{
 				"===": [{
 						"var": {
 							"cat": [
 								"data.phone"
 							]
 						}
 					},
 					True
 				]
 			}, {
 				"in": [{
 						"var": "data.involvedParts"
 					},
 					[
 						"1",
 						"2",
 						"3",
 						"4",
 						"5",
 						"6"
 					]
 				]
 			}]
 		}
 	}, {
 		"id": 8,
 		"apiName": "email",
 		"dataType": "boolean",
 		"displayName": "E-mail",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	},
 	{
 		"id": 9,
 		"apiName": "descriptionEmail",
 		"dataType": "string",
 		"displayName": "E-mail",
 		"displayIf": {
 			"and": [{
 				"===": [{
 						"var": {
 							"cat": [
 								"data.email"
 							]
 						}
 					},
 					True
 				]
 			}, {
 				"in": [{
 						"var": "data.involvedParts"
 					},
 					[
 						"1",
 						"2",
 						"3",
 						"4",
 						"5",
 						"6"
 					]
 				]
 			}]
 		}
 	}, {
 		"id": 10,
 		"apiName": "address",
 		"dataType": "string",
 		"displayName": "Logradouro",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	}, {
 		"id": 11,
 		"apiName": "addressNumber",
 		"dataType": "string",
 		"displayName": "Número",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	}, {
 		"id": 12,
 		"apiName": "district",
 		"dataType": "string",
 		"displayName": "Bairro",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	}, {
 		"id": 13,
 		"apiName": "addressAdditional",
 		"dataType": "string",
 		"displayName": "Complemento",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	}, {
 		"id": 14,
 		"apiName": "uf",
 		"dataType": "UF",
 		"displayName": "UF",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	}, {
 		"id": 15,
 		"apiName": "city",
 		"dataType": "string",
 		"displayName": "Cidade",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	}, {
 		"id": 16,
 		"apiName": "cep",
 		"dataType": "string",
 		"displayName": "CEP",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"1",
 					"2",
 					"3",
 					"4",
 					"5",
 					"6"
 				]
 			]
 		}
 	}, {
 		"id": 17,
 		"apiName": "originMedia",
 		"dataType": "select",
 		"displayName": "Meio de Comunica\u00e7\u00e3o",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"7",
 					"8",
 					"9"
 				]
 			]
 		},
 		"selectOptions": {
 			"options": [{
 				"name": "Carta",
 				"value": "1"
 			}, {
 				"name": "E-mail",
 				"value": "2"
 			}, {
 				"name": "Fax",
 				"value": "3"
 			}, {
 				"name": "Internet",
 				"value": "4"
 			}, {
 				"name": "Jornal",
 				"value": "5"
 			}, {
 				"name": "Of\u00edcio",
 				"value": "6"
 			}, {
 				"name": "R\u00e1dio",
 				"value": "7"
 			}, {
 				"name": "Telefone",
 				"value": "8"
 			}, {
 				"name": "TV",
 				"value": "9"
 			}, {
 				"name": "Verbal",
 				"value": "10"
 			}]
 		}
 	},
 	{
 		"id": 18,
 		"apiName": "name",
 		"dataType": "string",
 		"displayName": "Nome",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"7",
 					"8",
 					"9"
 				]
 			]
 		}
 	}, {
 		"id": 19,
 		"apiName": "phone",
 		"dataType": "string",
 		"displayName": "Telefone",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"7",
 					"8",
 					"9"
 				]
 			]
 		}
 	}, {
 		"id": 20,
 		"apiName": "cellphone",
 		"dataType": "string",
 		"displayName": "Celular",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"7",
 					"8",
 					"9"
 				]
 			]
 		}
 	}, {
 		"id": 21,
 		"apiName": "email",
 		"dataType": "string",
 		"displayName": "E-mail",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"7",
 					"8",
 					"9"
 				]
 			]
 		}
 	}, {
 		"id": 22,
 		"apiName": "qualification",
 		"dataType": "string",
 		"displayName": "Qualificação",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"7",
 					"8",
 					"9"
 				]
 			]
 		}
 	},
 	{
 		"id": 23,
 		"apiName": "name",
 		"dataType": "string",
 		"displayName": "Nome completo",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"10",
 					"11",
 					"12",
 					"13",
 					"14"
 				]
 			]
 		}
 	}, {
 		"id": 24,
 		"apiName": "company",
 		"dataType": "string",
 		"displayName": "Empresa",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"10",
 					"11",
 					"12",
 					"13",
 					"14"
 				]
 			]
 		}
 	}, {
 		"id": 25,
 		"apiName": "date",
 		"dataType": "timestamp",
 		"displayName": "Data",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"10",
 					"11",
 					"12",
 					"13",
 					"14"
 				]
 			]
 		}
 	}, {
 		"id": 26,
 		"apiName": "assignment",
 		"dataType": "string",
 		"displayName": "Atribuição",
 		"displayIf": {
 			"in": [{
 					"var": "data.involvedParts"
 				},
 				[
 					"10",
 					"11",
 					"12",
 					"13",
 					"14"
 				]
 			]
 		}
 	}
 ]

# %%
company.custom_options["occurrenceRecord"]["fields"]["involvedParts"] = involved_parts
company.custom_options["occurrenceRecord"]["fields"]["involvedPartsFields"] = involved_parts_fields

# %%
company.save()
