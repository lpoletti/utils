# %%
from helpers.apps.json_logic import apply_json_logic
from helpers.serializers import get_obj_serialized
from helpers.strings import get_obj_from_path, to_flatten_str
from helpers.apps.daily_reports import generate_exported_file
import datetime
from tqdm.notebook import tqdm
import re
import pandas as pd

# %%
def ordenar_chave(elemento):
    partes = re.split(r'(\d+)', elemento)
    return (partes[0], int(partes[1]))

# %%
def get_exporter_extra_columns(company):
    return get_obj_from_path(
        company.custom_options, "reporting__exporter__extra_columns"
    )

# %%
def get_exporter_extra_columns_parsed_infos(exporter_extra_columns):
    extra_columns = {}
    for extra_column in exporter_extra_columns:
        column_key = extra_column.get("key", "")
        extra_columns[column_key] = extra_column.get("header", "")
    return extra_columns

# %%
def get_values_from_reporting_extra_columns(record, extra_columns):
    new_val = {}
    if extra_columns:
        reporting_formatted = get_obj_serialized(record, is_reporting=True)
        for item in extra_columns:
            json_logic = None
            key = item.get("key", "")
            logic = item.get("logic", False)
            header = item.get("header", "")
            is_date = item.get("isDate", False)
            new_val[("Unidade")] = record.company.name
            new_val[("Encontrado Em")] = record.found_at.strftime('%d-%m-%Y %H:%M:%S')
            new_val[("Rodovia")] = record.road_name
            new_val[("Km")] = record.km
            new_val[("Km Final")] = record.end_km
            new_val[("Latitude")] = record.point[1]
            new_val[("Longitude")] = record.point[0]
            new_val[("Classe")] = record.occurrence_type.name
            if key and logic:
                try:
                    json_logic = apply_json_logic(logic, reporting_formatted)
                except Exception:
                    pass
            if not json_logic:
                try:
                    json_logic = reporting_formatted.form_data[key]
                except Exception:
                    pass
            if is_date and json_logic:
                json_logic = format_date(json_logic)
            new_val[(header)] = json_logic
    return new_val

# %%
# company=Company.objects.get(name__icontains='DER/SP')
companies  = sorted(list(Company.objects.filter(name__icontains='DER/SP').order_by('name').values_list('name',flat=True)),key=ordenar_chave)
companies
# Out:
# ['DER/SP - D1',
#  'DER/SP - D2',
#  'DER/SP - D3',
#  'DER/SP - D4',
#  'DER/SP - D5',
#  'DER/SP - D6',
#  'DER/SP - D7',
#  'DER/SP - D8',
#  'DER/SP - D9',
#  'DER/SP - D10',
#  'DER/SP - D11',
#  'DER/SP - D12',
#  'DER/SP - D13',
#  'DER/SP - D14']

# %%
dados={}
for name in tqdm(companies):
    reps=Reporting.objects.filter(company__name=name,
                                  occurrence_type__name='Correção de marco quilométrico').order_by('number')
#     print(reps.values_list('number',flat=True))
    for rep in reps:
        if rep.occurrence_type.form_fields.get('measurementColumns'):
            report=get_values_from_reporting_extra_columns(rep,rep.occurrence_type.form_fields['measurementColumns'])
            if rep.number not in dados.keys():
                dados[rep.number] = {}
            dados[rep.number] = report
        if rep.occurrence_type.form_fields.get('measurement_columns'):
            report=get_values_from_reporting_extra_columns(rep,rep.occurrence_type.form_fields['measurement_columns'])
            if rep.number not in dados.keys():
                dados[rep.number] = {}
            dados[rep.number] = report
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]

# %%
dados
# Out:
# {'D1-24000024': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '08-04-2024 13:34:00',
#   'Rodovia': 'SP-280',
#   'Km': 23.0,
#   'Km Final': 23.0,
#   'Latitude': -23.138907560635573,
#   'Longitude': -48.43715361384396,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 24,
#   'Observações': None},
#  'D1-24000049': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '02-05-2024 11:55:37',
#   'Rodovia': 'SP 360',
#   'Km': 16.225848931297186,
#   'Km Final': 16.225848931297186,
#   'Latitude': -23.0358119,
#   'Longitude': -46.842944,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 82,
#   'Observações': None},
#  'D1-24000050': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '02-05-2024 12:03:15',
#   'Rodovia': 'SP 360',
#   'Km': 17.37074353743871,
#   'Km Final': 17.37074353743871,
#   'Latitude': -23.0275118,
#   'Longitude': -46.8402984,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 83,
#   'Observações': None},
#  'D1-24000051': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '02-05-2024 12:09:49',
#   'Rodovia': 'SP 360',
#   'Km': 18.51185414195569,
#   'Km Final': 18.51185414195569,
#   'Latitude': -23.0193347,
#   'Longitude': -46.8423348,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 84,
#   'Observações': None},
#  'D1-24000052': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '02-05-2024 12:22:53',
#   'Rodovia': 'SP 360',
#   'Km': 86.51156867199347,
#   'Km Final': 86.51156867199347,
#   'Latitude': -23.0000218,
#   'Longitude': -46.8482339,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 87,
#   'Observações': None},
#  'D1-24000053': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '02-05-2024 12:33:36',
#   'Rodovia': 'SP 360',
#   'Km': 88.64750708453835,
#   'Km Final': 88.64750708453835,
#   'Latitude': -22.9848257,
#   'Longitude': -46.8406965,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 88,
#   'Observações': None},
#  'D1-24000054': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '02-05-2024 12:36:41',
#   'Rodovia': 'SP 360',
#   'Km': 89.61264404167348,
#   'Km Final': 89.61264404167348,
#   'Latitude': -22.9790747,
#   'Longitude': -46.8359549,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 89,
#   'Observações': None},
#  'D1-24000055': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '02-05-2024 12:40:02',
#   'Rodovia': 'SP 360',
#   'Km': 90.59907281344732,
#   'Km Final': 90.59907281344732,
#   'Latitude': -22.9751439,
#   'Longitude': -46.8309947,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 90,
#   'Observações': None},
#  'D1-24000056': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '02-05-2024 13:02:05',
#   'Rodovia': 'SP 360',
#   'Km': 86.60090347335588,
#   'Km Final': 86.60090347335588,
#   'Latitude': -22.9992823,
#   'Longitude': -46.848724,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 86,
#   'Observações': None},
#  'D1-24000057': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '02-05-2024 13:07:02',
#   'Rodovia': 'SP 360',
#   'Km': 85.46931341999728,
#   'Km Final': 85.46931341999728,
#   'Latitude': -23.0067132,
#   'Longitude': -46.8444688,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 85,
#   'Observações': None},
#  'D1-24000058': {'Unidade': 'DER/SP - D1',
#   'Encontrado Em': '09-05-2024 11:55:14',
#   'Rodovia': 'SP 308',
#   'Km': 108.65999996267006,
#   'Km Final': 108.65999996267006,
#   'Latitude': -25.4317226,
#   'Longitude': -49.3641472,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 109,
#   'Observações': None},
#  'D2-24000001': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:19:57',
#   'Rodovia': 'SP 249',
#   'Km': 0.0024,
#   'Km Final': 0.0024,
#   'Latitude': -24.516809677313397,
#   'Longitude': -48.84104660623553,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 0,
#   'Observações': '0+000 - perímetro urbano e ausência de marco'},
#  'D2-24000002': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:26:13',
#   'Rodovia': 'SP 249',
#   'Km': 1.011845717645271,
#   'Km Final': 1.011845717645271,
#   'Latitude': -24.5098513,
#   'Longitude': -48.8410345,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 1,
#   'Observações': 'Perímetro urbano e ausência de marco'},
#  'D2-24000003': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:31:29',
#   'Rodovia': 'SP 249',
#   'Km': 2.647612853347118,
#   'Km Final': 2.647612853347118,
#   'Latitude': -24.4991153,
#   'Longitude': -48.842855,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 2,
#   'Observações': 'Perímetro urbano '},
#  'D2-24000004': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:35:12',
#   'Rodovia': 'SP 249',
#   'Km': 4.0036375511168645,
#   'Km Final': 4.0036375511168645,
#   'Latitude': -24.4900027,
#   'Longitude': -48.8449703,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 3,
#   'Observações': 'Ausência de marco'},
#  'D2-24000005': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:38:05',
#   'Rodovia': 'SP 249',
#   'Km': 5.111368399495746,
#   'Km Final': 5.111368399495746,
#   'Latitude': -24.4835788,
#   'Longitude': -48.8397727,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 4,
#   'Observações': None},
#  'D2-24000006': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:41:33',
#   'Rodovia': 'SP 249',
#   'Km': 6.249075881353245,
#   'Km Final': 6.249075881353245,
#   'Latitude': -24.4749411,
#   'Longitude': -48.8404436,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 5,
#   'Observações': None},
#  'D2-24000007': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:43:51',
#   'Rodovia': 'SP 249',
#   'Km': 7.349188813779769,
#   'Km Final': 7.349188813779769,
#   'Latitude': -24.4671784,
#   'Longitude': -48.8407655,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 6,
#   'Observações': None},
#  'D2-24000008': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:46:01',
#   'Rodovia': 'SP 249',
#   'Km': 8.476211982365102,
#   'Km Final': 8.476211982365102,
#   'Latitude': -24.4589902,
#   'Longitude': -48.8440286,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 7,
#   'Observações': None},
#  'D2-24000009': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:48:39',
#   'Rodovia': 'SP 249',
#   'Km': 9.533443391291371,
#   'Km Final': 9.533443391291371,
#   'Latitude': -24.4543596,
#   'Longitude': -48.8509901,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 8,
#   'Observações': None},
#  'D2-24000010': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:52:37',
#   'Rodovia': 'SP 249',
#   'Km': 10.660441915653513,
#   'Km Final': 10.660441915653513,
#   'Latitude': -24.4467612,
#   'Longitude': -48.8546557,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 9,
#   'Observações': None},
#  'D2-24000011': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:54:58',
#   'Rodovia': 'SP 249',
#   'Km': 11.76537704930602,
#   'Km Final': 11.76537704930602,
#   'Latitude': -24.4400795,
#   'Longitude': -48.8583237,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 10,
#   'Observações': None},
#  'D2-24000012': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 14:57:14',
#   'Rodovia': 'SP 249',
#   'Km': 13.018062444550713,
#   'Km Final': 13.018062444550713,
#   'Latitude': -24.4364123,
#   'Longitude': -48.8667707,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 11,
#   'Observações': None},
#  'D2-24000013': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:00:06',
#   'Rodovia': 'SP 249',
#   'Km': 14.340828819533963,
#   'Km Final': 14.340828819533963,
#   'Latitude': -24.4316346,
#   'Longitude': -48.8722779,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 12,
#   'Observações': None},
#  'D2-24000014': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:05:12',
#   'Rodovia': 'SP 249',
#   'Km': 15.747518323549478,
#   'Km Final': 15.747518323549478,
#   'Latitude': -24.4242514,
#   'Longitude': -48.8659946,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 13,
#   'Observações': 'Ausência de marco'},
#  'D2-24000015': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:07:38',
#   'Rodovia': 'SP 249',
#   'Km': 16.990721312860472,
#   'Km Final': 16.990721312860472,
#   'Latitude': -24.4158086,
#   'Longitude': -48.8662381,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 14,
#   'Observações': None},
#  'D2-24000016': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:10:52',
#   'Rodovia': 'SP 249',
#   'Km': 18.34142135400514,
#   'Km Final': 18.34142135400514,
#   'Latitude': -24.4087973,
#   'Longitude': -48.8723265,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 15,
#   'Observações': None},
#  'D2-24000017': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:13:33',
#   'Rodovia': 'SP 249',
#   'Km': 19.663845712200583,
#   'Km Final': 19.663845712200583,
#   'Latitude': -24.4010178,
#   'Longitude': -48.8758102,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 16,
#   'Observações': None},
#  'D2-24000018': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:15:53',
#   'Rodovia': 'SP 249',
#   'Km': 21.02070587466868,
#   'Km Final': 21.02070587466868,
#   'Latitude': -24.3924777,
#   'Longitude': -48.8739948,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 17,
#   'Observações': None},
#  'D2-24000019': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:17:57',
#   'Rodovia': 'SP 249',
#   'Km': 22.34925078604518,
#   'Km Final': 22.34925078604518,
#   'Latitude': -24.3851322,
#   'Longitude': -48.8706396,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 18,
#   'Observações': None},
#  'D2-24000020': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:20:07',
#   'Rodovia': 'SP 249',
#   'Km': 23.67940956351803,
#   'Km Final': 23.67940956351803,
#   'Latitude': -24.3800626,
#   'Longitude': -48.8635734,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 19,
#   'Observações': None},
#  'D2-24000021': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:22:01',
#   'Rodovia': 'SP 249',
#   'Km': 24.88276197368498,
#   'Km Final': 24.88276197368498,
#   'Latitude': -24.373496,
#   'Longitude': -48.8582499,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 20,
#   'Observações': None},
#  'D2-24000022': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:24:44',
#   'Rodovia': 'SP 249',
#   'Km': 25.6151204159414,
#   'Km Final': 25.6151204159414,
#   'Latitude': -24.3669331,
#   'Longitude': -48.8532569,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 21,
#   'Observações': None},
#  'D2-24000023': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:26:53',
#   'Rodovia': 'SP 249',
#   'Km': 26.195338926738497,
#   'Km Final': 26.195338926738497,
#   'Latitude': -24.3600568,
#   'Longitude': -48.8527123,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 22,
#   'Observações': None},
#  'D2-24000024': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:29:01',
#   'Rodovia': 'SP 249',
#   'Km': 26.854489648081536,
#   'Km Final': 26.854489648081536,
#   'Latitude': -24.3521147,
#   'Longitude': -48.8523617,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 23,
#   'Observações': None},
#  'D2-24000025': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:31:26',
#   'Rodovia': 'SP 249',
#   'Km': 27.516499360059385,
#   'Km Final': 27.516499360059385,
#   'Latitude': -24.3459303,
#   'Longitude': -48.8483694,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 24,
#   'Observações': None},
#  'D2-24000026': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:33:26',
#   'Rodovia': 'SP 249',
#   'Km': 27.7619,
#   'Km Final': 27.7619,
#   'Latitude': -24.3451346,
#   'Longitude': -48.8438449,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 25,
#   'Observações': 'Do marco 24 ao 25 foi aferido 400mts no odômetro'},
#  'D2-24000027': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:53:06',
#   'Rodovia': 'SP 249',
#   'Km': 36.887302009855105,
#   'Km Final': 36.887302009855105,
#   'Latitude': -24.2800657,
#   'Longitude': -48.7907506,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 36,
#   'Observações': None},
#  'D2-24000028': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:56:04',
#   'Rodovia': 'SP 249',
#   'Km': 37.744676938692976,
#   'Km Final': 37.744676938692976,
#   'Latitude': -24.2771541,
#   'Longitude': -48.7851109,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 37,
#   'Observações': None},
#  'D2-24000029': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 15:58:16',
#   'Rodovia': 'SP 249',
#   'Km': 38.578353431004345,
#   'Km Final': 38.578353431004345,
#   'Latitude': -24.2712914,
#   'Longitude': -48.7775977,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 38,
#   'Observações': None},
#  'D2-24000030': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 16:00:57',
#   'Rodovia': 'SP 249',
#   'Km': 39.43128482281386,
#   'Km Final': 39.43128482281386,
#   'Latitude': -24.2640955,
#   'Longitude': -48.7717542,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 39,
#   'Observações': None},
#  'D2-24000031': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 16:03:02',
#   'Rodovia': 'SP 249',
#   'Km': 40.27778175808315,
#   'Km Final': 40.27778175808315,
#   'Latitude': -24.2558148,
#   'Longitude': -48.767574,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 40,
#   'Observações': None},
#  'D2-24000032': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 16:28:49',
#   'Rodovia': 'SP 249',
#   'Km': 41.148309943029744,
#   'Km Final': 41.148309943029744,
#   'Latitude': -24.2465399,
#   'Longitude': -48.7657031,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 41,
#   'Observações': 'Ausência de marco'},
#  'D2-24000033': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 16:31:23',
#   'Rodovia': 'SP 249',
#   'Km': 41.99264089730539,
#   'Km Final': 41.99264089730539,
#   'Latitude': -24.239136,
#   'Longitude': -48.7613169,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 42,
#   'Observações': None},
#  'D2-24000034': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 16:34:50',
#   'Rodovia': 'SP 249',
#   'Km': 43.02571608947346,
#   'Km Final': 43.02571608947346,
#   'Latitude': -24.2321824,
#   'Longitude': -48.7698435,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 43,
#   'Observações': None},
#  'D2-24000035': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 16:36:53',
#   'Rodovia': 'SP 249',
#   'Km': 43.48142233074903,
#   'Km Final': 43.48142233074903,
#   'Latitude': -24.2279546,
#   'Longitude': -48.7710943,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 43.5,
#   'Observações': None},
#  'D2-24000036': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:05:24',
#   'Rodovia': 'SP 275',
#   'Km': 324.61914952945244,
#   'Km Final': 324.61914952945244,
#   'Latitude': -23.8546473,
#   'Longitude': -49.155691,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 324.5,
#   'Observações': None},
#  'D2-24000037': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:08:29',
#   'Rodovia': 'SP 275',
#   'Km': 325.0523770213563,
#   'Km Final': 325.0523770213563,
#   'Latitude': -23.8534084,
#   'Longitude': -49.1598596,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 325,
#   'Observações': 'Ausência de marco '},
#  'D2-24000038': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:10:25',
#   'Rodovia': 'SP 275',
#   'Km': 326.04941828841106,
#   'Km Final': 326.04941828841106,
#   'Latitude': -23.8518906,
#   'Longitude': -49.1697833,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 326,
#   'Observações': None},
#  'D2-24000039': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:12:17',
#   'Rodovia': 'SP 275',
#   'Km': 327.03672377072417,
#   'Km Final': 327.03672377072417,
#   'Latitude': -23.8512697,
#   'Longitude': -49.1796643,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 327,
#   'Observações': None},
#  'D2-24000040': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:14:15',
#   'Rodovia': 'SP 275',
#   'Km': 328.0001,
#   'Km Final': 328.0001,
#   'Latitude': -23.857763271959634,
#   'Longitude': -49.18605507426316,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 328,
#   'Observações': None},
#  'D2-24000041': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:16:03',
#   'Rodovia': 'SP 275',
#   'Km': 328.9738970074274,
#   'Km Final': 328.9738970074274,
#   'Latitude': -23.8620972,
#   'Longitude': -49.1938151,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 329,
#   'Observações': None},
#  'D2-24000042': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:18:21',
#   'Rodovia': 'SP 275',
#   'Km': 330.0046,
#   'Km Final': 330.0046,
#   'Latitude': -23.866623533867003,
#   'Longitude': -49.20210902239557,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 330,
#   'Observações': 'Ausência de marco '},
#  'D2-24000043': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:20:51',
#   'Rodovia': 'SP 275',
#   'Km': 330.9120871719881,
#   'Km Final': 330.9120871719881,
#   'Latitude': -23.8656101,
#   'Longitude': -49.2105642,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 331,
#   'Observações': None},
#  'D2-24000044': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:22:51',
#   'Rodovia': 'SP 275',
#   'Km': 331.85814090446377,
#   'Km Final': 331.85814090446377,
#   'Latitude': -23.8626325,
#   'Longitude': -49.2195304,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 332,
#   'Observações': None},
#  'D2-24000045': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:24:29',
#   'Rodovia': 'SP 275',
#   'Km': 332.8414010883593,
#   'Km Final': 332.8414010883593,
#   'Latitude': -23.8605204,
#   'Longitude': -49.2288671,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 333,
#   'Observações': None},
#  'D2-24000046': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '29-04-2024 18:29:26',
#   'Rodovia': 'SP 275',
#   'Km': 333.2797,
#   'Km Final': 333.2797,
#   'Latitude': -23.858145169380645,
#   'Longitude': -49.23241140515569,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 333.45,
#   'Observações': 'Final do trecho pavimentado'},
#  'D2-24000047': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:20:22',
#   'Rodovia': 'SP 249',
#   'Km': 135.11422560858978,
#   'Km Final': 135.11422560858978,
#   'Latitude': -23.7122321,
#   'Longitude': -49.2538856,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 135,
#   'Observações': None},
#  'D2-24000048': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:23:30',
#   'Rodovia': 'SP 249',
#   'Km': 136.10141581947227,
#   'Km Final': 136.10141581947227,
#   'Latitude': -23.7030296,
#   'Longitude': -49.2545242,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 136,
#   'Observações': None},
#  'D2-24000049': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:25:01',
#   'Rodovia': 'SP 249',
#   'Km': 137.0992169401814,
#   'Km Final': 137.0992169401814,
#   'Latitude': -23.6948919,
#   'Longitude': -49.2590583,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 137,
#   'Observações': None},
#  'D2-24000050': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:27:30',
#   'Rodovia': 'SP 249',
#   'Km': 138.08088898280374,
#   'Km Final': 138.08088898280374,
#   'Latitude': -23.6903861,
#   'Longitude': -49.2672422,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 138,
#   'Observações': None},
#  'D2-24000051': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:29:17',
#   'Rodovia': 'SP 249',
#   'Km': 139.06868704104582,
#   'Km Final': 139.06868704104582,
#   'Latitude': -23.6884654,
#   'Longitude': -49.2771217,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 139,
#   'Observações': None},
#  'D2-24000052': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:31:03',
#   'Rodovia': 'SP 249',
#   'Km': 140.042,
#   'Km Final': 140.042,
#   'Latitude': -23.6813677,
#   'Longitude': -49.2823934,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 140,
#   'Observações': None},
#  'D2-24000053': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:32:30',
#   'Rodovia': 'SP 249',
#   'Km': 141.02461858140913,
#   'Km Final': 141.02461858140913,
#   'Latitude': -23.6723967,
#   'Longitude': -49.2845651,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 141,
#   'Observações': None},
#  'D2-24000054': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:34:35',
#   'Rodovia': 'SP 249',
#   'Km': 142.08225627558662,
#   'Km Final': 142.08225627558662,
#   'Latitude': -23.662736,
#   'Longitude': -49.2869019,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 142,
#   'Observações': None},
#  'D2-24000055': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:36:17',
#   'Rodovia': 'SP 249',
#   'Km': 142.98163378141996,
#   'Km Final': 142.98163378141996,
#   'Latitude': -23.6544812,
#   'Longitude': -49.2881581,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 143,
#   'Observações': None},
#  'D2-24000056': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:38:19',
#   'Rodovia': 'SP 249',
#   'Km': 143.9741304297284,
#   'Km Final': 143.9741304297284,
#   'Latitude': -23.6453051,
#   'Longitude': -49.288359,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 144,
#   'Observações': None},
#  'D2-24000057': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 13:40:51',
#   'Rodovia': 'SP 249',
#   'Km': 144.0288,
#   'Km Final': 144.0288,
#   'Latitude': -23.64476725796589,
#   'Longitude': -49.288512190670716,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 144.068,
#   'Observações': 'Final do trecho sob jurisdição do DER '},
#  'D2-24000058': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:20:07',
#   'Rodovia': 'SPA 245/270',
#   'Km': 0.13983225258846588,
#   'Km Final': 0.13983225258846588,
#   'Latitude': -23.4677641,
#   'Longitude': -48.7762471,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 0,
#   'Observações': '0+000 - Ausência de marco'},
#  'D2-24000059': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:23:56',
#   'Rodovia': 'SPA 245/270',
#   'Km': 0.973838482965391,
#   'Km Final': 0.973838482965391,
#   'Latitude': -23.4602456,
#   'Longitude': -48.7745745,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 1,
#   'Observações': None},
#  'D2-24000060': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:26:12',
#   'Rodovia': 'SPA 245/270',
#   'Km': 1.9473116640327568,
#   'Km Final': 1.9473116640327568,
#   'Latitude': -23.4514501,
#   'Longitude': -48.7727319,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 2,
#   'Observações': None},
#  'D2-24000061': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:27:48',
#   'Rodovia': 'SPA 245/270',
#   'Km': 2.9543666901911987,
#   'Km Final': 2.9543666901911987,
#   'Latitude': -23.4423517,
#   'Longitude': -48.7708287,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 3,
#   'Observações': None},
#  'D2-24000062': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:30:04',
#   'Rodovia': 'SPA 245/270',
#   'Km': 3.8570924312974073,
#   'Km Final': 3.8570924312974073,
#   'Latitude': -23.4354337,
#   'Longitude': -48.7664057,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 4,
#   'Observações': None},
#  'D2-24000063': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:31:52',
#   'Rodovia': 'SPA 245/270',
#   'Km': 4.856362135038303,
#   'Km Final': 4.856362135038303,
#   'Latitude': -23.4292488,
#   'Longitude': -48.7589929,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 5,
#   'Observações': None},
#  'D2-24000064': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:33:41',
#   'Rodovia': 'SPA 245/270',
#   'Km': 5.883978667775695,
#   'Km Final': 5.883978667775695,
#   'Latitude': -23.4211688,
#   'Longitude': -48.7550646,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 6,
#   'Observações': None},
#  'D2-24000065': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:35:59',
#   'Rodovia': 'SPA 245/270',
#   'Km': 6.8789245514504165,
#   'Km Final': 6.8789245514504165,
#   'Latitude': -23.4123424,
#   'Longitude': -48.7576119,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 7,
#   'Observações': 'Ausência de marco'},
#  'D2-24000066': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:38:03',
#   'Rodovia': 'SPA 245/270',
#   'Km': 7.892983953289274,
#   'Km Final': 7.892983953289274,
#   'Latitude': -23.4043035,
#   'Longitude': -48.752971,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 8,
#   'Observações': None},
#  'D2-24000067': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:39:42',
#   'Rodovia': 'SPA 245/270',
#   'Km': 8.955692411267727,
#   'Km Final': 8.955692411267727,
#   'Latitude': -23.3984385,
#   'Longitude': -48.7452607,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 9,
#   'Observações': 'Ausência de marco '},
#  'D2-24000068': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:42:09',
#   'Rodovia': 'SPA 245/270',
#   'Km': 9.83767561224306,
#   'Km Final': 9.83767561224306,
#   'Latitude': -23.3973493,
#   'Longitude': -48.7365345,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 10,
#   'Observações': None},
#  'D2-24000069': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:43:42',
#   'Rodovia': 'SPA 245/270',
#   'Km': 10.837533873890699,
#   'Km Final': 10.837533873890699,
#   'Latitude': -23.3924652,
#   'Longitude': -48.7280308,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 11,
#   'Observações': 'Ausência de marco '},
#  'D2-24000070': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 15:45:27',
#   'Rodovia': 'SPA 245/270',
#   'Km': 11.23,
#   'Km Final': 11.23,
#   'Latitude': -23.3903674,
#   'Longitude': -48.7247151,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 11.4,
#   'Observações': 'Fim do trecho/Perímetro urbano'},
#  'D2-24000071': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 17:55:58',
#   'Rodovia': 'SP 157',
#   'Km': 37.52429167632172,
#   'Km Final': 37.52429167632172,
#   'Latitude': -23.374834,
#   'Longitude': -48.1878483,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 37,
#   'Observações': 'Perímetro urbano '},
#  'D2-24000072': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:00:01',
#   'Rodovia': 'SP 157',
#   'Km': 38.64633029886943,
#   'Km Final': 38.64633029886943,
#   'Latitude': -23.3686623,
#   'Longitude': -48.1841274,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 38,
#   'Observações': 'Perímetro urbano '},
#  'D2-24000073': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:03:10',
#   'Rodovia': 'SP 157',
#   'Km': 39.81325925504111,
#   'Km Final': 39.81325925504111,
#   'Latitude': -23.3606514,
#   'Longitude': -48.1844954,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 39,
#   'Observações': 'Perímetro urbano '},
#  'D2-24000074': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:05:48',
#   'Rodovia': 'SP 157',
#   'Km': 40.85069730060884,
#   'Km Final': 40.85069730060884,
#   'Latitude': -23.3515519,
#   'Longitude': -48.1851709,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 40,
#   'Observações': 'Ausência de marco '},
#  'D2-24000075': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:07:34',
#   'Rodovia': 'SP 157',
#   'Km': 41.830263990839455,
#   'Km Final': 41.830263990839455,
#   'Latitude': -23.342842,
#   'Longitude': -48.1850236,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 41,
#   'Observações': None},
#  'D2-24000076': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:09:22',
#   'Rodovia': 'SP 157',
#   'Km': 42.73412554710198,
#   'Km Final': 42.73412554710198,
#   'Latitude': -23.3348782,
#   'Longitude': -48.1847554,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 42,
#   'Observações': None},
#  'D2-24000077': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:11:15',
#   'Rodovia': 'SP 157',
#   'Km': 43.85678427893224,
#   'Km Final': 43.85678427893224,
#   'Latitude': -23.3260614,
#   'Longitude': -48.1854958,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 43,
#   'Observações': None},
#  'D2-24000078': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:13:08',
#   'Rodovia': 'SP 157',
#   'Km': 44.86243646019875,
#   'Km Final': 44.86243646019875,
#   'Latitude': -23.3182924,
#   'Longitude': -48.181062,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 44,
#   'Observações': None},
#  'D2-24000079': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:14:43',
#   'Rodovia': 'SP 157',
#   'Km': 45.87809913913435,
#   'Km Final': 45.87809913913435,
#   'Latitude': -23.3105087,
#   'Longitude': -48.1758356,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 45,
#   'Observações': None},
#  'D2-24000080': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:16:36',
#   'Rodovia': 'SP 157',
#   'Km': 46.86706858234722,
#   'Km Final': 46.86706858234722,
#   'Latitude': -23.3045351,
#   'Longitude': -48.1686727,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 46,
#   'Observações': None},
#  'D2-24000081': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:18:13',
#   'Rodovia': 'SP 157',
#   'Km': 47.87442728095031,
#   'Km Final': 47.87442728095031,
#   'Latitude': -23.2967801,
#   'Longitude': -48.1648742,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 47,
#   'Observações': None},
#  'D2-24000082': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:20:06',
#   'Rodovia': 'SP 157',
#   'Km': 48.850958135248014,
#   'Km Final': 48.850958135248014,
#   'Latitude': -23.2883701,
#   'Longitude': -48.1657825,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 48,
#   'Observações': None},
#  'D2-24000083': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:21:30',
#   'Rodovia': 'SP 157',
#   'Km': 49.887501328475174,
#   'Km Final': 49.887501328475174,
#   'Latitude': -23.2814221,
#   'Longitude': -48.1592944,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 49,
#   'Observações': None},
#  'D2-24000084': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:23:20',
#   'Rodovia': 'SP 157',
#   'Km': 50.84768533409685,
#   'Km Final': 50.84768533409685,
#   'Latitude': -23.2741925,
#   'Longitude': -48.1541521,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 50,
#   'Observações': None},
#  'D2-24000085': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:25:02',
#   'Rodovia': 'SP 157',
#   'Km': 51.80744499353575,
#   'Km Final': 51.80744499353575,
#   'Latitude': -23.2663515,
#   'Longitude': -48.1504865,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 51,
#   'Observações': None},
#  'D2-24000086': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:26:47',
#   'Rodovia': 'SP 157',
#   'Km': 52.82072221886809,
#   'Km Final': 52.82072221886809,
#   'Latitude': -23.2647479,
#   'Longitude': -48.1405075,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 52,
#   'Observações': None},
#  'D2-24000087': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:28:57',
#   'Rodovia': 'SP 157',
#   'Km': 53.7730787402006,
#   'Km Final': 53.7730787402006,
#   'Latitude': -23.2578151,
#   'Longitude': -48.1353041,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 53,
#   'Observações': None},
#  'D2-24000088': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:30:54',
#   'Rodovia': 'SP 157',
#   'Km': 54.74829804502445,
#   'Km Final': 54.74829804502445,
#   'Latitude': -23.2496457,
#   'Longitude': -48.1319481,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 54,
#   'Observações': ''},
#  'D2-24000089': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:33:05',
#   'Rodovia': 'SP 157',
#   'Km': 55.736606145053436,
#   'Km Final': 55.736606145053436,
#   'Latitude': -23.2435495,
#   'Longitude': -48.1245036,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 56,
#   'Observações': None},
#  'D2-24000090': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '30-04-2024 18:35:42',
#   'Rodovia': 'SP 157',
#   'Km': 56.279585837803545,
#   'Km Final': 56.279585837803545,
#   'Latitude': -23.2385384,
#   'Longitude': -48.1230608,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 55.5,
#   'Observações': 'Fim do trecho'},
#  'D2-24000091': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:01:56',
#   'Rodovia': 'SP 141',
#   'Km': 0.2922,
#   'Km Final': 0.2922,
#   'Latitude': -23.532831780034346,
#   'Longitude': -47.72435747445777,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 0.32,
#   'Observações': 'INÍCIO DO TRECHO SOB JURISDIÇÃO DO DER. DO 0,000 AO 0,320 - CONCESSÃO - CONSIDERADO TRAÇADO VIGENTE DA RODOVIA.'},
#  'D2-24000092': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:22:50',
#   'Rodovia': 'SP 141',
#   'Km': 1.0050750102819928,
#   'Km Final': 1.0050750102819928,
#   'Latitude': -23.528244,
#   'Longitude': -47.728999,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 1,
#   'Observações': None},
#  'D2-24000093': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:26:15',
#   'Rodovia': 'SP 141',
#   'Km': 2.021680432492044,
#   'Km Final': 2.021680432492044,
#   'Latitude': -23.5217492,
#   'Longitude': -47.7355878,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 2,
#   'Observações': None},
#  'D2-24000094': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:29:16',
#   'Rodovia': 'SP 141',
#   'Km': 3.0652596604318485,
#   'Km Final': 3.0652596604318485,
#   'Latitude': -23.5135322,
#   'Longitude': -47.7396007,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 3,
#   'Observações': None},
#  'D2-24000095': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:31:43',
#   'Rodovia': 'SP 141',
#   'Km': 4.0846446245829,
#   'Km Final': 4.0846446245829,
#   'Latitude': -23.5051189,
#   'Longitude': -47.74279,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 4,
#   'Observações': None},
#  'D2-24000096': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:34:55',
#   'Rodovia': 'SP 141',
#   'Km': 5.149634530573403,
#   'Km Final': 5.149634530573403,
#   'Latitude': -23.4960079,
#   'Longitude': -47.7420361,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 5,
#   'Observações': None},
#  'D2-24000097': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:38:29',
#   'Rodovia': 'SP 141',
#   'Km': 6.148786466451123,
#   'Km Final': 6.148786466451123,
#   'Latitude': -23.4871364,
#   'Longitude': -47.7411504,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 6,
#   'Observações': 'PERÍMETRO URBANO - TRECHO DUPLICADO'},
#  'D2-24000098': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:41:13',
#   'Rodovia': 'SP 141',
#   'Km': 7.034061532145271,
#   'Km Final': 7.034061532145271,
#   'Latitude': -23.4781819,
#   'Longitude': -47.7414395,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 7,
#   'Observações': 'PERÍMETRO URBANO - TRECHO DUPLICADO '},
#  'D2-24000099': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:43:53',
#   'Rodovia': 'SP 141',
#   'Km': 7.067789302223117,
#   'Km Final': 7.067789302223117,
#   'Latitude': -23.477919,
#   'Longitude': -47.7416896,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 7,
#   'Observações': 'PERÍMETRO URBANO - TRECHO DUPLICADO '},
#  'D2-24000100': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:47:18',
#   'Rodovia': 'SP 141',
#   'Km': 8.165690997524472,
#   'Km Final': 8.165690997524472,
#   'Latitude': -23.4692588,
#   'Longitude': -47.7413528,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 8,
#   'Observações': 'PERÍMETRO URBANO - TRECHO DUPLICADO '},
#  'D2-24000101': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:48:26',
#   'Rodovia': 'SP 141',
#   'Km': 8.184175626528058,
#   'Km Final': 8.184175626528058,
#   'Latitude': -23.4690617,
#   'Longitude': -47.7415087,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 8,
#   'Observações': 'PERÍMETRO URBANO - TRECHO DUPLICADO '},
#  'D2-24000102': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:52:20',
#   'Rodovia': 'SP 141',
#   'Km': 9.283623623100134,
#   'Km Final': 9.283623623100134,
#   'Latitude': -23.4622221,
#   'Longitude': -47.7352989,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 9,
#   'Observações': None},
#  'D2-24000103': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:54:26',
#   'Rodovia': 'SP 141',
#   'Km': 10.200930664445067,
#   'Km Final': 10.200930664445067,
#   'Latitude': -23.4537499,
#   'Longitude': -47.7349438,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 10,
#   'Observações': None},
#  'D2-24000104': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 12:57:44',
#   'Rodovia': 'SP 141',
#   'Km': 11.18857736878747,
#   'Km Final': 11.18857736878747,
#   'Latitude': -23.4447835,
#   'Longitude': -47.7360506,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 11,
#   'Observações': None},
#  'D2-24000105': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:01:10',
#   'Rodovia': 'SP 141',
#   'Km': 12.162598713677033,
#   'Km Final': 12.162598713677033,
#   'Latitude': -23.4358518,
#   'Longitude': -47.7354098,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 12,
#   'Observações': None},
#  'D2-24000106': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:04:37',
#   'Rodovia': 'SP 141',
#   'Km': 13.139730107995598,
#   'Km Final': 13.139730107995598,
#   'Latitude': -23.4270612,
#   'Longitude': -47.7365274,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 13,
#   'Observações': None},
#  'D2-24000107': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:06:43',
#   'Rodovia': 'SP 141',
#   'Km': 14.090844573282789,
#   'Km Final': 14.090844573282789,
#   'Latitude': -23.4192211,
#   'Longitude': -47.7409909,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 14,
#   'Observações': None},
#  'D2-24000108': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:09:39',
#   'Rodovia': 'SP 141',
#   'Km': 15.081733752896529,
#   'Km Final': 15.081733752896529,
#   'Latitude': -23.4111966,
#   'Longitude': -47.7458526,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 15,
#   'Observações': None},
#  'D2-24000109': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:11:54',
#   'Rodovia': 'SP 141',
#   'Km': 16.02425068863947,
#   'Km Final': 16.02425068863947,
#   'Latitude': -23.4040044,
#   'Longitude': -47.7513775,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 16,
#   'Observações': None},
#  'D2-24000110': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:15:13',
#   'Rodovia': 'SP 141',
#   'Km': 17.007231343444545,
#   'Km Final': 17.007231343444545,
#   'Latitude': -23.3985223,
#   'Longitude': -47.757537,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 17,
#   'Observações': None},
#  'D2-24000111': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:17:59',
#   'Rodovia': 'SP 141',
#   'Km': 17.9700152096264,
#   'Km Final': 17.9700152096264,
#   'Latitude': -23.3962061,
#   'Longitude': -47.7658555,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 18,
#   'Observações': None},
#  'D2-24000112': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:25:34',
#   'Rodovia': 'SP 141',
#   'Km': 18.96671362369947,
#   'Km Final': 18.96671362369947,
#   'Latitude': -23.3910189,
#   'Longitude': -47.7734674,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 19,
#   'Observações': None},
#  'D2-24000113': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:28:00',
#   'Rodovia': 'SP 141',
#   'Km': 19.947377147583374,
#   'Km Final': 19.947377147583374,
#   'Latitude': -23.3865358,
#   'Longitude': -47.7817175,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 20,
#   'Observações': None},
#  'D2-24000114': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:31:11',
#   'Rodovia': 'SP 141',
#   'Km': 20.94418039118034,
#   'Km Final': 20.94418039118034,
#   'Latitude': -23.3814965,
#   'Longitude': -47.7899259,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 21,
#   'Observações': None},
#  'D2-24000115': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:35:39',
#   'Rodovia': 'SP 141',
#   'Km': 22.015024257842235,
#   'Km Final': 22.015024257842235,
#   'Latitude': -23.3744712,
#   'Longitude': -47.7958508,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 22,
#   'Observações': 'TRECHO DUPLICADO '},
#  'D2-24000116': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:42:33',
#   'Rodovia': 'SP 141',
#   'Km': 23.114274572225867,
#   'Km Final': 23.114274572225867,
#   'Latitude': -23.3682661,
#   'Longitude': -47.8028924,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 23,
#   'Observações': 'TRECHO DUPLICADO '},
#  'D2-24000117': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:46:05',
#   'Rodovia': 'SP 141',
#   'Km': 24.22150006480144,
#   'Km Final': 24.22150006480144,
#   'Latitude': -23.3598281,
#   'Longitude': -47.8034064,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 24,
#   'Observações': 'TRECHO DUPLICADO '},
#  'D2-24000118': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:49:24',
#   'Rodovia': 'SP 141',
#   'Km': 25.26156552054871,
#   'Km Final': 25.26156552054871,
#   'Latitude': -23.355396,
#   'Longitude': -47.8112073,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 25,
#   'Observações': 'TRECHO DUPLICADO '},
#  'D2-24000119': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:52:54',
#   'Rodovia': 'SP 141',
#   'Km': 26.374393137039892,
#   'Km Final': 26.374393137039892,
#   'Latitude': -23.3535651,
#   'Longitude': -47.820965,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 26,
#   'Observações': 'TRECHO DUPLICADO '},
#  'D2-24000120': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:56:19',
#   'Rodovia': 'SP 141',
#   'Km': 27.466274719826988,
#   'Km Final': 27.466274719826988,
#   'Latitude': -23.3515228,
#   'Longitude': -47.8304721,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 27,
#   'Observações': 'TRECHO DUPLICADO '},
#  'D2-24000121': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 13:59:22',
#   'Rodovia': 'SP 141',
#   'Km': 28.0588,
#   'Km Final': 28.0588,
#   'Latitude': -23.35086317452999,
#   'Longitude': -47.83628732266947,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 27.63,
#   'Observações': 'PERÍMETRO URBANO - TRECHO DUPLICADO. FINAL DO TRECHO SOB JURISDIÇÃO DO DER '},
#  'D2-24000122': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 16:18:04',
#   'Rodovia': 'SP 141',
#   'Km': 50.159885516786055,
#   'Km Final': 50.159885516786055,
#   'Latitude': -23.2191261,
#   'Longitude': -47.9734408,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 50,
#   'Observações': 'TRECHO DUPLICADO '},
#  'D2-24000123': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 16:27:52',
#   'Rodovia': 'SP 141',
#   'Km': 51.466589249880236,
#   'Km Final': 51.466589249880236,
#   'Latitude': -23.2180807,
#   'Longitude': -47.9813586,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 51,
#   'Observações': None},
#  'D2-24000124': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 16:31:00',
#   'Rodovia': 'SP 141',
#   'Km': 52.27643331276867,
#   'Km Final': 52.27643331276867,
#   'Latitude': -23.2201771,
#   'Longitude': -47.9896506,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 52,
#   'Observações': None},
#  'D2-24000125': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 16:35:09',
#   'Rodovia': 'SP 141',
#   'Km': 53.182768611270085,
#   'Km Final': 53.182768611270085,
#   'Latitude': -23.2232408,
#   'Longitude': -47.9984203,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 53,
#   'Observações': None},
#  'D2-24000126': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 16:37:35',
#   'Rodovia': 'SP 141',
#   'Km': 54.175411100616266,
#   'Km Final': 54.175411100616266,
#   'Latitude': -23.2232583,
#   'Longitude': -48.0079489,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 54,
#   'Observações': None},
#  'D2-24000127': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 16:40:39',
#   'Rodovia': 'SP 141',
#   'Km': 54.92711725650247,
#   'Km Final': 54.92711725650247,
#   'Latitude': -23.2261025,
#   'Longitude': -48.0164038,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 55,
#   'Observações': None},
#  'D2-24000128': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 16:42:55',
#   'Rodovia': 'SP 141',
#   'Km': 55.6257966874309,
#   'Km Final': 55.6257966874309,
#   'Latitude': -23.2270993,
#   'Longitude': -48.025605,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 56,
#   'Observações': None},
#  'D2-24000129': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 16:52:39',
#   'Rodovia': 'SP 141',
#   'Km': 56.57543796745525,
#   'Km Final': 56.57543796745525,
#   'Latitude': -23.225142,
#   'Longitude': -48.0341512,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 57,
#   'Observações': None},
#  'D2-24000130': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 16:55:37',
#   'Rodovia': 'SP 141',
#   'Km': 57.51820874126836,
#   'Km Final': 57.51820874126836,
#   'Latitude': -23.2222622,
#   'Longitude': -48.0417439,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 58,
#   'Observações': None},
#  'D2-24000131': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 17:00:07',
#   'Rodovia': 'SP 141',
#   'Km': 58.464946650909766,
#   'Km Final': 58.464946650909766,
#   'Latitude': -23.2196346,
#   'Longitude': -48.0503257,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 59,
#   'Observações': None},
#  'D2-24000132': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 17:03:06',
#   'Rodovia': 'SP 141',
#   'Km': 59.48478661512472,
#   'Km Final': 59.48478661512472,
#   'Latitude': -23.2166862,
#   'Longitude': -48.0590221,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 60,
#   'Observações': None},
#  'D2-24000133': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 17:06:10',
#   'Rodovia': 'SP 141',
#   'Km': 60.58423067879771,
#   'Km Final': 60.58423067879771,
#   'Latitude': -23.2131821,
#   'Longitude': -48.0672786,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 61,
#   'Observações': None},
#  'D2-24000134': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 17:09:00',
#   'Rodovia': 'SP 141',
#   'Km': 61.6120895694324,
#   'Km Final': 61.6120895694324,
#   'Latitude': -23.2117701,
#   'Longitude': -48.0761734,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 62,
#   'Observações': None},
#  'D2-24000135': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 17:14:05',
#   'Rodovia': 'SP 141',
#   'Km': 62.6702,
#   'Km Final': 62.6702,
#   'Latitude': -23.209597222630098,
#   'Longitude': -48.08277640900093,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 63,
#   'Observações': 'AUSÊNCIA DE MARCO QUILOMÉTRICO '},
#  'D2-24000136': {'Unidade': 'DER/SP - D2',
#   'Encontrado Em': '02-05-2024 17:17:34',
#   'Rodovia': 'SP 141',
#   'Km': 63.68880681011358,
# ...
#   'Latitude': -22.6751569,
#   'Longitude': -44.4433432,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 297,
#   'Observações': None},
#  'D6-24000249': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 19:54:02',
#   'Rodovia': 'SP 068',
#   'Km': 298.0834844777783,
#   'Km Final': 298.0834844777783,
#   'Latitude': -22.6769923,
#   'Longitude': -44.4247483,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 299,
#   'Observações': None},
#  'D6-24000250': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 19:55:36',
#   'Rodovia': 'SP 068',
#   'Km': 298.6064569750938,
#   'Km Final': 298.6064569750938,
#   'Latitude': -22.6757394,
#   'Longitude': -44.4162762,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 300,
#   'Observações': None},
#  'D6-24000251': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 19:56:59',
#   'Rodovia': 'SP 068',
#   'Km': 299.10692765425557,
#   'Km Final': 299.10692765425557,
#   'Latitude': -22.6737863,
#   'Longitude': -44.4077719,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 301,
#   'Observações': None},
#  'D6-24000252': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 19:58:24',
#   'Rodovia': 'SP 068',
#   'Km': 299.61027425891746,
#   'Km Final': 299.61027425891746,
#   'Latitude': -22.6760386,
#   'Longitude': -44.3994517,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 302,
#   'Observações': None},
#  'D6-24000253': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 20:00:13',
#   'Rodovia': 'SP 068',
#   'Km': 300.2840537784222,
#   'Km Final': 300.2840537784222,
#   'Latitude': -22.6785183,
#   'Longitude': -44.3931392,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 303,
#   'Observações': None},
#  'D6-24000254': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 20:02:23',
#   'Rodovia': 'SP 068',
#   'Km': 301.38013299045787,
#   'Km Final': 301.38013299045787,
#   'Latitude': -22.6793093,
#   'Longitude': -44.3874315,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 304,
#   'Observações': None},
#  'D6-24000255': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 20:04:03',
#   'Rodovia': 'SP 068',
#   'Km': 302.5799677686123,
#   'Km Final': 302.5799677686123,
#   'Latitude': -22.6796867,
#   'Longitude': -44.3782639,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 305,
#   'Observações': None},
#  'D6-24000256': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 20:05:23',
#   'Rodovia': 'SP 068',
#   'Km': 303.63861491601585,
#   'Km Final': 303.63861491601585,
#   'Latitude': -22.6872287,
#   'Longitude': -44.3742905,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 306,
#   'Observações': None},
#  'D6-24000257': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 20:06:58',
#   'Rodovia': 'SP 068',
#   'Km': 304.7915608774447,
#   'Km Final': 304.7915608774447,
#   'Latitude': -22.6951199,
#   'Longitude': -44.3716276,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 307,
#   'Observações': None},
#  'D6-24000258': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 20:08:28',
#   'Rodovia': 'SP 068',
#   'Km': 305.85343949657215,
#   'Km Final': 305.85343949657215,
#   'Latitude': -22.6892372,
#   'Longitude': -44.3659247,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 308,
#   'Observações': None},
#  'D6-24000259': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 20:09:58',
#   'Rodovia': 'SP 068',
#   'Km': 307.00398456745984,
#   'Km Final': 307.00398456745984,
#   'Latitude': -22.6854254,
#   'Longitude': -44.3588219,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 309,
#   'Observações': None},
#  'D6-24000260': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 20:11:44',
#   'Rodovia': 'SP 068',
#   'Km': 308.14652849487493,
#   'Km Final': 308.14652849487493,
#   'Latitude': -22.690659,
#   'Longitude': -44.3515162,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 310,
#   'Observações': None},
#  'D6-24000261': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 20:13:21',
#   'Rodovia': 'SP 068',
#   'Km': 309.28199818871184,
#   'Km Final': 309.28199818871184,
#   'Latitude': -22.693239,
#   'Longitude': -44.3478342,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 311,
#   'Observações': None},
#  'D6-24000262': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '08-05-2024 20:14:50',
#   'Rodovia': 'SP 068',
#   'Km': 310.4187287978747,
#   'Km Final': 310.4187287978747,
#   'Latitude': -22.6861784,
#   'Longitude': -44.3427992,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 312,
#   'Observações': None},
#  'D6-24000263': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 10:58:58',
#   'Rodovia': 'SP 068',
#   'Km': 318.889143797765,
#   'Km Final': 318.889143797765,
#   'Latitude': -22.6566279,
#   'Longitude': -44.2933156,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 319,
#   'Observações': None},
#  'D6-24000264': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 11:02:31',
#   'Rodovia': 'SP 068',
#   'Km': 317.918407895474,
#   'Km Final': 317.918407895474,
#   'Latitude': -22.6613857,
#   'Longitude': -44.2999964,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 318,
#   'Observações': None},
#  'D6-24000265': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 11:04:29',
#   'Rodovia': 'SP 068',
#   'Km': 316.95861132486095,
#   'Km Final': 316.95861132486095,
#   'Latitude': -22.6684097,
#   'Longitude': -44.3055616,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 317,
#   'Observações': None},
#  'D6-24000266': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 11:07:25',
#   'Rodovia': 'SP 068',
#   'Km': 315.9847984718679,
#   'Km Final': 315.9847984718679,
#   'Latitude': -22.674095,
#   'Longitude': -44.3102772,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 316,
#   'Observações': None},
#  'D6-24000267': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 11:17:27',
#   'Rodovia': 'SP 068',
#   'Km': 319.86747360432094,
#   'Km Final': 319.86747360432094,
#   'Latitude': -22.6500097,
#   'Longitude': -44.2873659,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 320,
#   'Observações': None},
#  'D6-24000268': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 14:15:44',
#   'Rodovia': 'SP 123',
#   'Km': 22.416410287128997,
#   'Km Final': 22.416410287128997,
#   'Latitude': -22.8882713,
#   'Longitude': -45.5970925,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 23,
#   'Observações': None},
#  'D6-24000269': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 14:17:01',
#   'Rodovia': 'SP 123',
#   'Km': 23.293148492304653,
#   'Km Final': 23.293148492304653,
#   'Latitude': -22.8794767,
#   'Longitude': -45.5978343,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 24,
#   'Observações': None},
#  'D6-24000270': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 14:18:52',
#   'Rodovia': 'SP 123',
#   'Km': 24.67371568277705,
#   'Km Final': 24.67371568277705,
#   'Latitude': -22.8708041,
#   'Longitude': -45.5954445,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 25,
#   'Observações': None},
#  'D6-24000271': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 14:20:26',
#   'Rodovia': 'SP 123',
#   'Km': 26.00907647783333,
#   'Km Final': 26.00907647783333,
#   'Latitude': -22.8640376,
#   'Longitude': -45.600245,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 26,
#   'Observações': None},
#  'D6-24000272': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 14:23:42',
#   'Rodovia': 'SP 123',
#   'Km': 26.998847948683135,
#   'Km Final': 26.998847948683135,
#   'Latitude': -22.8606702,
#   'Longitude': -45.6089188,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 27,
#   'Observações': None},
#  'D6-24000273': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 15:00:34',
#   'Rodovia': 'SP 123',
#   'Km': 41.675137738841364,
#   'Km Final': 41.675137738841364,
#   'Latitude': -22.7836849,
#   'Longitude': -45.611412,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 42,
#   'Observações': None},
#  'D6-24000274': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 15:04:51',
#   'Rodovia': 'SP 123',
#   'Km': 45.32646392969588,
#   'Km Final': 45.32646392969588,
#   'Latitude': -22.7573848,
#   'Longitude': -45.6105193,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 46,
#   'Observações': None},
#  'D6-24000275': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 15:32:59',
#   'Rodovia': 'SPA 162/050',
#   'Km': 162.71832565353927,
#   'Km Final': 162.71832565353927,
#   'Latitude': -22.774259,
#   'Longitude': -45.7028441,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 0,
#   'Observações': None},
#  'D6-24000276': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 15:34:59',
#   'Rodovia': 'SPA 162/050',
#   'Km': 1.1009456264747026,
#   'Km Final': 1.1009456264747026,
#   'Latitude': -22.7662637,
#   'Longitude': -45.7062223,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 1,
#   'Observações': None},
#  'D6-24000277': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 15:36:43',
#   'Rodovia': 'SPA 162/050',
#   'Km': 2.1330382836955315,
#   'Km Final': 2.1330382836955315,
#   'Latitude': -22.7602496,
#   'Longitude': -45.7106173,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 2,
#   'Observações': None},
#  'D6-24000278': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 15:38:52',
#   'Rodovia': 'SPA 162/050',
#   'Km': 3.233204143974903,
#   'Km Final': 3.233204143974903,
#   'Latitude': -22.7553071,
#   'Longitude': -45.7169943,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 3,
#   'Observações': None},
#  'D6-24000279': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 15:40:39',
#   'Rodovia': 'SPA 162/050',
#   'Km': 4.2938503531421395,
#   'Km Final': 4.2938503531421395,
#   'Latitude': -22.747211,
#   'Longitude': -45.717534,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 4,
#   'Observações': None},
#  'D6-24000280': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:05:15',
#   'Rodovia': 'SP 050',
#   'Km': 150.98683051715508,
#   'Km Final': 150.98683051715508,
#   'Latitude': -22.8199309,
#   'Longitude': -45.7423968,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 151,
#   'Observações': None},
#  'D6-24000281': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:09:28',
#   'Rodovia': 'SP 050',
#   'Km': 148.1531451467096,
#   'Km Final': 148.1531451467096,
#   'Latitude': -22.818153,
#   'Longitude': -45.7570703,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 148,
#   'Observações': None},
#  'D6-24000282': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:13:15',
#   'Rodovia': 'SP 050',
#   'Km': 145.41161655986832,
#   'Km Final': 145.41161655986832,
#   'Latitude': -22.8406222,
#   'Longitude': -45.7618322,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 145,
#   'Observações': None},
#  'D6-24000283': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:14:56',
#   'Rodovia': 'SP 050',
#   'Km': 144.4176133306882,
#   'Km Final': 144.4176133306882,
#   'Latitude': -22.8478503,
#   'Longitude': -45.7666427,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 144,
#   'Observações': None},
#  'D6-24000284': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:16:37',
#   'Rodovia': 'SP 050',
#   'Km': 143.36137604785884,
#   'Km Final': 143.36137604785884,
#   'Latitude': -22.8533301,
#   'Longitude': -45.7746261,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 143,
#   'Observações': None},
#  'D6-24000285': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:21:15',
#   'Rodovia': 'SP 050',
#   'Km': 141.48057509352577,
#   'Km Final': 141.48057509352577,
#   'Latitude': -22.8587444,
#   'Longitude': -45.776932,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 141,
#   'Observações': None},
#  'D6-24000286': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:29:18',
#   'Rodovia': 'SP 050',
#   'Km': 140.5230008285518,
#   'Km Final': 140.5230008285518,
#   'Latitude': -22.8592288,
#   'Longitude': -45.7709174,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 140,
#   'Observações': None},
#  'D6-24000287': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:30:47',
#   'Rodovia': 'SP 050',
#   'Km': 139.58461694580657,
#   'Km Final': 139.58461694580657,
#   'Latitude': -22.8653509,
#   'Longitude': -45.7745684,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 139,
#   'Observações': None},
#  'D6-24000288': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:32:34',
#   'Rodovia': 'SP 050',
#   'Km': 138.63670680854395,
#   'Km Final': 138.63670680854395,
#   'Latitude': -22.870854,
#   'Longitude': -45.7807063,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 138,
#   'Observações': None},
#  'D6-24000289': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:34:05',
#   'Rodovia': 'SP 050',
#   'Km': 137.62392599121574,
#   'Km Final': 137.62392599121574,
#   'Latitude': -22.8786618,
#   'Longitude': -45.7812956,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 137,
#   'Observações': None},
#  'D6-24000290': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:35:52',
#   'Rodovia': 'SP 050',
#   'Km': 136.5999155225803,
#   'Km Final': 136.5999155225803,
#   'Latitude': -22.8859546,
#   'Longitude': -45.7848512,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 136,
#   'Observações': None},
#  'D6-24000291': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:37:16',
#   'Rodovia': 'SP 050',
#   'Km': 135.60494483842453,
#   'Km Final': 135.60494483842453,
#   'Latitude': -22.8874887,
#   'Longitude': -45.7943151,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 135,
#   'Observações': None},
#  'D6-24000292': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:38:38',
#   'Rodovia': 'SP 050',
#   'Km': 134.61136228920583,
#   'Km Final': 134.61136228920583,
#   'Latitude': -22.8950286,
#   'Longitude': -45.7979861,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 134,
#   'Observações': None},
#  'D6-24000293': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:40:02',
#   'Rodovia': 'SP 050',
#   'Km': 133.64362179468026,
#   'Km Final': 133.64362179468026,
#   'Latitude': -22.9023368,
#   'Longitude': -45.8012392,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 133,
#   'Observações': None},
#  'D6-24000294': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:41:37',
#   'Rodovia': 'SP 050',
#   'Km': 132.62381435936877,
#   'Km Final': 132.62381435936877,
#   'Latitude': -22.911185,
#   'Longitude': -45.800425,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 132,
#   'Observações': None},
#  'D6-24000295': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:43:17',
#   'Rodovia': 'SP 050',
#   'Km': 131.6252714836659,
#   'Km Final': 131.6252714836659,
#   'Latitude': -22.9178302,
#   'Longitude': -45.8059269,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 131,
#   'Observações': None},
#  'D6-24000296': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:44:45',
#   'Rodovia': 'SP 050',
#   'Km': 130.675505797192,
#   'Km Final': 130.675505797192,
#   'Latitude': -22.9216504,
#   'Longitude': -45.8111709,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 130,
#   'Observações': None},
#  'D6-24000297': {'Unidade': 'DER/SP - D6',
#   'Encontrado Em': '09-05-2024 16:46:06',
#   'Rodovia': 'SP 050',
#   'Km': 129.7003634526706,
#   'Km Final': 129.7003634526706,
#   'Latitude': -22.9200093,
#   'Longitude': -45.8198763,
#   'Classe': 'Correção de marco quilométrico',
#   'Quilometro correto': 129,
#   'Observações': None},
#  ...}

# %%
df = pd.DataFrame.from_dict(dados)

# %%
df.transpose()
# Out:
#                    Unidade        Encontrado Em Rodovia         Km   Km Final  \
# D1-24000024    DER/SP - D1  08-04-2024 13:34:00  SP-280       23.0       23.0
# D1-24000049    DER/SP - D1  02-05-2024 11:55:37  SP 360  16.225849  16.225849
# D1-24000050    DER/SP - D1  02-05-2024 12:03:15  SP 360  17.370744  17.370744
# D1-24000051    DER/SP - D1  02-05-2024 12:09:49  SP 360  18.511854  18.511854
# D1-24000052    DER/SP - D1  02-05-2024 12:22:53  SP 360  86.511569  86.511569
# ...                    ...                  ...     ...        ...        ...
# D14-24000159  DER/SP - D14  09-05-2024 18:58:35  SP 385  23.068997  23.068997
# D14-24000160  DER/SP - D14  09-05-2024 19:00:21  SP 385  22.001533  22.001533
# D14-24000161  DER/SP - D14  09-05-2024 19:02:37  SP 385  20.973186  20.973186
# D14-24000162  DER/SP - D14  09-05-2024 19:04:40  SP 385  19.901732  19.901732
# D14-24000163  DER/SP - D14  09-05-2024 19:06:13  SP 385      19.26      19.26
#
#                Latitude  Longitude                          Classe  \
# D1-24000024  -23.138908 -48.437154  Correção de marco quilométrico
# D1-24000049  -23.035812 -46.842944  Correção de marco quilométrico
# D1-24000050  -23.027512 -46.840298  Correção de marco quilométrico
# D1-24000051  -23.019335 -46.842335  Correção de marco quilométrico
# D1-24000052  -23.000022 -46.848234  Correção de marco quilométrico
# ...                 ...        ...                             ...
# D14-24000159 -20.195011 -47.952928  Correção de marco quilométrico
# D14-24000160 -20.200297 -47.944797  Correção de marco quilométrico
# D14-24000161 -20.205375  -47.93695  Correção de marco quilométrico
# D14-24000162 -20.210563 -47.928665  Correção de marco quilométrico
# D14-24000163 -20.212783 -47.922412  Correção de marco quilométrico
#
#              Quilometro correto              Observações
# D1-24000024                  24                     None
# D1-24000049                  82                     None
# D1-24000050                  83                     None
# D1-24000051                  84                     None
# D1-24000052                  87                     None
# ...                         ...                      ...
# D14-24000159                 23                     None
# D14-24000160                 22  Ausente de placa do km
# D14-24000161                 21                     None
# D14-24000162                 20  Ausente de placa do km
# D14-24000163                 19                     None
#
# [2294 rows x 10 columns]

# %%
month=datetime.datetime.now().month
day=datetime.datetime.now().day

# %%
df.transpose().to_excel(f'Rel_DERs_{day}_{month}.xlsx')
